# %% [markdown]
# # we can write in here
#
# it will have misspellinfs
#
# Dont ever ttype in a demo

# %%
Get-Module -ListAvailable
# Out:
#     Directory: C:\Users\mrrob\.dotnet\tools\.store\microsoft.dotnet-interactive\1.0.115702\microsof
# t.dotnet-interactive\1.0.115702\tools\netcoreapp3.1\any\Modules
#
# ModuleType Version    PreRelease Name                                PSEdition ExportedCommands
# ---------- -------    ---------- ----                                --------- ----------------
# Manifest   0.1.0                 Microsoft.DotNet.Interactive.Power… Core      {Get-HtmlContent, N…
# Manifest   1.2.5                 Microsoft.PowerShell.Archive        Desk      {Compress-Archive, …
# Script     1.4.6                 PackageManagement                   Desk      {Find-Package, Get-…
# Script     2.2.3                 PowerShellGet                       Desk      {Find-Command, Find…
# Binary     2.0.3                 ThreadJob                           Desk      Start-ThreadJob
#
#     Directory: C:\Users\mrrob\OneDrive\Documents\PowerShell\Modules
#
# ...
