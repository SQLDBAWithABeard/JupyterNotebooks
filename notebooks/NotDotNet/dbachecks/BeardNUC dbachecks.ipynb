# %% [markdown]
# # Exploring PowerShell Notebooks
#
# 1. Get Some coffee
# 233. Check the backups
# 6. Get some more coffee
# 323423. make sure the that capitalisation is consistent

# %% [markdown]
# This will show the version of PowerShell that is being used. On a Windows Machine it will be Windows 5.1 on a Windows Machine and PowerShell Core 6.2.3 on a Linux or Mac.

# %%
$PSVersionTable
# Out:
# Name                           Value
# ----                           -----
# PSVersion                      5.1.18362.145
# PSEdition                      Desktop
# PSCompatibleVersions           {1.0, 2.0, 3.0, 4.0...}
# BuildVersion                   10.0.18362.145
# CLRVersion                     4.0.30319.42000
# WSManStackVersion              3.0
# PSRemotingProtocolVersion      2.3
# SerializationVersion           1.1.0.1

# %% [markdown]
# Make sure that dbachecks is available, if no response here run `Install-Module dbachecks -Scope CurrentUser`

# %%
Get-Module dbachecks -ListAvailable
# Out:
#     Directory: C:\Users\Rob\Documents\WindowsPowerShell\Modules
#
#
# ModuleType Version    Name                                ExportedCommands
# ---------- -------    ----                                ----------------
# Script     1.2.24     dbachecks                           {Get-DbcConfig, Get-DbcConfigValue, Get-DbcReleaseNote, Se...

# %% [markdown]
# This will set all of the currently runnign instances on my Hyper-V Hosts with SQL in the name in a variable. (This works becuase I name my VMs the same as the Host Name applied to the machine)

# %%
$SqlInstances = (Get-Vm -ComputerName BEARDNUC,BEARDNUC2).Where{$_.State -eq 'Running' -and $_.Name -like '*SQL*'}.Name

# %% [markdown]
# Going to check that the Instances are available

# %%
Invoke-DbcCheck -Sqlinstance $SqlInstances -Check InstanceConnection
# Out:
#     ____            __
#    / __ \___  _____/ /____  _____
#   / /_/ / _ \/ ___/ __/ _ \/ ___/
#  / ____/  __(__  ) /_/  __/ /
# /_/    \___/____/\__/\___/_/
# Pester v4.9.0
# Executing all tests in 'C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1' with Tags InstanceConnection
#
# Executing script C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2005Ser2003
#       [+] connects successfully to SQL2005Ser2003 2ms
#       [+] auth scheme should be Kerberos on SQL2005Ser2003 41ms
#       [+] SQL2005Ser2003 is pingable 5ms
#       [+] SQL2005Ser2003 Is PSRemoteable 580ms
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2008Ser12R2
#       [+] connects successfully to SQL2008Ser12R2 1ms
#       [+] auth scheme should be Kerberos on SQL2008Ser12R2 246ms
#       [+] SQL2008Ser12R2 is pingable 2ms
#       [+] SQL2008Ser12R2 Is PSRemoteable 419ms
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2012Ser08AG1
#       [+] connects successfully to SQL2012Ser08AG1 1ms
#       [+] auth scheme should be Kerberos on SQL2012Ser08AG1 102ms
#       [+] SQL2012Ser08AG1 is pingable 5ms
#       [+] SQL2012Ser08AG1 Is PSRemoteable 662ms
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2012Ser08AG2
#       [+] connects successfully to SQL2012Ser08AG2 2ms
#       [+] auth scheme should be Kerberos on SQL2012Ser08AG2 476ms
#       [+] SQL2012Ser08AG2 is pingable 2ms
#       [+] SQL2012Ser08AG2 Is PSRemoteable 531ms
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2012Ser08AG3
#       [+] connects successfully to SQL2012Ser08AG3 4ms
#       [+] auth scheme should be Kerberos on SQL2012Ser08AG3 347ms
#       [+] SQL2012Ser08AG3 is pingable 4ms
#       [+] SQL2012Ser08AG3 Is PSRemoteable 486ms
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2014Ser12R2
#       [+] connects successfully to SQL2014Ser12R2 1ms
#       [+] auth scheme should be Kerberos on SQL2014Ser12R2 72ms
#       [+] SQL2014Ser12R2 is pingable 3ms
#       [+] SQL2014Ser12R2 Is PSRemoteable 574ms
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2016N1
#       [+] connects successfully to SQL2016N1 3ms
#       [+] auth scheme should be Kerberos on SQL2016N1 102ms
#       [+] SQL2016N1 is pingable 5ms
#       [+] SQL2016N1 Is PSRemoteable 801ms
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2016N2
#       [+] connects successfully to SQL2016N2 1ms
#       [+] auth scheme should be Kerberos on SQL2016N2 136ms
#       [+] SQL2016N2 is pingable 4ms
#       [+] SQL2016N2 Is PSRemoteable 1.11s
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2016N3
#       [+] connects successfully to SQL2016N3 1ms
#       [+] auth scheme should be Kerberos on SQL2016N3 149ms
#       [+] SQL2016N3 is pingable 2ms
#       [+] SQL2016N3 Is PSRemoteable 387ms
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2017N5
#       [+] connects successfully to SQL2017N5 1ms
#       [+] auth scheme should be Kerberos on SQL2017N5 101ms
#       [-] SQL2017N5 is pingable 607ms
#         Expected $true, but got $false.
#         72:                     $pingable | Should -BeTrue
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1: line 72
#       [+] SQL2017N5 Is PSRemoteable 1.26s
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2019N20
#       [+] connects successfully to SQL2019N20 1ms
#       [+] auth scheme should be Kerberos on SQL2019N20 50ms
#       [-] SQL2019N20 is pingable 951ms
#         Expected $true, but got $false.
#         72:                     $pingable | Should -BeTrue
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1: line 72
#       [+] SQL2019N20 Is PSRemoteable 1.63s
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2019N21
#       [+] connects successfully to SQL2019N21 1ms
#       [+] auth scheme should be Kerberos on SQL2019N21 63ms
#       [-] SQL2019N21 is pingable 637ms
#         Expected $true, but got $false.
#         72:                     $pingable | Should -BeTrue
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1: line 72
#       [+] SQL2019N21 Is PSRemoteable 715ms
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2019N22
#       [+] connects successfully to SQL2019N22 1ms
#       [+] auth scheme should be Kerberos on SQL2019N22 60ms
#       [-] SQL2019N22 is pingable 565ms
#         Expected $true, but got $false.
#         72:                     $pingable | Should -BeTrue
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1: line 72
#       [+] SQL2019N22 Is PSRemoteable 653ms
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2019N5
#       [+] connects successfully to SQL2019N5 1ms
#       [+] auth scheme should be Kerberos on SQL2019N5 55ms
#       [-] SQL2019N5 is pingable 619ms
#         Expected $true, but got $false.
#         72:                     $pingable | Should -BeTrue
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1: line 72
#       [+] SQL2019N5 Is PSRemoteable 643ms
# Tests completed in 19.93s
# Tests Passed: 51, Failed: 5, Skipped: 0, Pending: 0, Inconclusive: 0

# %% [markdown]
# This is my favourite check - how quick can I check the last time that DBCC CHeckDB was run?

# %%
Get-DbaDatabase -SqlInstance $SqlInstances | Group-Object SqlInstance | Measure-Object Count  -Sum
# Out:
# Count    : 14
# Average  :
# Sum      : 160
# Maximum  :
# Minimum  :
# Property : Count

# %%
Invoke-DbcCheck -SqlInstance $sqlInstances -Check LastGoodCheckDb
# Out:
#     ____            __
#    / __ \___  _____/ /____  _____
#   / /_/ / _ \/ ___/ __/ _ \/ ___/
#  / ____/  __(__  ) /_/  __/ /
# /_/    \___/____/\__/\___/_/
# Pester v4.9.0
# Executing all tests in 'C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1' with Tags LastGoodCheckDb
#
# Executing script C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1
#
#   Describing Last Good DBCC CHECKDB
#
#     Context Testing Last Good DBCC CHECKDB on SQL2005Ser2003
#       [+] last good integrity check for master on SQL2005SER2003 should be less than 7 days old 2ms
#       [+] last good integrity check for master on SQL2005SER2003 has Data Purity Enabled 2ms
#       [+] last good integrity check for model on SQL2005SER2003 should be less than 7 days old 2ms
#       [+] last good integrity check for model on SQL2005SER2003 has Data Purity Enabled 1ms
#       [+] last good integrity check for msdb on SQL2005SER2003 should be less than 7 days old 4ms
#       [+] last good integrity check for msdb on SQL2005SER2003 has Data Purity Enabled 2ms
#       [+] last good integrity check for AdventureWorksDW on SQL2005SER2003 should be less than 7 days old 1ms
#       [+] last good integrity check for AdventureWorksDW on SQL2005SER2003 has Data Purity Enabled 1ms
#       [+] last good integrity check for AdventureWorks on SQL2005SER2003 should be less than 7 days old 2ms
#       [+] last good integrity check for AdventureWorks on SQL2005SER2003 has Data Purity Enabled 2ms
#       [+] last good integrity check for Aerosmith on SQL2005SER2003 should be less than 7 days old 1ms
#       [+] last good integrity check for Aerosmith on SQL2005SER2003 has Data Purity Enabled 5ms
#       [+] last good integrity check for BlackSabbath on SQL2005SER2003 should be less than 7 days old 1ms
#       [+] last good integrity check for BlackSabbath on SQL2005SER2003 has Data Purity Enabled 2ms
#       [+] last good integrity check for IronMaiden on SQL2005SER2003 should be less than 7 days old 1ms
#       [+] last good integrity check for IronMaiden on SQL2005SER2003 has Data Purity Enabled 1ms
#       [+] last good integrity check for Nirvana on SQL2005SER2003 should be less than 7 days old 2ms
#       [+] last good integrity check for Nirvana on SQL2005SER2003 has Data Purity Enabled 2ms
#       [+] last good integrity check for Prince on SQL2005SER2003 should be less than 7 days old 2ms
#       [+] last good integrity check for Prince on SQL2005SER2003 has Data Purity Enabled 2ms
#       [+] last good integrity check for RageAgainstTheMachine on SQL2005SER2003 should be less than 7 days old 1ms
#       [+] last good integrity check for RageAgainstTheMachine on SQL2005SER2003 has Data Purity Enabled 1ms
#       [+] last good integrity check for DBA-Admin on SQL2005SER2003 should be less than 7 days old 1ms
#       [+] last good integrity check for DBA-Admin on SQL2005SER2003 has Data Purity Enabled 1ms
#
#   Describing Last Good DBCC CHECKDB
#
#     Context Testing Last Good DBCC CHECKDB on SQL2008Ser12R2
#       [+] last good integrity check for master on SQL2008SER12R2 should be less than 7 days old 1ms
#       [+] last good integrity check for master on SQL2008SER12R2 has Data Purity Enabled 2ms
#       [+] last good integrity check for model on SQL2008SER12R2 should be less than 7 days old 1ms
#       [+] last good integrity check for model on SQL2008SER12R2 has Data Purity Enabled 1ms
#       [+] last good integrity check for msdb on SQL2008SER12R2 should be less than 7 days old 1ms
#       [+] last good integrity check for msdb on SQL2008SER12R2 has Data Purity Enabled 1ms
#       [-] last good integrity check for DBA-Admin on SQL2008SER12R2 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:31.1195548Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:07.9930000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for DBA-Admin on SQL2008SER12R2 has Data Purity Enabled 1ms
#
#   Describing Last Good DBCC CHECKDB
#
#     Context Testing Last Good DBCC CHECKDB on SQL2012Ser08AG1
#       [+] last good integrity check for master on SQL2012SER08AG1 should be less than 7 days old 3ms
#       [+] last good integrity check for master on SQL2012SER08AG1 has Data Purity Enabled 3ms
#       [+] last good integrity check for model on SQL2012SER08AG1 should be less than 7 days old 1ms
#       [+] last good integrity check for model on SQL2012SER08AG1 has Data Purity Enabled 1ms
#       [+] last good integrity check for msdb on SQL2012SER08AG1 should be less than 7 days old 1ms
#       [+] last good integrity check for msdb on SQL2012SER08AG1 has Data Purity Enabled 1ms
#       [-] last good integrity check for AdventureWorks2012AG on SQL2012SER08AG1 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:31.8691187Z, because You should have run a DBCC CheckDB inside that time, but got 2017-04-22T00:00:03.1270000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for AdventureWorks2012AG on SQL2012SER08AG1 has Data Purity Enabled 1ms
#       [-] last good integrity check for SQL2012Ser08AG_DB on SQL2012SER08AG1 should be less than 7 days old 2ms
#         Expected the actual value to be greater than 2020-01-20T23:11:31.8871546Z, because You should have run a DBCC CheckDB inside that time, but got 2017-04-22T00:00:35.5970000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for SQL2012Ser08AG_DB on SQL2012SER08AG1 has Data Purity Enabled 1ms
#       [-] last good integrity check for UserGroupTest on SQL2012SER08AG1 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:31.9071186Z, because You should have run a DBCC CheckDB inside that time, but got 2017-04-22T00:00:44.4300000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for UserGroupTest on SQL2012SER08AG1 has Data Purity Enabled 1ms
#       [-] last good integrity check for TestDatabase on SQL2012SER08AG1 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:31.9251723Z, because You should have run a DBCC CheckDB inside that time, but got 2017-04-22T00:00:39.5030000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for TestDatabase on SQL2012SER08AG1 has Data Purity Enabled 1ms
#       [-] last good integrity check for Store on SQL2012SER08AG1 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:31.9451521Z, because You should have run a DBCC CheckDB inside that time, but got 2017-04-22T00:00:38.9900000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for Store on SQL2012SER08AG1 has Data Purity Enabled 2ms
#       [-] last good integrity check for HarvesterofSorrow on SQL2012SER08AG1 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:31.9681478Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:10.0870000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for HarvesterofSorrow on SQL2012SER08AG1 has Data Purity Enabled 1ms
#       [-] last good integrity check for AGDB on SQL2012SER08AG1 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:31.9868752Z, because You should have run a DBCC CheckDB inside that time, but got 2017-04-22T00:00:28.0000000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for AGDB on SQL2012SER08AG1 has Data Purity Enabled 2ms
#       [-] last good integrity check for EyeoftheBeholder on SQL2012SER08AG1 should be less than 7 days old 2ms
#         Expected the actual value to be greater than 2020-01-20T23:11:32.0058758Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:08.0230000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for EyeoftheBeholder on SQL2012SER08AG1 has Data Purity Enabled 1ms
#       [-] last good integrity check for AndJusticeforAll on SQL2012SER08AG1 should be less than 7 days old 2ms
#         Expected the actual value to be greater than 2020-01-20T23:11:32.0258754Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:01.2830000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for AndJusticeforAll on SQL2012SER08AG1 has Data Purity Enabled 1ms
#       [-] last good integrity check for TheShortestStraw on SQL2012SER08AG1 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:32.0438752Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:39.4970000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for TheShortestStraw on SQL2012SER08AG1 has Data Purity Enabled 1ms
#       [-] last good integrity check for One on SQL2012SER08AG1 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:32.0648735Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:11.5500000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for One on SQL2012SER08AG1 has Data Purity Enabled 1ms
#       [-] last good integrity check for TheFrayedEndsofSanity on SQL2012SER08AG1 should be less than 7 days old 5ms
#         Expected the actual value to be greater than 2020-01-20T23:11:32.0838748Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:39.1000000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for TheFrayedEndsofSanity on SQL2012SER08AG1 has Data Purity Enabled 1ms
#       [-] last good integrity check for Blackened on SQL2012SER08AG1 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:32.1049112Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:03.1100000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for Blackened on SQL2012SER08AG1 has Data Purity Enabled 2ms
#       [-] last good integrity check for DyersEve on SQL2012SER08AG1 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:32.1248905Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:06.7930000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for DyersEve on SQL2012SER08AG1 has Data Purity Enabled 2ms
#       [-] last good integrity check for ToLiveIstoDie on SQL2012SER08AG1 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:32.1498772Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:39.9100000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for ToLiveIstoDie on SQL2012SER08AG1 has Data Purity Enabled 1ms
#       [-] last good integrity check for DBA-Admin on SQL2012SER08AG1 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:32.1709129Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:04.7600000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for DBA-Admin on SQL2012SER08AG1 has Data Purity Enabled 3ms
#       [-] last good integrity check for SQLWatch on SQL2012SER08AG1 should be less than 7 days old 5ms
#         Expected the actual value to be greater than 2020-01-20T23:11:32.1918770Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:13.5200000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for SQLWatch on SQL2012SER08AG1 has Data Purity Enabled 3ms
#
#   Describing Last Good DBCC CHECKDB
#
#     Context Testing Last Good DBCC CHECKDB on SQL2012Ser08AG2
#       [-] last good integrity check for master on SQL2012SER08AG2 should be less than 7 days old 2ms
#         Expected the actual value to be greater than 2020-01-20T23:11:32.6919795Z, because You should have run a DBCC CheckDB inside that time, but got 2016-04-10T14:23:43.3300000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for master on SQL2012SER08AG2 has Data Purity Enabled 1ms
#       [+] last good integrity check for model on SQL2012SER08AG2 should be less than 7 days old 1ms
#       [+] last good integrity check for model on SQL2012SER08AG2 has Data Purity Enabled 3ms
#       [+] last good integrity check for msdb on SQL2012SER08AG2 should be less than 7 days old 1ms
#       [+] last good integrity check for msdb on SQL2012SER08AG2 has Data Purity Enabled 1ms
#       [-] last good integrity check for DBA-Admin on SQL2012SER08AG2 should be less than 7 days old 2ms
#         Expected the actual value to be greater than 2020-01-20T23:11:32.7419928Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:01.4200000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for DBA-Admin on SQL2012SER08AG2 has Data Purity Enabled 2ms
#       [-] last good integrity check for SQLWatch on SQL2012SER08AG2 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:32.7629942Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:04.3170000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for SQLWatch on SQL2012SER08AG2 has Data Purity Enabled 1ms
#
#   Describing Last Good DBCC CHECKDB
#
#     Context Testing Last Good DBCC CHECKDB on SQL2012Ser08AG3
#       [+] last good integrity check for master on SQL2012SER08AG3 should be less than 7 days old 3ms
#       [+] last good integrity check for master on SQL2012SER08AG3 has Data Purity Enabled 1ms
#       [+] last good integrity check for model on SQL2012SER08AG3 should be less than 7 days old 1ms
#       [+] last good integrity check for model on SQL2012SER08AG3 has Data Purity Enabled 2ms
#       [+] last good integrity check for msdb on SQL2012SER08AG3 should be less than 7 days old 2ms
#       [+] last good integrity check for msdb on SQL2012SER08AG3 has Data Purity Enabled 1ms
#       [-] last good integrity check for SQLWatch on SQL2012SER08AG3 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:33.3083857Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:06.8570000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for SQLWatch on SQL2012SER08AG3 has Data Purity Enabled 2ms
#       [-] last good integrity check for DBA-Admin on SQL2012SER08AG3 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:33.3288927Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:01.7370000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for DBA-Admin on SQL2012SER08AG3 has Data Purity Enabled 1ms
#
#   Describing Last Good DBCC CHECKDB
#
#     Context Testing Last Good DBCC CHECKDB on SQL2014Ser12R2
#       [+] last good integrity check for master on SQL2014SER12R2 should be less than 7 days old 3ms
#       [+] last good integrity check for master on SQL2014SER12R2 has Data Purity Enabled 1ms
#       [+] last good integrity check for model on SQL2014SER12R2 should be less than 7 days old 1ms
#       [+] last good integrity check for model on SQL2014SER12R2 has Data Purity Enabled 1ms
#       [+] last good integrity check for msdb on SQL2014SER12R2 should be less than 7 days old 1ms
#       [+] last good integrity check for msdb on SQL2014SER12R2 has Data Purity Enabled 1ms
#       [-] last good integrity check for ReportServer on SQL2014SER12R2 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:33.9461214Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-30T08:48:26.0470000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for ReportServer on SQL2014SER12R2 has Data Purity Enabled 1ms
#       [-] last good integrity check for ReportServerTempDB on SQL2014SER12R2 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:33.9671222Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-30T08:48:26.6570000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for ReportServerTempDB on SQL2014SER12R2 has Data Purity Enabled 2ms
#       [-] last good integrity check for SQL2014Ser12R2DB on SQL2014SER12R2 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:33.9871207Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-30T08:48:27.4400000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for SQL2014Ser12R2DB on SQL2014SER12R2 has Data Purity Enabled 1ms
#       [-] last good integrity check for CricketAverages on SQL2014SER12R2 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.0091557Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-30T08:48:22.4800000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for CricketAverages on SQL2014SER12R2 has Data Purity Enabled 1ms
#       [-] last good integrity check for CricketAverages-2014-4-24-19-26 on SQL2014SER12R2 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.0301219Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-30T08:48:22.9770000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for CricketAverages-2014-4-24-19-26 on SQL2014SER12R2 has Data Purity Enabled 1ms
#       [-] last good integrity check for SchemaCheck on SQL2014SER12R2 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.0501603Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-30T08:48:27.0770000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for SchemaCheck on SQL2014SER12R2 has Data Purity Enabled 1ms
#       [-] last good integrity check for MDW-Test on SQL2014SER12R2 should be less than 7 days old 2ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.0741457Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-30T08:48:25.3800000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for MDW-Test on SQL2014SER12R2 has Data Purity Enabled 1ms
#       [-] last good integrity check for AdventureWorks2014 on SQL2014SER12R2 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.0941204Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-30T08:45:34.8170000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for AdventureWorks2014 on SQL2014SER12R2 has Data Purity Enabled 1ms
#       [-] last good integrity check for AdventureWorksDW2014 on SQL2014SER12R2 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.1151196Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-30T08:48:11.9400000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for AdventureWorksDW2014 on SQL2014SER12R2 has Data Purity Enabled 2ms
#       [-] last good integrity check for SQLWatch on SQL2014SER12R2 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.1371223Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-30T08:48:27.9130000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for SQLWatch on SQL2014SER12R2 has Data Purity Enabled 1ms
#       [-] last good integrity check for aSchemaCheck on SQL2014SER12R2 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.1581202Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-30T08:48:20.7470000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for aSchemaCheck on SQL2014SER12R2 has Data Purity Enabled 1ms
#       [-] last good integrity check for Autogrowth on SQL2014SER12R2 should be less than 7 days old 2ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.1771595Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-30T08:48:21.9800000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for Autogrowth on SQL2014SER12R2 has Data Purity Enabled 1ms
#       [-] last good integrity check for ReportQueries on SQL2014SER12R2 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.1961544Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-30T08:48:25.7200000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for ReportQueries on SQL2014SER12R2 has Data Purity Enabled 1ms
#       [-] last good integrity check for DBA on SQL2014SER12R2 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.2161192Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-30T08:48:23.3900000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for DBA on SQL2014SER12R2 has Data Purity Enabled 1ms
#       [-] last good integrity check for DBADatabase on SQL2014SER12R2 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.2361452Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-30T08:48:24.7130000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for DBADatabase on SQL2014SER12R2 has Data Purity Enabled 1ms
#       [-] last good integrity check for DBA-Admin on SQL2014SER12R2 should be less than 7 days old 2ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.2561199Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-30T08:48:23.9500000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for DBA-Admin on SQL2014SER12R2 has Data Purity Enabled 1ms
#
#   Describing Last Good DBCC CHECKDB
#
#     Context Testing Last Good DBCC CHECKDB on SQL2016N1
#       [+] last good integrity check for master on SQL2016N1 should be less than 7 days old 1ms
#       [+] last good integrity check for master on SQL2016N1 has Data Purity Enabled 1ms
#       [+] last good integrity check for model on SQL2016N1 should be less than 7 days old 2ms
#       [+] last good integrity check for model on SQL2016N1 has Data Purity Enabled 2ms
#       [+] last good integrity check for msdb on SQL2016N1 should be less than 7 days old 1ms
#       [+] last good integrity check for msdb on SQL2016N1 has Data Purity Enabled 1ms
#       [-] last good integrity check for DBA-Admin on SQL2016N1 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.8639901Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:24.0370000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for DBA-Admin on SQL2016N1 has Data Purity Enabled 1ms
#       [-] last good integrity check for ReportServer on SQL2016N1 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.8830048Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:42.2830000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for ReportServer on SQL2016N1 has Data Purity Enabled 1ms
#       [-] last good integrity check for ReportServerTempDB on SQL2016N1 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.9049633Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:43.1870000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for ReportServerTempDB on SQL2016N1 has Data Purity Enabled 1ms
#       [-] last good integrity check for DAC on SQL2016N1 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.9249623Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:18.6530000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for DAC on SQL2016N1 has Data Purity Enabled 1ms
#       [-] last good integrity check for SSISDB on SQL2016N1 should be less than 7 days old 2ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.9450018Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:50.9870000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for SSISDB on SQL2016N1 has Data Purity Enabled 3ms
#       [-] last good integrity check for dbachecks on SQL2016N1 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.9659889Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:28.1030000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for dbachecks on SQL2016N1 has Data Purity Enabled 1ms
#       [-] last good integrity check for AdventureWorksDW2014 on SQL2016N1 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:34.9869800Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:01.7000000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for AdventureWorksDW2014 on SQL2016N1 has Data Purity Enabled 1ms
#       [-] last good integrity check for BeardedAg_db on SQL2016N1 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:35.0079753Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:13.8600000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for BeardedAg_db on SQL2016N1 has Data Purity Enabled 1ms
#       [-] last good integrity check for database on SQL2016N1 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:35.0280217Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:21.3900000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for database on SQL2016N1 has Data Purity Enabled 1ms
#       [-] last good integrity check for SQLWatch on SQL2016N1 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:35.0470020Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:43.5930000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for SQLWatch on SQL2016N1 has Data Purity Enabled 1ms
#
#   Describing Last Good DBCC CHECKDB
#
#     Context Testing Last Good DBCC CHECKDB on SQL2016N2
#       [+] last good integrity check for master on SQL2016N2 should be less than 7 days old 1ms
#       [+] last good integrity check for master on SQL2016N2 has Data Purity Enabled 1ms
#       [+] last good integrity check for model on SQL2016N2 should be less than 7 days old 1ms
#       [+] last good integrity check for model on SQL2016N2 has Data Purity Enabled 1ms
#       [+] last good integrity check for msdb on SQL2016N2 should be less than 7 days old 2ms
#       [+] last good integrity check for msdb on SQL2016N2 has Data Purity Enabled 1ms
#       [-] last good integrity check for TheBeardsProd on SQL2016N2 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:35.6021185Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:51.8100000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for TheBeardsProd on SQL2016N2 has Data Purity Enabled 1ms
#       [-] last good integrity check for DBA-Admin on SQL2016N2 should be less than 7 days old 6ms
#         Expected the actual value to be greater than 2020-01-20T23:11:35.6221194Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:01.7130000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for DBA-Admin on SQL2016N2 has Data Purity Enabled 1ms
#       [-] last good integrity check for NoGoodDBCC on SQL2016N2 should be less than 7 days old 2ms
#         Expected the actual value to be greater than 2020-01-20T23:11:35.6441201Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:41.2470000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for NoGoodDBCC on SQL2016N2 has Data Purity Enabled 3ms
#       [-] last good integrity check for Viennadbareports on SQL2016N2 should be less than 7 days old 2ms
#         Expected the actual value to be greater than 2020-01-20T23:11:35.6631196Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:52.6970000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for Viennadbareports on SQL2016N2 has Data Purity Enabled 1ms
#       [-] last good integrity check for VideoDemodbareports on SQL2016N2 should be less than 7 days old 2ms
#         Expected the actual value to be greater than 2020-01-20T23:11:35.6811203Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:52.2700000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for VideoDemodbareports on SQL2016N2 has Data Purity Enabled 1ms
#       [-] last good integrity check for passrocssug_dbareports on SQL2016N2 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:35.7011200Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:41.8730000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for passrocssug_dbareports on SQL2016N2 has Data Purity Enabled 1ms
#       [-] last good integrity check for Lisbondbareports on SQL2016N2 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:35.7210870Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:40.1830000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for Lisbondbareports on SQL2016N2 has Data Purity Enabled 1ms
#       [-] last good integrity check for DEMOdbareports on SQL2016N2 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:35.7400863Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:39.4900000.
# ...
#         Expected the actual value to be greater than 2020-01-20T23:11:36.3412204Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:39.4900000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for DEMOdbareports on SQL2016N3 has Data Purity Enabled 1ms
#       [-] last good integrity check for NoGoodDBCC on SQL2016N3 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:36.3652220Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:41.2470000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for NoGoodDBCC on SQL2016N3 has Data Purity Enabled 1ms
#       [-] last good integrity check for TheBeardsProd on SQL2016N3 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:36.3832206Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:51.8100000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for TheBeardsProd on SQL2016N3 has Data Purity Enabled 1ms
#       [-] last good integrity check for passrocssug_dbareports on SQL2016N3 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:36.4032370Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:41.8730000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for passrocssug_dbareports on SQL2016N3 has Data Purity Enabled 1ms
#       [-] last good integrity check for VideoDemodbareports on SQL2016N3 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:36.4212230Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:52.2700000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for VideoDemodbareports on SQL2016N3 has Data Purity Enabled 1ms
#       [-] last good integrity check for Lisbondbareports on SQL2016N3 should be less than 7 days old 2ms
#         Expected the actual value to be greater than 2020-01-20T23:11:36.4412209Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:40.1830000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for Lisbondbareports on SQL2016N3 has Data Purity Enabled 2ms
#       [-] last good integrity check for Viennadbareports on SQL2016N3 should be less than 7 days old 2ms
#         Expected the actual value to be greater than 2020-01-20T23:11:36.4602200Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:52.6970000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for Viennadbareports on SQL2016N3 has Data Purity Enabled 1ms
#       [-] last good integrity check for SQLWatch on SQL2016N3 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:36.4822415Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:20.0700000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for SQLWatch on SQL2016N3 has Data Purity Enabled 1ms
#       [-] last good integrity check for DBA-Admin on SQL2016N3 should be less than 7 days old 2ms
#         Expected the actual value to be greater than 2020-01-20T23:11:36.5042404Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-27T07:35:05.1630000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for DBA-Admin on SQL2016N3 has Data Purity Enabled 1ms
#
#   Describing Last Good DBCC CHECKDB
#
#     Context Testing Last Good DBCC CHECKDB on SQL2017N5
#       [+] last good integrity check for master on SQL2017N5 should be less than 7 days old 2ms
#       [+] last good integrity check for master on SQL2017N5 has Data Purity Enabled 1ms
#       [+] last good integrity check for model on SQL2017N5 should be less than 7 days old 1ms
#       [+] last good integrity check for model on SQL2017N5 has Data Purity Enabled 1ms
#       [+] last good integrity check for msdb on SQL2017N5 should be less than 7 days old 1ms
#       [+] last good integrity check for msdb on SQL2017N5 has Data Purity Enabled 1ms
#       [-] last good integrity check for SqlWatch on SQL2017N5 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:36.8589184Z, because You should have run a DBCC CheckDB inside that time, but got 2020-01-14T16:47:37.5200000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for SqlWatch on SQL2017N5 has Data Purity Enabled 1ms
#       [-] last good integrity check for SSISDB on SQL2017N5 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:36.8799186Z, because You should have run a DBCC CheckDB inside that time, but got $null.
#         203:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 203
#       [+] last good integrity check for SSISDB on SQL2017N5 has Data Purity Enabled 1ms
#       [-] last good integrity check for ASockFactory on SQL2017N5 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:36.9009190Z, because You should have run a DBCC CheckDB inside that time, but got $null.
#         203:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 203
#       [+] last good integrity check for ASockFactory on SQL2017N5 has Data Purity Enabled 1ms
#       [-] last good integrity check for ASausageFactory on SQL2017N5 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:36.9232444Z, because You should have run a DBCC CheckDB inside that time, but got $null.
#         203:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 203
#       [+] last good integrity check for ASausageFactory on SQL2017N5 has Data Purity Enabled 1ms
#       [-] last good integrity check for ADonutFactory on SQL2017N5 should be less than 7 days old 2ms
#         Expected the actual value to be greater than 2020-01-20T23:11:36.9442760Z, because You should have run a DBCC CheckDB inside that time, but got $null.
#         203:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 203
#       [+] last good integrity check for ADonutFactory on SQL2017N5 has Data Purity Enabled 1ms
#
#   Describing Last Good DBCC CHECKDB
#
#     Context Testing Last Good DBCC CHECKDB on SQL2019N20
#       [+] last good integrity check for master on SQL2019N20 should be less than 7 days old 1ms
#       [+] last good integrity check for master on SQL2019N20 has Data Purity Enabled 1ms
#       [+] last good integrity check for model on SQL2019N20 should be less than 7 days old 2ms
#       [+] last good integrity check for model on SQL2019N20 has Data Purity Enabled 1ms
#       [+] last good integrity check for msdb on SQL2019N20 should be less than 7 days old 1ms
#       [+] last good integrity check for msdb on SQL2019N20 has Data Purity Enabled 1ms
#       [-] last good integrity check for SqlWatch on SQL2019N20 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:37.2498182Z, because You should have run a DBCC CheckDB inside that time, but got 2020-01-14T16:47:38.0630000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for SqlWatch on SQL2019N20 has Data Purity Enabled 1ms
#
#   Describing Last Good DBCC CHECKDB
#
#     Context Testing Last Good DBCC CHECKDB on SQL2019N21
#       [+] last good integrity check for master on SQL2019N21 should be less than 7 days old 1ms
#       [+] last good integrity check for master on SQL2019N21 has Data Purity Enabled 1ms
#       [+] last good integrity check for model on SQL2019N21 should be less than 7 days old 3ms
#       [+] last good integrity check for model on SQL2019N21 has Data Purity Enabled 3ms
#       [+] last good integrity check for msdb on SQL2019N21 should be less than 7 days old 1ms
#       [+] last good integrity check for msdb on SQL2019N21 has Data Purity Enabled 1ms
#       [-] last good integrity check for SqlWatch on SQL2019N21 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-01-20T23:11:37.5657944Z, because You should have run a DBCC CheckDB inside that time, but got 2020-01-14T16:47:38.0300000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for SqlWatch on SQL2019N21 has Data Purity Enabled 1ms
#
#   Describing Last Good DBCC CHECKDB
#
#     Context Testing Last Good DBCC CHECKDB on SQL2019N22
#       [+] last good integrity check for master on SQL2019N22 should be less than 7 days old 1ms
#       [+] last good integrity check for master on SQL2019N22 has Data Purity Enabled 1ms
#       [+] last good integrity check for model on SQL2019N22 should be less than 7 days old 1ms
#       [+] last good integrity check for model on SQL2019N22 has Data Purity Enabled 1ms
#       [+] last good integrity check for msdb on SQL2019N22 should be less than 7 days old 1ms
#       [+] last good integrity check for msdb on SQL2019N22 has Data Purity Enabled 1ms
#       [-] last good integrity check for SqlWatch on SQL2019N22 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:37.8868685Z, because You should have run a DBCC CheckDB inside that time, but got 2020-01-14T16:47:37.4730000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for SqlWatch on SQL2019N22 has Data Purity Enabled 1ms
#
#   Describing Last Good DBCC CHECKDB
#
#     Context Testing Last Good DBCC CHECKDB on SQL2019N5
#       [+] last good integrity check for master on SQL2019N5 should be less than 7 days old 1ms
#       [+] last good integrity check for master on SQL2019N5 has Data Purity Enabled 1ms
#       [+] last good integrity check for model on SQL2019N5 should be less than 7 days old 1ms
#       [+] last good integrity check for model on SQL2019N5 has Data Purity Enabled 1ms
#       [+] last good integrity check for msdb on SQL2019N5 should be less than 7 days old 1ms
#       [+] last good integrity check for msdb on SQL2019N5 has Data Purity Enabled 1ms
#       [-] last good integrity check for SqlWatch on SQL2019N5 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-01-20T23:11:38.1735675Z, because You should have run a DBCC CheckDB inside that time, but got 2020-01-14T16:47:38.9930000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\Rob\Documents\WindowsPowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [+] last good integrity check for SqlWatch on SQL2019N5 has Data Purity Enabled 1ms
# Tests completed in 8.35s
# Tests Passed: 177, Failed: 77, Skipped: 0, Pending: 0, Inconclusive: 0
