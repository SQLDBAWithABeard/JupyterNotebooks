# %% [markdown]
# # dbachecks PR check on Beard NUC - MultipleInstances
#
# Rob uses this process to make sure that changes will work in an AD estate with a variety of versions

# %% [markdown]
# First we must check the status of the local source control and ensure that we are in the PR branch

# %%
cd D:\OneDrive\Documents\GitHub\dbachecks
git status
# Out:
# <script type="text/javascript">#!javascript
# if ((typeof(requirejs) !==  typeof(Function)) || (typeof(requirejs.config) !== typeof(Function))) {
#     let script = document.createElement("script");
#     script.setAttribute("src", "https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js");
#     script.onload = function(){
#         loadDotnetInteractiveApi();
#     };
#     document.getElementsByTagName("head")[0].appendChild(script);
# }
# else {
#     loadDotnetInteractiveApi();
# }
#
# function loadDotnetInteractiveApi(){
#     let apiRequire = requirejs.config({context:"dotnet-interactive.17432.62312",paths:{dotnetInteractive:"http://localhost:62312/resources/dotnet-interactive"}});
#     apiRequire(['dotnetInteractive'],
#     function(api) {
#         api.createDotnetInteractiveClient("http://localhost:62312/", window);
#     },
#     function(error){
#         console.log(error);
#     });
# }</script>
# On branch pr/ashdar/752
# Your branch is ahead of 'ashdar/fix_PingComputer' by 66 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %% [markdown]
# First we need to import the module from source control - I normally use verbose to see how it is going

# %%
Import-Module .\dbachecks.psd1
$null = Reset-DbcConfig

# %% [markdown]
# Excellent, that worked. Now to run some checks against a single instance

# %% [markdown]
# I don't care if the test pass or fail, I am only interested in any
#
# > Describe block has Error
#
# or
#
# > Error in Script
#
# type failures

# %% [markdown]
# Multiple Instances at parameter

# %%
Get-VM -ComputerName BEARDNUC, BEARDNUC2
# Out:
# Name                             State   CPUUsage(%) MemoryAssigned(M) Uptime              Status
# ----                             -----   ----------- ----------------- ------              ------
# BeardDC1                         Running 0           978               11.16:02:51.5670000 Operati…
# BeardDC2                         Off     0           0                 00:00:00            Operati…
# BeardLinuxVNext                  Off     0           0                 00:00:00            Operati…
# DockerDesktopVM                  Off     0           0                 00:00:00            Operati…
# LinuxvNextCTP14                  Off     0           0                 00:00:00            Operati…
# PullServer                       Off     0           0                 00:00:00            Operati…
# SQL2005Ser2003                   Running 0           722               11.16:03:23.1270000 Operati…
# SQL2008Ser12R2                   Running 0           874               11.16:03:21.5640000 Operati…
# SQL2012Ser08AG1                  Running 9           3564              10.14:59:55.6120000 Operati…
# SQL2012Ser08AG2                  Running 11          2584              10.14:58:41.4600000 Operati…
# SQL2012Ser08AG3                  Running 10          1988              10.14:58:51.7160000 Operati…
# SQL2014Ser12R2                   Running 9           5354              10.14:55:12.2700000 Operati…
# SQL2016N1                        Running 13          5130              11.16:03:24.9760000 Operati…
# SQL2016N2                        Running 10          4284              10.16:15:13.8460000 Operati…
# SQL2016N3                        Running 9           3628              11.16:03:25.9620000 Operati…
# SQL2017CTP2                      Off     0           0                 00:00:00            Operati…
# SQL2019N1                        Off     0           0                 00:00:00            Operati…
# SQL2019N2                        Off     0           0                 00:00:00            Operati…
# SQLVnextN1                       Off     0           0                 00:00:00            Operati…
# SQLvNextN2                       Off     0           0                 00:00:00            Operati…
# THEBEARDDNS1                     Off     0           0                 00:00:00            Operati…
# BeardDC4                         Running 0           948               4.22:05:21.8310000  Operati…
# BeardNUC2VMs_2020-02-24-03-17-17 Off     0           0                 00:00:00            Operati…
# BeardNUC2VMs_2020-02-24-07-51-51 Off     0           0                 00:00:00            Operati…
# BeardNUC2VMs_2020-02-24-07-54-54 Off     0           0                 00:00:00            Operati…
# BeardNUC2VMs_2020-02-24-07-58-58 Off     0           0                 00:00:00            Operati…
# BeardNUC2VMs_2020-02-24-08-01-01 Off     0           0                 00:00:00            Operati…
# BeardNUC2VMs_2020-03-02-04-51-51 Off     0           0                 00:00:00            Operati…
# BeardNUC2VMs_2020-03-02-04-55-55 Off     0           0                 00:00:00            Operati…
# BeardNUC2VMs_2020-03-02-04-58-58 Off     0           0                 00:00:00            Operati…
# BeardNUC2VMs_2020-03-02-05-02-02 Off     0           0                 00:00:00            Operati…
# BeardNUC2VMs_2020-03-02-05-05-05 Off     0           0                 00:00:00            Operati…
# BeardNUC2VMs_2020-03-02-05-08-08 Off     0           0                 00:00:00            Operati…
# SQL2017N5                        Running 0           4096              4.22:05:22.8610000  Operati…
# SQL2019N20                       Running 0           3446              4.22:05:22.1290000  Operati…
# SQL2019N21                       Running 0           3306              4.22:05:22.6020000  Operati…
# SQL2019N22                       Running 0           3294              4.22:05:22.8340000  Operati…
# SQL2019N5                        Running 0           4096              4.22:05:22.0830000  Operati…

# %%
$Sqlinstances = (Get-VM -ComputerName BEARDNUC, BEARDNUC2 -Name *SQL* | Where State -eq 'Running').Name

Invoke-DbcCheck -SqlInstance $SQLInstances -Check InstanceConnection
# Out:
#     ____            __
#    / __ \___  _____/ /____  _____
#   / /_/ / _ \/ ___/ __/ _ \/ ___/
#  / ____/  __(__  ) /_/  __/ /
# /_/    \___/____/\__/\___/_/
# Pester v4.9.0
# Executing all tests in 'D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1' with Tags InstanceConnection
#
# Executing script D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2005Ser2003
#       [+] connects successfully to SQL2005Ser2003 34ms
#       [+] auth scheme should be Kerberos on SQL2005Ser2003 279ms
#       [+] SQL2005Ser2003 is pingable 20ms
#       [-] SQL2005Ser2003 Is PSRemoteable 30ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2016N2
#       [+] connects successfully to SQL2016N2 1ms
#       [+] auth scheme should be Kerberos on SQL2016N2 133ms
#       [+] SQL2016N2 is pingable 4ms
#       [-] SQL2016N2 Is PSRemoteable 5ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2012Ser08AG1
#       [+] connects successfully to SQL2012Ser08AG1 1ms
#       [+] auth scheme should be Kerberos on SQL2012Ser08AG1 91ms
#       [+] SQL2012Ser08AG1 is pingable 3ms
#       [-] SQL2012Ser08AG1 Is PSRemoteable 5ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2016N3
#       [+] connects successfully to SQL2016N3 3ms
#       [+] auth scheme should be Kerberos on SQL2016N3 96ms
#       [+] SQL2016N3 is pingable 3ms
#       [-] SQL2016N3 Is PSRemoteable 4ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2012Ser08AG3
#       [+] connects successfully to SQL2012Ser08AG3 2ms
#       [+] auth scheme should be Kerberos on SQL2012Ser08AG3 391ms
#       [+] SQL2012Ser08AG3 is pingable 8ms
#       [-] SQL2012Ser08AG3 Is PSRemoteable 4ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2012Ser08AG2
#       [+] connects successfully to SQL2012Ser08AG2 1ms
#       [+] auth scheme should be Kerberos on SQL2012Ser08AG2 109ms
#       [+] SQL2012Ser08AG2 is pingable 4ms
#       [-] SQL2012Ser08AG2 Is PSRemoteable 7ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2014Ser12R2
#       [+] connects successfully to SQL2014Ser12R2 1ms
#       [+] auth scheme should be Kerberos on SQL2014Ser12R2 107ms
#       [+] SQL2014Ser12R2 is pingable 3ms
#       [-] SQL2014Ser12R2 Is PSRemoteable 4ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2008Ser12R2
#       [+] connects successfully to SQL2008Ser12R2 1ms
#       [+] auth scheme should be Kerberos on SQL2008Ser12R2 390ms
#       [+] SQL2008Ser12R2 is pingable 6ms
#       [-] SQL2008Ser12R2 Is PSRemoteable 5ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2016N1
#       [+] connects successfully to SQL2016N1 3ms
#       [+] auth scheme should be Kerberos on SQL2016N1 265ms
#       [+] SQL2016N1 is pingable 6ms
#       [-] SQL2016N1 Is PSRemoteable 5ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2017N5
#       [+] connects successfully to SQL2017N5 1ms
#       [+] auth scheme should be Kerberos on SQL2017N5 115ms
#       [-] SQL2017N5 is pingable 716ms
#         Expected $true, but got $false.
#         72:                     $pingable | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 72
#       [-] SQL2017N5 Is PSRemoteable 3ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2019N22
#       [+] connects successfully to SQL2019N22 2ms
#       [+] auth scheme should be Kerberos on SQL2019N22 53ms
#       [-] SQL2019N22 is pingable 772ms
#         Expected $true, but got $false.
#         72:                     $pingable | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 72
#       [-] SQL2019N22 Is PSRemoteable 5ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2019N21
#       [+] connects successfully to SQL2019N21 1ms
#       [+] auth scheme should be Kerberos on SQL2019N21 49ms
#       [-] SQL2019N21 is pingable 778ms
#         Expected $true, but got $false.
#         72:                     $pingable | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 72
#       [-] SQL2019N21 Is PSRemoteable 6ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2019N20
#       [+] connects successfully to SQL2019N20 2ms
#       [+] auth scheme should be Kerberos on SQL2019N20 67ms
#       [-] SQL2019N20 is pingable 738ms
#         Expected $true, but got $false.
#         72:                     $pingable | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 72
#       [-] SQL2019N20 Is PSRemoteable 4ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2019N5
#       [+] connects successfully to SQL2019N5 1ms
#       [+] auth scheme should be Kerberos on SQL2019N5 59ms
#       [-] SQL2019N5 is pingable 760ms
#         Expected $true, but got $false.
#         72:                     $pingable | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 72
#       [-] SQL2019N5 Is PSRemoteable 6ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
# Tests completed in 10s
# Tests Passed: 37, Failed: 19, Skipped: 0, Pending: 0, Inconclusive: 0
