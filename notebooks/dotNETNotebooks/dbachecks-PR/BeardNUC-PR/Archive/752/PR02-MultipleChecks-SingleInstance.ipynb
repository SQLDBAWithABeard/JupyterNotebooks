# %% [markdown]
# # dbachecks PR check on Beard NUC - Multiple Checks - Single Instance
#
# Rob uses this process to make sure that changes will work in an AD estate with a variety of versions

# %% [markdown]
# First we must check the status of the local source control and ensure that we are in the PR branch

# %%
cd D:\OneDrive\Documents\GitHub\dbachecks
git status
# Out:
# <script type="text/javascript">#!javascript
# if ((typeof(requirejs) !==  typeof(Function)) || (typeof(requirejs.config) !== typeof(Function))) {
#     let script = document.createElement("script");
#     script.setAttribute("src", "https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js");
#     script.onload = function(){
#         loadDotnetInteractiveApi();
#     };
#     document.getElementsByTagName("head")[0].appendChild(script);
# }
# else {
#     loadDotnetInteractiveApi();
# }
#
# function loadDotnetInteractiveApi(){
#     let apiRequire = requirejs.config({context:"dotnet-interactive.18700.62103",paths:{dotnetInteractive:"http://localhost:62103/resources/dotnet-interactive"}});
#     apiRequire(['dotnetInteractive'],
#     function(api) {
#         api.createDotnetInteractiveClient("http://localhost:62103/", window);
#     },
#     function(error){
#         console.log(error);
#     });
# }</script>
# On branch pr/ashdar/752
# Your branch is ahead of 'ashdar/fix_PingComputer' by 66 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %% [markdown]
# First we need to import the module from source control - I normally use verbose to see how it is going

# %%
Import-Module .\dbachecks.psd1
$null = Reset-DbcConfig

# %% [markdown]
# Excellent, that worked. Now to run some checks against a single instance
#
# Maybe all of instance

# %% [markdown]
# I don't care if the test pass or fail, I am only interested in any
#
# > Describe block has Error
#
# or
#
# > Error in Script
#
# type failures

# %%
Invoke-DbcCheck -SqlInstance SQL2017N5 -Check Instance -Show Fails
# Out:
#     ____            __
#    / __ \___  _____/ /____  _____
#   / /_/ / _ \/ ___/ __/ _ \/ ___/
#  / ____/  __(__  ) /_/  __/ /
# /_/    \___/____/\__/\___/_/
# Pester v4.9.0
# Executing all tests in 'D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1' with Tags Instance
#
# Executing script D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2017N5
#       [-] SQL2017N5 is pingable 749ms
#         Expected $true, but got $false.
#         72:                     $pingable | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 72
#       [-] SQL2017N5 Is PSRemoteable 14ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing SQL Engine Service
#
#     Context Testing SQL Engine Service on SQL2017N5
#
#   Describing TempDB Configuration
#
#     Context Testing TempDB Configuration on SQL2017N5
#       [!] should have TF1118 enabled on SQL2017N5, is skipped 0ms
#       [-] should not have TempDB Files on the C Drive on SQL2017N5 12ms
#         Expected $false, because You do not want the tempdb files on the same drive as the operating system, but got $true.
#         149:                     $TempDBTest[3].CurrentSetting | Should -Be $TempDBTest[3].Recommended -Because 'You do not want the tempdb files on the same drive as the operating system'
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 149
#
#   Describing Ad Hoc Workload Optimization
#
#     Context Testing Ad Hoc Workload Optimization on SQL2017N5
#       [-] SQL2017N5 Should be Optimize for Ad Hoc workloads 42ms
#         Expected 1, because optimize for ad hoc workloads is a recommended setting, but got 0.
#         173:                         $psitem.CurrentOptimizeAdHoc | Should -Be $psitem.RecommendedOptimizeAdHoc -Because "optimize for ad hoc workloads is a recommended setting"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 173
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 172
#
#   Describing Backup Path Access
#
#     Context Testing Backup Path Access on SQL2017N5
#
#   Describing Default File Path
#
#     Context Testing Default Data File Path on SQL2017N5
#       [-] Default Data File Path on SQL2017N5 165ms
#         Expected 'C' to be different from the actual value, because Default Data file path should not be your C:\ drive, but got the same value.
#         213:                     $diskFile.Value.substring(0, 1) | Should -Not -Be "C" -Because 'Default Data file path should not be your C:\ drive'
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 213
#
#     Context Testing Default Log File Path on SQL2017N5
#       [-] Default Log File Path on SQL2017N5 176ms
#         Expected 'C' to be different from the actual value, because Default Log file path should not be your C:\ drive, but got the same value.
#         219:                     $diskLog.Value.substring(0, 1) | Should -Not -Be "C" -Because 'Default Log file path should not be your C:\ drive'
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 219
#
#   Describing Dedicated Administrator Connection
#
#     Context Testing Dedicated Administrator Connection on SQL2017N5
#       [-] DAC is set to True on SQL2017N5 79ms
#         Expected $true, because This is the setting that you have chosen for DAC connections, but got $false.
#         237:                     (Get-DbaSpConfigure -SqlInstance $psitem -ConfigName 'RemoteDACConnectionsEnabled').ConfiguredValue -eq 1 | Should -Be $dac -Because 'This is the setting that you have chosen for DAC connections'
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 237
#
#   Describing Network Latency
#
#     Context Testing Network Latency on SQL2017N5
#
#   Describing Linked Servers
#
#     Context Testing Linked Servers on SQL2017N5
#
#   Describing Max Memory
#
#     Context Testing Max Memory on SQL2017N5
#
#   Describing Orphaned Files
#
#     Context Checking for orphaned database files on SQL2017N5
#
#   Describing SQL and Windows names match
#
#     Context Testing instance name matches Windows name for SQL2017N5
#
#   Describing SQL Memory Dumps
#
#     Context Checking that dumps on SQL2017N5 do not exceed 1 for SQL2017N5
#
#   Describing Supported Build
#
#     Context Checking that build is still supported by Microsoft for SQL2017N5
#
#   Describing SA Login Renamed
#
#     Context Checking that sa login has been renamed on SQL2017N5
#       [-] sa login has been renamed on SQL2017N5 14ms
#         Expected $null, because Renaming the sa account is a requirement, but got [sa].
#         413:                     $results | Should -Be $null -Because 'Renaming the sa account is a requirement'
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 413
#
#   Describing SA Login Disabled
#
#     Context Checking that sa login has been disabled on SQL2017N5
#       [!] sa login is disabled on SQL2017N5, is skipped 0ms
#
#   Describing Login SA cannot exist
#
#     Context Checking that a login named sa does not exist on SQL2017N5
#       [!] sa login does not exist on SQL2017N5, is skipped 0ms
#
#   Describing Default Backup Compression
#
#     Context Testing Default Backup Compression on SQL2017N5
#       [-] Default Backup Compression is set to True on SQL2017N5 34ms
#         Expected $true, because The default backup compression should be set correctly, but got $false.
#         858:     (Get-DbaSpConfigure -SqlInstance $Instance -ConfigName 'DefaultBackupCompression').ConfiguredValue -eq 1 | Should -Be $defaultbackupcompression -Because 'The default backup compression should be set correctly'
#         at Assert-BackupCompression, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Instance.Assertions.ps1: line 858
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 466
#
#   Describing XE Sessions That should be Stopped
# WARNING: You need to use Set-DbcConfig -Name policy.xevent.requiredstoppedsession -Value to add some Extended Events session names to run this check
#
#   Describing XE Sessions That should be Running
# WARNING: You need to use Set-DbcConfig -Name policy.xevent.requiredrunningsession -Value to add some Extended Events session names to run this check
#
#   Describing XE Sessions That Are Allowed to Be Running
# WARNING: You need to use Set-DbcConfig -Name policy.xevent.validrunningsession -Value to add some Extended Events session names to run this check
#
#   Describing OLE Automation
#
#     Context Testing OLE Automation on SQL2017N5
#
#   Describing sp_whoisactive is Installed
#
#     Context Testing WhoIsActive exists on SQL2017N5
#
#   Describing Model Database Growth
#
#     Context Testing model database growth setting is not default on SQL2017N5
#
#   Describing Ad Users and Groups
#
#     Context Testing Active Directory users on SQL2017N5
#
#     Context Testing Active Directory groups on SQL2017N5
#
#   Describing Error Log Entries
#
#     Context Checking error log on SQL2017N5
#
#   Describing Error Log Count
#
#     Context Checking error log count on SQL2017N5
#
#   Describing Instance MaxDop
#
#     Context Testing Instance MaxDop Value on SQL2017N5
#
#   Describing Two Digit Year Cutoff
#
#     Context Testing Two Digit Year Cutoff on SQL2017N5
#
#   Describing Trace Flags Expected
#
#     Context Testing Expected Trace Flags on SQL2017N5
#
#   Describing Trace Flags Not Expected
#
#     Context Testing Not Expected Trace Flags on SQL2017N5
#
#   Describing CLR Enabled
#
#     Context Testing CLR Enabled on SQL2017N5
#       [-] CLR Enabled is set to False on SQL2017N5 63ms
#         Expected $false, because The CLR Enabled should be set correctly, but got $true.
#         942:     (Get-DbaSpConfigure -SqlInstance $SQLInstance -Name IsSqlClrEnabled).ConfiguredValue -eq 1 | Should -Be $CLREnabled -Because 'The CLR Enabled should be set correctly'
#         at Assert-CLREnabled, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Instance.Assertions.ps1: line 942
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 804
#
#   Describing Cross Database Ownership Chaining
#
#     Context Testing Cross Database Ownership Chaining on SQL2017N5
#
#   Describing Ad Hoc Distributed Queries
#
#     Context Testing Ad Hoc Distributed Queries on SQL2017N5
#
#   Describing XP CmdShell
#
#     Context Testing XP CmdShell on SQL2017N5
#
#   Describing Scan For Startup Procedures
#
#     Context Testing Scan For Startup Procedures on SQL2017N5
#       [-] Scan For Startup Procedures should be disabled on SQL2017N5 6ms
#         Expected 0, because We expected the scan for startup procedures to be disabled, but got 1.
#         827:     $AllInstanceInfo.ScanForStartupProceduresDisabled.ConfiguredValue | Should -Be 0 -Because "We expected the scan for startup procedures to be disabled"
#         at Assert-ScanForStartupProcedures, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Instance.Assertions.ps1: line 827
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 872
#
#   Describing Default Trace
#
#     Context Checking Default Trace on SQL2017N5
#
#   Describing OLE Automation Procedures Disabled
#
#     Context Checking OLE Automation Procedures on SQL2017N5
#
#   Describing Remote Access Disabled
#
#     Context Testing Remote Access on SQL2017N5
#       [-] The Remote Access should be disabled on SQL2017N5 5ms
#         Expected 0, because We expected Remote Access to be disabled, but got 1.
#         836:     $AllInstanceInfo.RemoteAccess.ConfiguredValue | Should -Be 0 -Because "We expected Remote Access to be disabled"
#         at Assert-RemoteAccess, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Instance.Assertions.ps1: line 836
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 923
#
#   Describing Latest Build
#
#     Context Testing Latest Build on SQL2017N5
#       [-] The Latest Build of SQL should be installed on SQL2017N5 9ms
#         Expected $true, because We expected the SQL Server to be on the newest SQL Server Packs/CUs, but got $false.
#         979:     $AllInstanceInfo.LatestBuild.Compliant | Should -Be $true -Because "We expected the SQL Server to be on the newest SQL Server Packs/CUs"
#         at Assert-LatestBuild, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Instance.Assertions.ps1: line 979
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 941
#
#   Describing Login BUILTIN Administrators cannot exist
#
#     Context Checking that a login named BUILTIN\Administrators does not exist on SQL2017N5
#       [!] BUILTIN\Administrators login does not exist on SQL2017N5, is skipped 0ms
#
#   Describing Local Windows Groups Not Have SQL Logins
#
#     Context Checking that local Windows groups do not have SQL Logins on SQL2017N5
#       [!] Local Windows groups should not SQL Logins on SQL2017N5, is skipped 0ms
#
#   Describing Failed Login Auditing
#
#     Context Testing if failed login auditing is in place on SQL2017N5
#       [!] The failed login auditing should be set on SQL2017N5, is skipped 0ms
#
#   Describing Successful Login Auditing
#
#     Context Testing if successful and failed login auditing is in place on SQL2017N5
#       [!] The successful and failed auditing should be set on SQL2017N5, is skipped 0ms
#
#   Describing SqlAgentProxiesNoPublicRole
#
#     Context Testing to see if the public role has access to the SQL Agent proxies on SQL2017N5
#       [!] The public role should not have access to the SQL Agent Proxies on SQL2017N5, is skipped 0ms
#
#   Describing Hide Instance
#
#     Context Checking the Hide an Instance of SQL Server Database Engine property on SQL2017N5
#       [!] The Hide an Instance of SQL Server Database Engine property on SQL Server instance SQL2017N5, is skipped 0ms
#
#   Describing SQL Engine Service Admin
#
#     Context Testing whether SQL Engine account is a local administrator on SQL2017N5
#       [!] The SQL Engine service account should not be a local administrator on SQL2017N5, is skipped 0ms
#
#   Describing SQL Agent Service Admin
#
#     Context Testing whether SQL Agent account is a local administrator on SQL2017N5
#       [!] The SQL Agent service account should not be a local administrator on SQL2017N5, is skipped 0ms
#
#   Describing SQL Full Text Service Admin
#
#     Context Testing whether SQL Full Text account is a local administrator on  SQL2017N5
#       [!] The SQL Full Text service account should not be a local administrator on SQL2017N5, is skipped 0ms
#
#   Describing Login Check Policy
#
#     Context Testing if the CHECK_POLICY is enabled on all logins on SQL2017N5
#       [!] All logins should have the CHECK_POLICY option set to ON on SQL2017N5, is skipped 0ms
#
#   Describing Login Password Expiration
#
#     Context Testing if the login password expiration is enabled for sql logins in the sysadmin role on SQL2017N5
#       [!] All sql logins should have the password expiration option set to ON in the sysadmin role on SQL2017N5, is skipped 0ms
#
#   Describing Login Must Change
#
#     Context Testing if the new SQL logins that have not logged have to change their password when they log in on SQL2017N5
#       [!] All new sql logins should have the have to change their password when they log in for the first time on SQL2017N5, is skipped 0ms
#
#   Describing SQL Browser Service
# WARNING: [10:54:36][Get-ComputerName] You must specify -ComputerName or use Set-DbcConfig app.computername to setup a list of servers
# Tests completed in 15.69s
# Tests Passed: 60, Failed: 13, Skipped: 15, Pending: 0, Inconclusive: 0

# %%
Invoke-DbcCheck -SqlInstance SQL2017N5 -Check Database -Show Fails
# Out:
#     ____            __
#    / __ \___  _____/ /____  _____
#   / /_/ / _ \/ ___/ __/ _ \/ ___/
#  / ____/  __(__  ) /_/  __/ /
# /_/    \___/____/\__/\___/_/
# Pester v4.9.0
# Executing all tests in 'D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1', 'D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1' with Tags Database
#
# Executing script D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1
#
# Executing script D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1
#
#   Describing Database Collation
#
#     Context Testing database collation on SQL2017N5
#       [-] database collation (Latin1_General_CI_AS) should match server collation (SQL_Latin1_General_CP1_CI_AS) for SqlWatch on SQL2017N5 13ms
#         Expected strings to be the same, because You will get collation conflict errors in tempdb, but they were different.
#         Expected length: 20
#         Actual length:   28
#         Strings differ at index 0.
#         Expected: 'Latin1_General_CI_AS'
#         But was:  'SQL_Latin1_General_CP1_CI_AS'
#         47:                         $psitem.ServerCollation | Should -Be $psitem.DatabaseCollation -Because "You will get collation conflict errors in tempdb"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 47
#
#   Describing Suspect Page
#
#     Context Testing suspect pages on SQL2017N5
#
#   Describing Last Backup Restore Test
#
#   Describing Last Backup VerifyOnly
#
#     Context VerifyOnly tests of last backups on SQL2017N5
#   Describing Valid Database Owner
#
#     Context Testing Database Owners on SQL2017N5
#       [-] Database ADonutFactory - owner THEBEARD\Rob should be in this list ( sa ) on SQL2017N5 10ms
#         Expected collection sa to contain 'THEBEARD\Rob', because The account that is the database owner is not what was expected, but it was not found.
#         154:                         $psitem.Owner | Should -BeIn $TargetOwner -Because "The account that is the database owner is not what was expected"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 154
#       [-] Database ASausageFactory - owner THEBEARD\Rob should be in this list ( sa ) on SQL2017N5 4ms
#         Expected collection sa to contain 'THEBEARD\Rob', because The account that is the database owner is not what was expected, but it was not found.
#         154:                         $psitem.Owner | Should -BeIn $TargetOwner -Because "The account that is the database owner is not what was expected"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 154
#       [-] Database ASockFactory - owner THEBEARD\Rob should be in this list ( sa ) on SQL2017N5 4ms
#         Expected collection sa to contain 'THEBEARD\Rob', because The account that is the database owner is not what was expected, but it was not found.
#         154:                         $psitem.Owner | Should -BeIn $TargetOwner -Because "The account that is the database owner is not what was expected"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 154
#       [-] Database SqlWatch - owner THEBEARD\Rob should be in this list ( sa ) on SQL2017N5 5ms
#         Expected collection sa to contain 'THEBEARD\Rob', because The account that is the database owner is not what was expected, but it was not found.
#         154:                         $psitem.Owner | Should -BeIn $TargetOwner -Because "The account that is the database owner is not what was expected"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 154
#       [-] Database SSISDB - owner THEBEARD\Rob should be in this list ( sa ) on SQL2017N5 4ms
#         Expected collection sa to contain 'THEBEARD\Rob', because The account that is the database owner is not what was expected, but it was not found.
#         154:                         $psitem.Owner | Should -BeIn $TargetOwner -Because "The account that is the database owner is not what was expected"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 154
#
#   Describing Invalid Database Owner
#
#     Context Testing Database Owners on SQL2017N5
#
#   Describing Last Good DBCC CHECKDB
#
#     Context Testing Last Good DBCC CHECKDB on SQL2017N5
#       [-] last good integrity check for SqlWatch on SQL2017N5 should be less than 7 days old 4ms
#         Expected the actual value to be greater than 2020-03-22T09:55:08.0118871Z, because You should have run a DBCC CheckDB inside that time, but got 2020-01-14T16:47:37.5200000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 200
#       [-] last good integrity check for SSISDB on SQL2017N5 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-03-22T09:55:08.0229928Z, because You should have run a DBCC CheckDB inside that time, but got $null.
#         203:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 203
#       [-] last good integrity check for ASockFactory on SQL2017N5 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-03-22T09:55:08.0346164Z, because You should have run a DBCC CheckDB inside that time, but got $null.
#         203:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 203
#       [-] last good integrity check for ASausageFactory on SQL2017N5 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-03-22T09:55:08.0446133Z, because You should have run a DBCC CheckDB inside that time, but got $null.
#         203:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 203
#       [-] last good integrity check for ADonutFactory on SQL2017N5 should be less than 7 days old 3ms
#         Expected the actual value to be greater than 2020-03-22T09:55:08.0545992Z, because You should have run a DBCC CheckDB inside that time, but got $null.
#         203:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 203
#
#   Describing Column Identity Usage
#
#     Context Testing Column Identity Usage on SQL2017N5
#
#   Describing Recovery Model
#
#     Context Testing Recovery Model on SQL2017N5
#       [-] msdb should be set to Full on SQL2017N5 3ms
#         Expected 'Full', because You expect this recovery model, but got Simple.
#         262:                         $psitem.RecoveryModel | Should -Be $recoverymodel -Because "You expect this recovery model"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 262
#       [-] SqlWatch should be set to Full on SQL2017N5 4ms
#         Expected 'Full', because You expect this recovery model, but got Simple.
#         262:                         $psitem.RecoveryModel | Should -Be $recoverymodel -Because "You expect this recovery model"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 262
#
#   Describing Duplicate Index
#
#     Context Testing duplicate indexes on SQL2017N5
#
#   Describing Unused Index
#
#     Context Testing Unused indexes on SQL2017N5
#       [!] The SQL Service on SQL2017N5 was restarted on 03/24/2020 11:52:44, which is not long enough for a solid evaluation. on  should return 0 Unused indexes, is skipped 0ms
#
#   Describing Disabled Index
#
#     Context Testing Disabled indexes on SQL2017N5
#
#   Describing Database Growth Event
#
#     Context Testing database growth event on SQL2017N5
#       [-] tempdb should return 0 database growth events on SQL2017N5 3ms
#         Expected 0, because You want to control how your database files are grown, but got 1.
#         357:                         @($results).Count | Should -Be 0 -Because "You want to control how your database files are grown"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 357
#
#   Describing Page Verify
#
#     Context Testing page verify on SQL2017N5
#
#   Describing Auto Close
#
#     Context Testing Auto Close on SQL2017N5
#
#   Describing Auto Shrink
#
#     Context Testing Auto Shrink on SQL2017N5
#
#   Describing Last Full Backup Times
#
#     Context Testing last full backups on SQL2017N5
#       [-] master full backups on SQL2017N5 should be less than 1 days 3ms
#         Expected the actual value to be greater than 2020-03-28T09:55:21.3062817Z, because Taking regular backups is extraordinarily important, but got 2020-03-28T03:45:39.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 463
#       [-] model full backups on SQL2017N5 should be less than 1 days 3ms
#         Expected the actual value to be greater than 2020-03-28T09:55:21.3129976Z, because Taking regular backups is extraordinarily important, but got 2020-03-28T03:45:39.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 463
#       [-] msdb full backups on SQL2017N5 should be less than 1 days 3ms
#         Expected the actual value to be greater than 2020-03-28T09:55:21.3200675Z, because Taking regular backups is extraordinarily important, but got 2020-03-28T03:45:39.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 463
#
#   Describing Last Diff Backup Times
#
#     Context Testing last diff backups on SQL2017N5
#       [-] ADonutFactory diff backups on SQL2017N5 should be less than 25 hours 9ms
#         Expected the actual value to be greater than 2020-03-28T08:55:21.4513933Z, because Taking regular backups is extraordinarily important, but got 2020-03-28T04:00:39.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 487
#       [-] ASausageFactory diff backups on SQL2017N5 should be less than 25 hours 3ms
#         Expected the actual value to be greater than 2020-03-28T08:55:21.4589176Z, because Taking regular backups is extraordinarily important, but got 2020-03-28T04:00:40.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 487
#       [-] ASockFactory diff backups on SQL2017N5 should be less than 25 hours 4ms
#         Expected the actual value to be greater than 2020-03-28T08:55:21.4672844Z, because Taking regular backups is extraordinarily important, but got 2020-03-28T04:00:40.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 487
#       [-] SqlWatch diff backups on SQL2017N5 should be less than 25 hours 4ms
#         Expected the actual value to be greater than 2020-03-28T08:55:21.4765429Z, because Taking regular backups is extraordinarily important, but got 2020-03-28T04:00:44.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 487
#       [-] SSISDB diff backups on SQL2017N5 should be less than 25 hours 4ms
#         Expected the actual value to be greater than 2020-03-28T08:55:21.4856696Z, because Taking regular backups is extraordinarily important, but got 2020-03-28T04:00:46.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 487
#
#   Describing Last Log Backup Times
#
#     Context Testing last log backups on SQL2017N5
#       [-] ADonutFactory log backups on SQL2017N5 should be less than 15 minutes 10ms
#         Expected the actual value to be greater than 2020-03-29T09:41:21.6300786Z, because Taking regular backups is extraordinarily important, but got 2020-03-29T08:55:39.0000000Z.
#         512:                             $psitem.LastLogBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddMinutes( - ($maxlog) + 1) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 512
#       [-] ASausageFactory log backups on SQL2017N5 should be less than 15 minutes 5ms
#         Expected the actual value to be greater than 2020-03-29T09:41:21.6383927Z, because Taking regular backups is extraordinarily important, but got 2020-03-29T08:55:39.0000000Z.
#         512:                             $psitem.LastLogBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddMinutes( - ($maxlog) + 1) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 512
#       [-] ASockFactory log backups on SQL2017N5 should be less than 15 minutes 5ms
#         Expected the actual value to be greater than 2020-03-29T09:41:21.6472844Z, because Taking regular backups is extraordinarily important, but got 2020-03-29T08:55:39.0000000Z.
#         512:                             $psitem.LastLogBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddMinutes( - ($maxlog) + 1) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 512
#       [-] SSISDB log backups on SQL2017N5 should be less than 15 minutes 2ms
#         Expected the actual value to be greater than 2020-03-29T09:41:21.6568628Z, because Taking regular backups is extraordinarily important, but got 2020-03-29T08:55:40.0000000Z.
#         512:                             $psitem.LastLogBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddMinutes( - ($maxlog) + 1) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 512
#
#   Describing Virtual Log Files
#
#     Context Testing Database VLFs on SQL2017N5
#
#   Describing Log File Count Checks
#
#     Context Testing Log File count for SQL2017N5
#
#   Describing Log File Size Checks
#
#     Context Testing Log File size for SQL2017N5
#
#   Describing Future File Growth
#
#     Context Testing for files likely to grow soon on SQL2017N5
#       [-] master file master on SQL2017N5 has free space under threshold 6ms
#         Expected the actual value to be greater than or equal to 20, because free space within the file should be lower than threshold of 20 %, but got 3.488.
#         612:                                 $PSItem.PercentFree | Should -BeGreaterOrEqual $threshold -Because "free space within the file should be lower than threshold of $threshold %"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 612
#       [-] msdb file MSDBData on SQL2017N5 has free space under threshold 3ms
#         Expected the actual value to be greater than or equal to 20, because free space within the file should be lower than threshold of 20 %, but got 5.491.
#         612:                                 $PSItem.PercentFree | Should -BeGreaterOrEqual $threshold -Because "free space within the file should be lower than threshold of $threshold %"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 612
#       [-] SSISDB file data on SQL2017N5 has free space under threshold 2ms
#         Expected the actual value to be greater than or equal to 20, because free space within the file should be lower than threshold of 20 %, but got 2.773.
#         612:                                 $PSItem.PercentFree | Should -BeGreaterOrEqual $threshold -Because "free space within the file should be lower than threshold of $threshold %"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 612
#
#   Describing Correctly sized Filegroup members
#
#     Context Testing for balanced FileGroups on SQL2017N5
#
#   Describing Certificate Expiration
#
#     Context Checking that encryption certificates have not expired on SQL2017N5
#       [-] MS_SQLISSigningCertificate in SSISDB has not expired on SQL2017N5 3ms
#         Expected the actual value to be greater than 2020-03-29T09:55:24.8135484Z, because this certificate should not be expired, but got 2018-08-23T01:39:03.0000000Z.
#         664:                         $psitem.ExpirationDate.ToUniversalTime()  | Should -BeGreaterThan (Get-Date).ToUniversalTime() -Because "this certificate should not be expired"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 664
#       [-] MS_SQLISSigningCertificate in SSISDB does not expire for more than 1 months on SQL2017N5 3ms
#         Expected the actual value to be greater than 2020-04-29T09:55:24.8203051Z, because expires inside the warning window of 1, but got 2018-08-23T01:39:03.0000000Z.
#         667:                         $psitem.ExpirationDate.ToUniversalTime()  | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddMonths($CertificateWarning) -Because "expires inside the warning window of $CertificateWarning"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 667
#
#   Describing Auto Create Statistics
#
#     Context Testing Auto Create Statistics on SQL2017N5
#
#   Describing Auto Update Statistics
#
#     Context Testing Auto Update Statistics on SQL2017N5
#
#   Describing Auto Update Statistics Asynchronously
#
#     Context Testing Auto Update Statistics Asynchronously on SQL2017N5
#
#   Describing Datafile Auto Growth Configuration
#
#     Context Testing datafile growth type on SQL2017N5
#       [-] master on filegroup PRIMARY should have GrowthType set to kb on SQL2017N5 8ms
#         Expected strings to be the same, because We expect a certain file growth type, but they were different.
#         Expected length: 2
#         Actual length:   7
#         Strings differ at index 0.
#         Expected: 'kb'
#         But was:  'Percent'
#         751:                             $psitem.GrowthType | Should -Be $datafilegrowthtype -Because "We expect a certain file growth type"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 751
#       [-] master on filegroup PRIMARY should have Growth set equal or higher than 65535 on SQL2017N5 9ms
#         Expected the actual value to be greater than or equal to 65535, because We expect a certain file growth value, but got 80.
#         755:                                 $psitem.Growth * 8 | Should -BeGreaterOrEqual $datafilegrowthvalue  -because "We expect a certain file growth value"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 755
#       [-] mastlog on filegroup  should have GrowthType set to kb on SQL2017N5 3ms
#         Expected strings to be the same, because We expect a certain file growth type, but they were different.
#         Expected length: 2
#         Actual length:   7
#         Strings differ at index 0.
#         Expected: 'kb'
#         But was:  'Percent'
#         751:                             $psitem.GrowthType | Should -Be $datafilegrowthtype -Because "We expect a certain file growth type"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 751
#       [-] mastlog on filegroup  should have Growth set equal or higher than 65535 on SQL2017N5 3ms
#         Expected the actual value to be greater than or equal to 65535, because We expect a certain file growth value, but got 80.
#         755:                                 $psitem.Growth * 8 | Should -BeGreaterOrEqual $datafilegrowthvalue  -because "We expect a certain file growth value"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 755
#       [-] MSDBData on filegroup PRIMARY should have GrowthType set to kb on SQL2017N5 4ms
#         Expected strings to be the same, because We expect a certain file growth type, but they were different.
#         Expected length: 2
#         Actual length:   7
#         Strings differ at index 0.
#         Expected: 'kb'
#         But was:  'Percent'
#         751:                             $psitem.GrowthType | Should -Be $datafilegrowthtype -Because "We expect a certain file growth type"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 751
#       [-] MSDBData on filegroup PRIMARY should have Growth set equal or higher than 65535 on SQL2017N5 3ms
#         Expected the actual value to be greater than or equal to 65535, because We expect a certain file growth value, but got 80.
#         755:                                 $psitem.Growth * 8 | Should -BeGreaterOrEqual $datafilegrowthvalue  -because "We expect a certain file growth value"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 755
#       [-] MSDBLog on filegroup  should have GrowthType set to kb on SQL2017N5 5ms
#         Expected strings to be the same, because We expect a certain file growth type, but they were different.
#         Expected length: 2
#         Actual length:   7
#         Strings differ at index 0.
#         Expected: 'kb'
#         But was:  'Percent'
#         751:                             $psitem.GrowthType | Should -Be $datafilegrowthtype -Because "We expect a certain file growth type"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 751
#       [-] MSDBLog on filegroup  should have Growth set equal or higher than 65535 on SQL2017N5 4ms
#         Expected the actual value to be greater than or equal to 65535, because We expect a certain file growth value, but got 80.
#         755:                                 $psitem.Growth * 8 | Should -BeGreaterOrEqual $datafilegrowthvalue  -because "We expect a certain file growth value"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 755
#       [-] data on filegroup PRIMARY should have GrowthType set to kb on SQL2017N5 3ms
#         Expected strings to be the same, because We expect a certain file growth type, but they were different.
#         Expected length: 2
#         Actual length:   7
#         Strings differ at index 0.
#         Expected: 'kb'
#         But was:  'Percent'
#         751:                             $psitem.GrowthType | Should -Be $datafilegrowthtype -Because "We expect a certain file growth type"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 751
#       [-] data on filegroup PRIMARY should have Growth set equal or higher than 65535 on SQL2017N5 3ms
#         Expected the actual value to be greater than or equal to 65535, because We expect a certain file growth value, but got 80.
#         755:                                 $psitem.Growth * 8 | Should -BeGreaterOrEqual $datafilegrowthvalue  -because "We expect a certain file growth value"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 755
#       [-] log on filegroup  should have GrowthType set to kb on SQL2017N5 3ms
#         Expected strings to be the same, because We expect a certain file growth type, but they were different.
#         Expected length: 2
#         Actual length:   7
#         Strings differ at index 0.
#         Expected: 'kb'
#         But was:  'Percent'
#         751:                             $psitem.GrowthType | Should -Be $datafilegrowthtype -Because "We expect a certain file growth type"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 751
#       [-] log on filegroup  should have Growth set equal or higher than 65535 on SQL2017N5 3ms
#         Expected the actual value to be greater than or equal to 65535, because We expect a certain file growth value, but got 80.
#         755:                                 $psitem.Growth * 8 | Should -BeGreaterOrEqual $datafilegrowthvalue  -because "We expect a certain file growth value"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 755
#
#   Describing Trustworthy Option
#
#     Context Testing database trustworthy option on SQL2017N5
#
#   Describing Database Orphaned User
#
#     Context Testing database orphaned user event on SQL2017N5
#
#   Describing PseudoSimple Recovery Model
#
#     Context Testing database is not in PseudoSimple recovery model on SQL2017N5
#
#   Describing Compatibility Level
#
#     Context Testing database compatibility level matches server compatibility level on SQL2017N5
#
#   Describing Foreign keys and check constraints not trusted
#
#     Context Testing Foreign Keys and Check Constraints are not trusted SQL2017N5
#       [-] fk_sqlwatch_logger_agent_job_history_job foreign key on table [dbo].[sqlwatch_logger_agent_job_history] within database SqlWatch should be trusted on SQL2017N5. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_logger_agent_job_history_snapshot_header foreign key on table [dbo].[sqlwatch_logger_agent_job_history] within database SqlWatch should be trusted on SQL2017N5. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] FK_logger_disk_util_database_database foreign key on table [dbo].[sqlwatch_logger_disk_utilisation_database] within database SqlWatch should be trusted on SQL2017N5. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] FK_logger_disk_util_database_snapshot foreign key on table [dbo].[sqlwatch_logger_disk_utilisation_database] within database SqlWatch should be trusted on SQL2017N5. 2ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] FK_disk_util_vol_snapshot_header foreign key on table [dbo].[sqlwatch_logger_disk_utilisation_volume] within database SqlWatch should be trusted on SQL2017N5. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_logger_disk_utilisation_volume_id foreign key on table [dbo].[sqlwatch_logger_disk_utilisation_volume] within database SqlWatch should be trusted on SQL2017N5. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_logger_missing_indexes_snapshot_header foreign key on table [dbo].[sqlwatch_logger_index_missing_stats] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_logger_index_missing_stats_index_detail foreign key on table [dbo].[sqlwatch_logger_index_missing_stats] within database SqlWatch should be trusted on SQL2017N5. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_index_usage_stats_header foreign key on table [dbo].[sqlwatch_logger_index_usage_stats] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_logger_index_usage_stats_index foreign key on table [dbo].[sqlwatch_logger_index_usage_stats] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_logger_index_stats_histogram foreign key on table [dbo].[sqlwatch_logger_index_usage_stats_histogram] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] pk_sqlwatch_logger_index_usage_stats_histogram_index foreign key on table [dbo].[sqlwatch_logger_index_usage_stats_histogram] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sql_perf_mon_file_stats_snapshot_header foreign key on table [dbo].[sqlwatch_logger_perf_file_stats] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_logger_perf_file_stats_master_file foreign key on table [dbo].[sqlwatch_logger_perf_file_stats] within database SqlWatch should be trusted on SQL2017N5. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sql_perf_mon_os_memory_clerks_snapshot_header foreign key on table [dbo].[sqlwatch_logger_perf_os_memory_clerks] within database SqlWatch should be trusted on SQL2017N5. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_logger_perf_os_memory_clerks_meta foreign key on table [dbo].[sqlwatch_logger_perf_os_memory_clerks] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sql_perf_mon_perf_counters_snapshot_header foreign key on table [dbo].[sqlwatch_logger_perf_os_performance_counters] within database SqlWatch should be trusted on SQL2017N5. 2ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_logger_perf_os_performance_counters_meta foreign key on table [dbo].[sqlwatch_logger_perf_os_performance_counters] within database SqlWatch should be trusted on SQL2017N5. 2ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sql_perf_mon_os_process_memory_snapshot_header foreign key on table [dbo].[sqlwatch_logger_perf_os_process_memory] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_logger_perf_os_process_memory_server foreign key on table [dbo].[sqlwatch_logger_perf_os_process_memory] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_logger_perf_os_schedulers foreign key on table [dbo].[sqlwatch_logger_perf_os_schedulers] within database SqlWatch should be trusted on SQL2017N5. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_logger_perf_os_schedulers_server foreign key on table [dbo].[sqlwatch_logger_perf_os_schedulers] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sql_perf_mon_wait_stats_snapshot_header foreign key on table [dbo].[sqlwatch_logger_perf_os_wait_stats] within database SqlWatch should be trusted on SQL2017N5. 5ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_logger_perf_os_wait_stats_wait_type_id foreign key on table [dbo].[sqlwatch_logger_perf_os_wait_stats] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] FK__sqlwatch___snaps__5CA1C101 foreign key on table [dbo].[sqlwatch_logger_snapshot_header] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sql_perf_mon_who_is_active_snapshot_header foreign key on table [dbo].[sqlwatch_logger_whoisactive] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_logger_whoisactive_server foreign key on table [dbo].[sqlwatch_logger_whoisactive] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_logger_perf_xes_blockers foreign key on table [dbo].[sqlwatch_logger_xes_blockers] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
# ...
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_logger_xes_long_queries_server foreign key on table [dbo].[sqlwatch_logger_xes_long_queries] within database SqlWatch should be trusted on SQL2017N5. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_logger_xe_query_processing_snapshot_header foreign key on table [dbo].[sqlwatch_logger_xes_query_processing] within database SqlWatch should be trusted on SQL2017N5. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_logger_xes_query_processing_server foreign key on table [dbo].[sqlwatch_logger_xes_query_processing] within database SqlWatch should be trusted on SQL2017N5. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_logger_xes_waits_snapshot_header foreign key on table [dbo].[sqlwatch_logger_xes_waits_stats] within database SqlWatch should be trusted on SQL2017N5. 11ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_logger_xes_waits_stats_server foreign key on table [dbo].[sqlwatch_logger_xes_waits_stats] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_meta_agent_job_server foreign key on table [dbo].[sqlwatch_meta_agent_job] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_meta_agent_job_id foreign key on table [dbo].[sqlwatch_meta_agent_job_step] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_meta_database_server foreign key on table [dbo].[sqlwatch_meta_database] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_meta_index foreign key on table [dbo].[sqlwatch_meta_index] within database SqlWatch should be trusted on SQL2017N5. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_meta_index_missing_table foreign key on table [dbo].[sqlwatch_meta_index_missing] within database SqlWatch should be trusted on SQL2017N5. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] FK_sql_perf_mon_master_files_db foreign key on table [dbo].[sqlwatch_meta_master_file] within database SqlWatch should be trusted on SQL2017N5. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_meta_memory_clerk_server foreign key on table [dbo].[sqlwatch_meta_memory_clerk] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_meta_os_volume_server foreign key on table [dbo].[sqlwatch_meta_os_volume] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_meta_performance_counter_server foreign key on table [dbo].[sqlwatch_meta_performance_counter] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_meta_table_database foreign key on table [dbo].[sqlwatch_meta_table] within database SqlWatch should be trusted on SQL2017N5. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#       [-] fk_sqlwatch_meta_wait_stats_server foreign key on table [dbo].[sqlwatch_meta_wait_stats] within database SqlWatch should be trusted on SQL2017N5. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 858
#
#   Describing Database MaxDop
#
#     Context Database MaxDop setting is correct on SQL2017N5
#
#   Describing Database Status
#
#     Context Database status is correct on SQL2017N5
#
#   Describing Database Exists
#
#     Context Database exists on SQL2017N5
#
#   Describing Contained Database Auto Close
#
#     Context Testing contained database auto close option on SQL2017N5
#
#   Describing CLR Assemblies SAFE_ACCESS
#
#     Context Testing that all user-defined CLR assemblies are set to SAFE_ACCESS on SQL2017N5
#       [-] master on SQL2017N5 user-defined CLR assemblies are set to SAFE_ACCESS 76ms
#         Expected 0, because Symmetric keys should have a key length greater than or equal to 2048, but got 1.
#         89:     @(Get-DbaDbEncryption -SqlInstance $Instance -Database $Database | Where-Object {$_.Encryption -eq "Symmetric Key" -and $_.KeyLength -LT 2048}).Count | Should -Be 0 -Because "Symmetric keys should have a key length greater than or equal to 2048"
#         at Assert-CLRAssembliesSafe, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Database.Assertions.ps1: line 89
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 974
#       [-] SSISDB on SQL2017N5 user-defined CLR assemblies are set to SAFE_ACCESS 79ms
#         Expected 0, because Symmetric keys should have a key length greater than or equal to 2048, but got 4.
#         89:     @(Get-DbaDbEncryption -SqlInstance $Instance -Database $Database | Where-Object {$_.Encryption -eq "Symmetric Key" -and $_.KeyLength -LT 2048}).Count | Should -Be 0 -Because "Symmetric keys should have a key length greater than or equal to 2048"
#         at Assert-CLRAssembliesSafe, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Database.Assertions.ps1: line 89
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Database.Tests.ps1: line 974
#
#   Describing Guest User
#
#     Context Testing Guest user has CONNECT permission on SQL2017N5
#       [!] Guest user should return no CONNECT permissions in ADonutFactory on SQL2017N5, is skipped 0ms
#       [!] Guest user should return no CONNECT permissions in ASausageFactory on SQL2017N5, is skipped 0ms
#       [!] Guest user should return no CONNECT permissions in ASockFactory on SQL2017N5, is skipped 0ms
#       [!] Guest user should return no CONNECT permissions in model on SQL2017N5, is skipped 0ms
#       [!] Guest user should return no CONNECT permissions in SqlWatch on SQL2017N5, is skipped 0ms
#       [!] Guest user should return no CONNECT permissions in SSISDB on SQL2017N5, is skipped 0ms
#
#   Describing AsymmetricKeySize
#
#     Context Testing Asymmetric Key Size is 2048 or higher on SQL2017N5
#       [!] ADonutFactory on SQL2017N5 Asymmetric Key Size should be at least 2048, is skipped 0ms
#       [!] ASausageFactory on SQL2017N5 Asymmetric Key Size should be at least 2048, is skipped 0ms
#       [!] ASockFactory on SQL2017N5 Asymmetric Key Size should be at least 2048, is skipped 0ms
#       [!] model on SQL2017N5 Asymmetric Key Size should be at least 2048, is skipped 0ms
#       [!] SqlWatch on SQL2017N5 Asymmetric Key Size should be at least 2048, is skipped 0ms
#       [!] SSISDB on SQL2017N5 Asymmetric Key Size should be at least 2048, is skipped 0ms
#
#   Describing SymmetricKeyEncryptionLevel
#
#     Context Testing Symmetric Key Encruption Level at least AES_128 or higher on SQL2017N5
#       [!] ADonutFactory on SQL2017N5 Symmetric Key Encryption Level should have AES_128 or higher, is skipped 0ms
#       [!] ASausageFactory on SQL2017N5 Symmetric Key Encryption Level should have AES_128 or higher, is skipped 0ms
#       [!] ASockFactory on SQL2017N5 Symmetric Key Encryption Level should have AES_128 or higher, is skipped 0ms
#       [!] model on SQL2017N5 Symmetric Key Encryption Level should have AES_128 or higher, is skipped 0ms
#       [!] SqlWatch on SQL2017N5 Symmetric Key Encryption Level should have AES_128 or higher, is skipped 0ms
#       [!] SSISDB on SQL2017N5 Symmetric Key Encryption Level should have AES_128 or higher, is skipped 0ms
# Tests completed in 40.88s
# Tests Passed: 522, Failed: 93, Skipped: 19, Pending: 0, Inconclusive: 0

# %%
Invoke-DbcCheck -SqlInstance SQL2017N5 -Check Agent -Show Fails
# Out:
#     ____            __
#    / __ \___  _____/ /____  _____
#   / /_/ / _ \/ ___/ __/ _ \/ ___/
#  / ____/  __(__  ) /_/  __/ /
# /_/    \___/____/\__/\___/_/
# Pester v4.9.0
# Executing all tests in 'D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1', 'D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1' with Tags Agent
#
# Executing script D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1
#
#   Describing Database Mail XPs
#
#     Context Testing Testing Database Mail XPs  on SQL2017N5
#       [-] Testing Database Mail XPs is set to False on SQL2017N5 65ms
#         Expected $false, because The Database Mail XPs setting should be set correctly, but got $true.
#         6:    (Get-DbaSpConfigure -SqlInstance $SQLInstance -Name DatabaseMailEnabled).ConfiguredValue -eq 1 | Should -Be $DatabaseMailEnabled -Because 'The Database Mail XPs setting should be set correctly'
#         at Assert-DatabaseMailEnabled, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Agent.Assertions.ps1: line 6
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 34
#
#   Describing SQL Agent Account
#
#     Context Testing SQL Agent is running on SQL2017N5
#
#   Describing DBA Operators
#
#     Context Testing DBA Operators exists on SQL2017N5
#
#   Describing Failsafe Operator
#
#     Context Testing failsafe operator exists on SQL2017N5
#       [-] failsafe operator on SQL2017N5 exists 67ms
#         Expected $null, because The failsafe operator will ensure that any job failures will be notified to someone if not set explicitly, but got <empty>.
#         118:                                 (Connect-DbaInstance -SqlInstance $psitem).JobServer.AlertSystem.FailSafeOperator | Should -Be $failsafeoperator -Because 'The failsafe operator will ensure that any job failures will be notified to someone if not set explicitly'
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 118
#
#   Describing Database Mail Profile
#
#     Context Testing database mail profile is set on SQL2017N5
#       [-] database mail profile on SQL2017N5 is  66ms
#         Expected $null, because The database mail profile is required to send emails, but got 'DBaMail'.
#         136:                                 (Get-DbaDbMailProfile -SqlInstance $InstanceSMO).Name | Should -Be $databasemailprofile -Because 'The database mail profile is required to send emails'
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 136
#
#   Describing Failed Jobs
#
#     Context Checking for failed enabled jobs since 02/28/2020 10:55:43 on SQL2017N5
#       [-] Gather SQLWatch Data's last run outcome on SQL2017N5 is Failed 3ms
#         Expected 'Succeeded', because All Agent Jobs should have succeed - you need to investigate the failed jobs, but got Failed.
#         169:                                         $psitem.LastRunOutcome | Should -Be "Succeeded" -Because 'All Agent Jobs should have succeed - you need to investigate the failed jobs'
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 169
#
#   Describing Valid Job Owner
#
#     Context Testing job owners on SQL2017N5
#       [-] Job Gather SQLWatch Data  - owner THEBEARD\Rob should be in this list ( sa ) on SQL2017N5 3ms
#         Expected collection sa to contain 'THEBEARD\Rob', because The account that is the job owner is not what was expected, but it was not found.
#         191:                                     $psitem.OwnerLoginName | Should -BeIn $TargetOwner -Because "The account that is the job owner is not what was expected"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 191
#       [-] Job SQLWATCH-INTERNAL-META-CONFIG  - owner THEBEARD\Rob should be in this list ( sa ) on SQL2017N5 4ms
#         Expected collection sa to contain 'THEBEARD\Rob', because The account that is the job owner is not what was expected, but it was not found.
#         191:                                     $psitem.OwnerLoginName | Should -BeIn $TargetOwner -Because "The account that is the job owner is not what was expected"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 191
#       [-] Job SQLWATCH-INTERNAL-RETENTION  - owner THEBEARD\Rob should be in this list ( sa ) on SQL2017N5 4ms
#         Expected collection sa to contain 'THEBEARD\Rob', because The account that is the job owner is not what was expected, but it was not found.
#         191:                                     $psitem.OwnerLoginName | Should -BeIn $TargetOwner -Because "The account that is the job owner is not what was expected"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 191
#       [-] Job SQLWATCH-LOGGER-AGENT-HISTORY  - owner THEBEARD\Rob should be in this list ( sa ) on SQL2017N5 2ms
#         Expected collection sa to contain 'THEBEARD\Rob', because The account that is the job owner is not what was expected, but it was not found.
#         191:                                     $psitem.OwnerLoginName | Should -BeIn $TargetOwner -Because "The account that is the job owner is not what was expected"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 191
#       [-] Job SQLWATCH-LOGGER-DISK-UTILISATION  - owner THEBEARD\Rob should be in this list ( sa ) on SQL2017N5 3ms
#         Expected collection sa to contain 'THEBEARD\Rob', because The account that is the job owner is not what was expected, but it was not found.
#         191:                                     $psitem.OwnerLoginName | Should -BeIn $TargetOwner -Because "The account that is the job owner is not what was expected"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 191
#       [-] Job SQLWATCH-LOGGER-INDEXES  - owner THEBEARD\Rob should be in this list ( sa ) on SQL2017N5 3ms
#         Expected collection sa to contain 'THEBEARD\Rob', because The account that is the job owner is not what was expected, but it was not found.
#         191:                                     $psitem.OwnerLoginName | Should -BeIn $TargetOwner -Because "The account that is the job owner is not what was expected"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 191
#       [-] Job SQLWATCH-LOGGER-PERFORMANCE  - owner THEBEARD\Rob should be in this list ( sa ) on SQL2017N5 3ms
#         Expected collection sa to contain 'THEBEARD\Rob', because The account that is the job owner is not what was expected, but it was not found.
#         191:                                     $psitem.OwnerLoginName | Should -BeIn $TargetOwner -Because "The account that is the job owner is not what was expected"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 191
#       [-] Job SQLWATCH-LOGGER-WHOISACTIVE  - owner THEBEARD\Rob should be in this list ( sa ) on SQL2017N5 3ms
#         Expected collection sa to contain 'THEBEARD\Rob', because The account that is the job owner is not what was expected, but it was not found.
#         191:                                     $psitem.OwnerLoginName | Should -BeIn $TargetOwner -Because "The account that is the job owner is not what was expected"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 191
#       [-] Job SSIS Server Maintenance Job  - owner ##MS_SSISServerCleanupJobLogin## should be in this list ( sa ) on SQL2017N5 2ms
#         Expected collection sa to contain '##MS_SSISServerCleanupJobLogin##', because The account that is the job owner is not what was expected, but it was not found.
#         191:                                     $psitem.OwnerLoginName | Should -BeIn $TargetOwner -Because "The account that is the job owner is not what was expected"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 191
#
#   Describing Agent Alerts
#
#     Context Testing Agent Alerts Severity exists on SQL2017N5
#       [-] SQL2017N5 should have Severity 16 Alert 8ms
#         Expected $true, because Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/, but got $null.
#         221:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 221
#       [-] SQL2017N5 should have Severity 16 Alert enabled 9ms
#         Expected $true, because Configured alerts should be enabled, but got $null.
#         224:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Configured alerts should be enabled"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 224
#       [-] SQL2017N5 should have notification for Severity 16 Alert 12ms
#         Expected $true, because Should notify by Agent notifications, but got $false.
#         233:                                         ($alerts.Where{ $psitem.Severity -eq $sev }).HasNotification -in 1, 2, 3, 4, 5, 6, 7 | Should -be $true -Because "Should notify by Agent notifications"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 233
#       [-] SQL2017N5 should have Severity 17 Alert 4ms
#         Expected $true, because Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/, but got $null.
#         221:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 221
#       [-] SQL2017N5 should have Severity 17 Alert enabled 2ms
#         Expected $true, because Configured alerts should be enabled, but got $null.
#         224:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Configured alerts should be enabled"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 224
#       [-] SQL2017N5 should have notification for Severity 17 Alert 3ms
#         Expected $true, because Should notify by Agent notifications, but got $false.
#         233:                                         ($alerts.Where{ $psitem.Severity -eq $sev }).HasNotification -in 1, 2, 3, 4, 5, 6, 7 | Should -be $true -Because "Should notify by Agent notifications"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 233
#       [-] SQL2017N5 should have Severity 18 Alert 3ms
#         Expected $true, because Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/, but got $null.
#         221:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 221
#       [-] SQL2017N5 should have Severity 18 Alert enabled 5ms
#         Expected $true, because Configured alerts should be enabled, but got $null.
#         224:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Configured alerts should be enabled"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 224
#       [-] SQL2017N5 should have notification for Severity 18 Alert 4ms
#         Expected $true, because Should notify by Agent notifications, but got $false.
#         233:                                         ($alerts.Where{ $psitem.Severity -eq $sev }).HasNotification -in 1, 2, 3, 4, 5, 6, 7 | Should -be $true -Because "Should notify by Agent notifications"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 233
#       [-] SQL2017N5 should have Severity 19 Alert 2ms
#         Expected $true, because Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/, but got $null.
#         221:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 221
#       [-] SQL2017N5 should have Severity 19 Alert enabled 2ms
#         Expected $true, because Configured alerts should be enabled, but got $null.
#         224:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Configured alerts should be enabled"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 224
#       [-] SQL2017N5 should have notification for Severity 19 Alert 4ms
#         Expected $true, because Should notify by Agent notifications, but got $false.
#         233:                                         ($alerts.Where{ $psitem.Severity -eq $sev }).HasNotification -in 1, 2, 3, 4, 5, 6, 7 | Should -be $true -Because "Should notify by Agent notifications"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 233
#       [-] SQL2017N5 should have Severity 20 Alert 2ms
#         Expected $true, because Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/, but got $null.
#         221:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 221
#       [-] SQL2017N5 should have Severity 20 Alert enabled 2ms
#         Expected $true, because Configured alerts should be enabled, but got $null.
#         224:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Configured alerts should be enabled"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 224
#       [-] SQL2017N5 should have notification for Severity 20 Alert 5ms
#         Expected $true, because Should notify by Agent notifications, but got $false.
#         233:                                         ($alerts.Where{ $psitem.Severity -eq $sev }).HasNotification -in 1, 2, 3, 4, 5, 6, 7 | Should -be $true -Because "Should notify by Agent notifications"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 233
#       [-] SQL2017N5 should have Severity 21 Alert 3ms
#         Expected $true, because Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/, but got $null.
#         221:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 221
#       [-] SQL2017N5 should have Severity 21 Alert enabled 3ms
#         Expected $true, because Configured alerts should be enabled, but got $null.
#         224:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Configured alerts should be enabled"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 224
#       [-] SQL2017N5 should have notification for Severity 21 Alert 4ms
#         Expected $true, because Should notify by Agent notifications, but got $false.
#         233:                                         ($alerts.Where{ $psitem.Severity -eq $sev }).HasNotification -in 1, 2, 3, 4, 5, 6, 7 | Should -be $true -Because "Should notify by Agent notifications"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 233
#       [-] SQL2017N5 should have Severity 22 Alert 3ms
#         Expected $true, because Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/, but got $null.
#         221:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 221
#       [-] SQL2017N5 should have Severity 22 Alert enabled 3ms
#         Expected $true, because Configured alerts should be enabled, but got $null.
#         224:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Configured alerts should be enabled"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 224
#       [-] SQL2017N5 should have notification for Severity 22 Alert 3ms
#         Expected $true, because Should notify by Agent notifications, but got $false.
#         233:                                         ($alerts.Where{ $psitem.Severity -eq $sev }).HasNotification -in 1, 2, 3, 4, 5, 6, 7 | Should -be $true -Because "Should notify by Agent notifications"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 233
#       [-] SQL2017N5 should have Severity 23 Alert 3ms
#         Expected $true, because Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/, but got $null.
#         221:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 221
#       [-] SQL2017N5 should have Severity 23 Alert enabled 5ms
#         Expected $true, because Configured alerts should be enabled, but got $null.
#         224:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Configured alerts should be enabled"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 224
#       [-] SQL2017N5 should have notification for Severity 23 Alert 5ms
#         Expected $true, because Should notify by Agent notifications, but got $false.
#         233:                                         ($alerts.Where{ $psitem.Severity -eq $sev }).HasNotification -in 1, 2, 3, 4, 5, 6, 7 | Should -be $true -Because "Should notify by Agent notifications"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 233
#       [-] SQL2017N5 should have Severity 24 Alert 3ms
#         Expected $true, because Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/, but got $null.
#         221:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 221
#       [-] SQL2017N5 should have Severity 24 Alert enabled 3ms
#         Expected $true, because Configured alerts should be enabled, but got $null.
#         224:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Configured alerts should be enabled"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 224
#       [-] SQL2017N5 should have notification for Severity 24 Alert 3ms
#         Expected $true, because Should notify by Agent notifications, but got $false.
#         233:                                         ($alerts.Where{ $psitem.Severity -eq $sev }).HasNotification -in 1, 2, 3, 4, 5, 6, 7 | Should -be $true -Because "Should notify by Agent notifications"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 233
#       [-] SQL2017N5 should have Severity 25 Alert 3ms
#         Expected $true, because Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/, but got $null.
#         221:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 221
#       [-] SQL2017N5 should have Severity 25 Alert enabled 4ms
#         Expected $true, because Configured alerts should be enabled, but got $null.
#         224:                                     ($alerts.Where{ $psitem.Severity -eq $sev }) | Should -be $true -Because "Configured alerts should be enabled"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 224
#       [-] SQL2017N5 should have notification for Severity 25 Alert 3ms
#         Expected $true, because Should notify by Agent notifications, but got $false.
#         233:                                         ($alerts.Where{ $psitem.Severity -eq $sev }).HasNotification -in 1, 2, 3, 4, 5, 6, 7 | Should -be $true -Because "Should notify by Agent notifications"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 233
#
#     Context Testing Agent Alerts MessageID exists on SQL2017N5
#       [-] SQL2017N5 should have Message_ID 823 Alert 13ms
#         Expected $true, because Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/, but got $null.
#         241:                                     ($alerts.Where{ $psitem.messageid -eq $mid }) | Should -be $true -Because "Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 241
#       [-] SQL2017N5 should have Message_ID 823 Alert enabled 10ms
#         Expected $true, because Configured alerts should be enabled, but got $null.
#         244:                                     ($alerts.Where{ $psitem.messageid -eq $mid }) | Should -be $true -Because "Configured alerts should be enabled"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 244
#       [-] SQL2017N5 should have notification for Message_ID 823 Alert 4ms
#         Expected $true, because Should notify by Agent notifications, but got $false.
#         253:                                         ($alerts.Where{ $psitem.messageid -eq $mid }).HasNotification -in 1, 2, 3, 4, 5, 6, 7 | Should -be $true -Because "Should notify by Agent notifications"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 253
#       [-] SQL2017N5 should have Message_ID 824 Alert 3ms
#         Expected $true, because Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/, but got $null.
#         241:                                     ($alerts.Where{ $psitem.messageid -eq $mid }) | Should -be $true -Because "Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 241
#       [-] SQL2017N5 should have Message_ID 824 Alert enabled 3ms
#         Expected $true, because Configured alerts should be enabled, but got $null.
#         244:                                     ($alerts.Where{ $psitem.messageid -eq $mid }) | Should -be $true -Because "Configured alerts should be enabled"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 244
#       [-] SQL2017N5 should have notification for Message_ID 824 Alert 4ms
#         Expected $true, because Should notify by Agent notifications, but got $false.
#         253:                                         ($alerts.Where{ $psitem.messageid -eq $mid }).HasNotification -in 1, 2, 3, 4, 5, 6, 7 | Should -be $true -Because "Should notify by Agent notifications"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 253
#       [-] SQL2017N5 should have Message_ID 825 Alert 4ms
#         Expected $true, because Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/, but got $null.
#         241:                                     ($alerts.Where{ $psitem.messageid -eq $mid }) | Should -be $true -Because "Recommended Agent Alerts to exists http://blog.extreme-advice.com/2013/01/29/list-of-errors-and-severity-level-in-sql-server-with-catalog-view-sysmessages/"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 241
#       [-] SQL2017N5 should have Message_ID 825 Alert enabled 4ms
#         Expected $true, because Configured alerts should be enabled, but got $null.
#         244:                                     ($alerts.Where{ $psitem.messageid -eq $mid }) | Should -be $true -Because "Configured alerts should be enabled"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 244
#       [-] SQL2017N5 should have notification for Message_ID 825 Alert 4ms
#         Expected $true, because Should notify by Agent notifications, but got $false.
#         253:                                         ($alerts.Where{ $psitem.messageid -eq $mid }).HasNotification -in 1, 2, 3, 4, 5, 6, 7 | Should -be $true -Because "Should notify by Agent notifications"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 253
#
#   Describing Job History Configuration
#
#     Context Testing job history configuration on SQL2017N5
#
#   Describing Long Running Agent Jobs
#
#     Context Testing long running jobs on SQL2017N5
#       [-] Running job IndexOptimize - USER_DATABASES duration should not be more than 50 % extra of the average run time on SQL2017N5 12ms
#         Expected the actual value to be less than 50, because The current running job IndexOptimize - USER_DATABASES has been running for 1341393 seconds longer than the average run time. This is more than the 50 % specified as the maximum, but got 2199005.
#         40:     [math]::Round($runningjob.Diff/$runningjob.AvgSec * 100) | Should -BeLessThan $runningjobpercentage -Because "The current running job $($runningjob.JobName) has been running for $($runningjob.Diff) seconds longer than the average run time. This is more than the $runningjobpercentage % specified as the maximum"
#         at Assert-LongRunningJobs, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Agent.Assertions.ps1: line 40
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 335
#       [-] Running job SQLWATCH-LOGGER-AGENT-HISTORY duration should not be more than 50 % extra of the average run time on SQL2017N5 5ms
#         Expected the actual value to be less than 50, because The current running job SQLWATCH-LOGGER-AGENT-HISTORY has been running for 1436132 seconds longer than the average run time. This is more than the 50 % specified as the maximum, but got 6838724.
#         40:     [math]::Round($runningjob.Diff/$runningjob.AvgSec * 100) | Should -BeLessThan $runningjobpercentage -Because "The current running job $($runningjob.JobName) has been running for $($runningjob.Diff) seconds longer than the average run time. This is more than the $runningjobpercentage % specified as the maximum"
#         at Assert-LongRunningJobs, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Agent.Assertions.ps1: line 40
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 335
#       [-] Running job SQLWATCH-LOGGER-DISK-UTILISATION duration should not be more than 50 % extra of the average run time on SQL2017N5 4ms
#         Expected the actual value to be less than 50, because The current running job SQLWATCH-LOGGER-DISK-UTILISATION has been running for 477853 seconds longer than the average run time. This is more than the 50 % specified as the maximum, but got 5309478.
#         40:     [math]::Round($runningjob.Diff/$runningjob.AvgSec * 100) | Should -BeLessThan $runningjobpercentage -Because "The current running job $($runningjob.JobName) has been running for $($runningjob.Diff) seconds longer than the average run time. This is more than the $runningjobpercentage % specified as the maximum"
#         at Assert-LongRunningJobs, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Agent.Assertions.ps1: line 40
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 335
#       [-] Running job SQLWATCH-LOGGER-DISK-UTILISATION duration should not be more than 50 % extra of the average run time on SQL2017N5 4ms
#         Expected the actual value to be less than 50, because The current running job SQLWATCH-LOGGER-DISK-UTILISATION has been running for 1436144 seconds longer than the average run time. This is more than the 50 % specified as the maximum, but got 15957156.
#         40:     [math]::Round($runningjob.Diff/$runningjob.AvgSec * 100) | Should -BeLessThan $runningjobpercentage -Because "The current running job $($runningjob.JobName) has been running for $($runningjob.Diff) seconds longer than the average run time. This is more than the $runningjobpercentage % specified as the maximum"
#         at Assert-LongRunningJobs, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Agent.Assertions.ps1: line 40
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 335
#       [-] Running job SQLWATCH-LOGGER-PERFORMANCE duration should not be more than 50 % extra of the average run time on SQL2017N5 10ms
#         Expected the actual value to be less than 50, because The current running job SQLWATCH-LOGGER-PERFORMANCE has been running for 1436152 seconds longer than the average run time. This is more than the 50 % specified as the maximum, but got 143615200.
#         40:     [math]::Round($runningjob.Diff/$runningjob.AvgSec * 100) | Should -BeLessThan $runningjobpercentage -Because "The current running job $($runningjob.JobName) has been running for $($runningjob.Diff) seconds longer than the average run time. This is more than the $runningjobpercentage % specified as the maximum"
#         at Assert-LongRunningJobs, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Agent.Assertions.ps1: line 40
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 335
#       [-] Running job SQLWATCH-LOGGER-PERFORMANCE duration should not be more than 50 % extra of the average run time on SQL2017N5 5ms
#         Expected the actual value to be less than 50, because The current running job SQLWATCH-LOGGER-PERFORMANCE has been running for 1387172 seconds longer than the average run time. This is more than the 50 % specified as the maximum, but got 138717200.
#         40:     [math]::Round($runningjob.Diff/$runningjob.AvgSec * 100) | Should -BeLessThan $runningjobpercentage -Because "The current running job $($runningjob.JobName) has been running for $($runningjob.Diff) seconds longer than the average run time. This is more than the $runningjobpercentage % specified as the maximum"
#         at Assert-LongRunningJobs, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Agent.Assertions.ps1: line 40
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 335
#       [-] Running job syspolicy_purge_history duration should not be more than 50 % extra of the average run time on SQL2017N5 4ms
#         Expected the actual value to be less than 50, because The current running job syspolicy_purge_history has been running for 448047 seconds longer than the average run time. This is more than the 50 % specified as the maximum, but got 3733725.
#         40:     [math]::Round($runningjob.Diff/$runningjob.AvgSec * 100) | Should -BeLessThan $runningjobpercentage -Because "The current running job $($runningjob.JobName) has been running for $($runningjob.Diff) seconds longer than the average run time. This is more than the $runningjobpercentage % specified as the maximum"
#         at Assert-LongRunningJobs, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Agent.Assertions.ps1: line 40
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 335
#
#   Describing Last Agent Job Run
#
#     Context Testing last job run time on SQL2017N5
#       [-] Job IndexOptimize - USER_DATABASES last run duration should be not be greater than 50 % extra of the average run time on SQL2017N5 5ms
#         Expected the actual value to be less than 50, because The last run of job IndexOptimize - USER_DATABASES was 130 seconds. This is more than the 50 % specified as the maximum variance, but got 113.
#         44:     [math]::Round($lastagentjobrun.Diff/$lastagentjobrun.AvgSec * 100) | Should -BeLessThan $runningjobpercentage -Because "The last run of job $($lastagentjobrun.JobName) was $($lastagentjobrun.duration) seconds. This is more than the $runningjobpercentage % specified as the maximum variance"
#         at Assert-LastJobRun, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Agent.Assertions.ps1: line 44
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 399
#       [-] Job DatabaseIntegrityCheck - SYSTEM_DATABASES last run duration should be not be greater than 50 % extra of the average run time on SQL2017N5 4ms
#         Expected the actual value to be less than 50, because The last run of job DatabaseIntegrityCheck - SYSTEM_DATABASES was 2 seconds. This is more than the 50 % specified as the maximum variance, but got 100.
#         44:     [math]::Round($lastagentjobrun.Diff/$lastagentjobrun.AvgSec * 100) | Should -BeLessThan $runningjobpercentage -Because "The last run of job $($lastagentjobrun.JobName) was $($lastagentjobrun.duration) seconds. This is more than the $runningjobpercentage % specified as the maximum variance"
#         at Assert-LastJobRun, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Agent.Assertions.ps1: line 44
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 399
#       [-] Job DatabaseBackup - USER_DATABASES - FULL last run duration should be not be greater than 50 % extra of the average run time on SQL2017N5 6ms
#         Expected the actual value to be less than 50, because The last run of job DatabaseBackup - USER_DATABASES - FULL was 38 seconds. This is more than the 50 % specified as the maximum variance, but got 138.
#         44:     [math]::Round($lastagentjobrun.Diff/$lastagentjobrun.AvgSec * 100) | Should -BeLessThan $runningjobpercentage -Because "The last run of job $($lastagentjobrun.JobName) was $($lastagentjobrun.duration) seconds. This is more than the $runningjobpercentage % specified as the maximum variance"
#         at Assert-LastJobRun, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Agent.Assertions.ps1: line 44
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 399
#       [-] Job SSIS Server Maintenance Job last run duration should be not be greater than 50 % extra of the average run time on SQL2017N5 5ms
#         Expected the actual value to be less than 50, because The last run of job SSIS Server Maintenance Job was 22 seconds. This is more than the 50 % specified as the maximum variance, but got 2100.
#         44:     [math]::Round($lastagentjobrun.Diff/$lastagentjobrun.AvgSec * 100) | Should -BeLessThan $runningjobpercentage -Because "The last run of job $($lastagentjobrun.JobName) was $($lastagentjobrun.duration) seconds. This is more than the $runningjobpercentage % specified as the maximum variance"
#         at Assert-LastJobRun, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Agent.Assertions.ps1: line 44
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 399
#       [-] Job Gather SQLWatch Data last run duration should be not be greater than 50 % extra of the average run time on SQL2017N5 48ms
#         Expected the actual value to be less than 50, because The last run of job Gather SQLWatch Data was 249 seconds. This is more than the 50 % specified as the maximum variance, but got 60.
#         44:     [math]::Round($lastagentjobrun.Diff/$lastagentjobrun.AvgSec * 100) | Should -BeLessThan $runningjobpercentage -Because "The last run of job $($lastagentjobrun.JobName) was $($lastagentjobrun.duration) seconds. This is more than the $runningjobpercentage % specified as the maximum variance"
#         at Assert-LastJobRun, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Agent.Assertions.ps1: line 44
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 399
#       [-] Job syspolicy_purge_history last run duration should be not be greater than 50 % extra of the average run time on SQL2017N5 5ms
#         Expected the actual value to be less than 50, because The last run of job syspolicy_purge_history was 35 seconds. This is more than the 50 % specified as the maximum variance, but got 192.
#         44:     [math]::Round($lastagentjobrun.Diff/$lastagentjobrun.AvgSec * 100) | Should -BeLessThan $runningjobpercentage -Because "The last run of job $($lastagentjobrun.JobName) was $($lastagentjobrun.duration) seconds. This is more than the $runningjobpercentage % specified as the maximum variance"
#         at Assert-LastJobRun, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Agent.Assertions.ps1: line 44
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 399
#       [-] Job SQLWATCH-LOGGER-PERFORMANCE last run duration should be not be greater than 50 % extra of the average run time on SQL2017N5 5ms
#         Expected the actual value to be less than 50, because The last run of job SQLWATCH-LOGGER-PERFORMANCE was 5 seconds. This is more than the 50 % specified as the maximum variance, but got 400.
#         44:     [math]::Round($lastagentjobrun.Diff/$lastagentjobrun.AvgSec * 100) | Should -BeLessThan $runningjobpercentage -Because "The last run of job $($lastagentjobrun.JobName) was $($lastagentjobrun.duration) seconds. This is more than the $runningjobpercentage % specified as the maximum variance"
#         at Assert-LastJobRun, D:\OneDrive\Documents\GitHub\dbachecks\internal\assertions\Agent.Assertions.ps1: line 44
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Agent.Tests.ps1: line 399
#
# Executing script D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1
# Tests completed in 4.66s
# Tests Passed: 36, Failed: 66, Skipped: 0, Pending: 0, Inconclusive: 0

# %%
Invoke-DbcCheck -SqlInstance SQL2017N5 -Check MaintenanceSolution -Show Fails
# Out:
#     ____            __
#    / __ \___  _____/ /____  _____
#   / /_/ / _ \/ ___/ __/ _ \/ ___/
#  / ____/  __(__  ) /_/  __/ /
# /_/    \___/____/\__/\___/_/
# Pester v4.9.0
# Executing all tests in 'D:\OneDrive\Documents\GitHub\dbachecks\checks\MaintenanceSolution.Tests.ps1' with Tags MaintenanceSolution
#
# Executing script D:\OneDrive\Documents\GitHub\dbachecks\checks\MaintenanceSolution.Tests.ps1
#
#   Describing Ola maintenance solution installed
#
#     Context Checking the CommandLog table on SQL2017N5
#
#     Context Checking the Ola Stored Procedures on SQL2017N5
#
#   Describing Ola - DatabaseBackup - SYSTEM_DATABASES - FULL
#
#     Context Is job enabled on SQL2017N5
#
#     Context Is job scheduled on SQL2017N5
#
#     Context Checking the backup retention on SQL2017N5
#       [-] Is the backup retention set to at least 192 hours on SQL2017N5 14ms
#         Expected the actual value to be greater than or equal to 192, because The backup retention for DatabaseBackup - SYSTEM_DATABASES - FULL needs to be correct, but got 0.
#         70:                     $hours | Should -BeGreaterOrEqual $Retention -Because "The backup retention for $SysFullJobName needs to be correct"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\MaintenanceSolution.Tests.ps1: line 70
#
#   Describing Ola - DatabaseBackup - USER_DATABASES - FULL
#
#     Context Is job enabled on SQL2017N5
#
#     Context Is job scheduled on SQL2017N5
#
#     Context Checking the backup retention on SQL2017N5
#       [-] Is the backup retention set to at least 192 hours on SQL2017N5 8ms
#         Expected the actual value to be greater than or equal to 192, because The backup retention for DatabaseBackup - USER_DATABASES - FULL needs to be correct, but got 0.
#         114:                     $hours | Should -BeGreaterOrEqual $Retention -Because "The backup retention for $UserFullJobName needs to be correct"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\MaintenanceSolution.Tests.ps1: line 114
#
#   Describing Ola - DatabaseBackup - USER_DATABASES - DIFF
#
#     Context Is job enabled on SQL2017N5
#
#     Context Is job scheduled on SQL2017N5
#
#     Context Checking the backup retention on SQL2017N5
#       [-] Is the backup retention set to at least 192 hours on SQL2017N5 11ms
#         Expected the actual value to be greater than or equal to 192, because The backup retention for DatabaseBackup - USER_DATABASES - DIFF needs to be correct, but got 0.
#         158:                     $hours | Should -BeGreaterOrEqual $Retention -Because "The backup retention for $UserDiffJobName needs to be correct"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\MaintenanceSolution.Tests.ps1: line 158
#
#   Describing Ola - DatabaseBackup - USER_DATABASES - Log
#
#     Context Is job enabled on SQL2017N5
#
#     Context Is job scheduled on SQL2017N5
#
#     Context Checking the backup retention on SQL2017N5
#       [-] Is the backup retention set to at least 192 hours on SQL2017N5 9ms
#         Expected the actual value to be greater than or equal to 192, because The backup retention for DatabaseBackup - USER_DATABASES - Log needs to be correct, but got 0.
#         202:                     $hours | Should -BeGreaterOrEqual $Retention -Because "The backup retention for $UserLogJobName needs to be correct"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\MaintenanceSolution.Tests.ps1: line 202
#
#   Describing Ola - CommandLog Cleanup
#
#     Context Is job enabled on SQL2017N5
#
#     Context Is job scheduled on SQL2017N5
#       [-] CommandLog Cleanup should be scheduled - True on SQL2017N5 46ms
#         Expected $true, because If the CommandLog Cleanup job is not scheduled it will not run, but got $false.
#         224:                 $job.HasSchedule | Should -Be $Scheduled -Because "If the $CommandLogJobName job is not scheduled it will not run"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\MaintenanceSolution.Tests.ps1: line 224
#       [-] CommandLog Cleanup schedules should be enabled - True on SQL2017N5 13ms
#         Expected the actual value to be greater than 0, because If the schedule is not enabled the CommandLog Cleanup job will not run, but got $false.
#         228:                 $results | Should -BeGreaterThan 0 -Because "If the schedule is not enabled the $CommandLogJobName job will not run"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\MaintenanceSolution.Tests.ps1: line 228
#
#     Context Checking the Command Log Cleanup Time on SQL2017N5
#
#   Describing Ola - DatabaseIntegrityCheck - SYSTEM_DATABASES
#
#     Context Is job enabled on SQL2017N5
#
#     Context Is job scheduled on SQL2017N5
#
#   Describing Ola - DatabaseIntegrityCheck - USER_DATABASES
#
#     Context Is job enabled on SQL2017N5
#
#     Context Is job scheduled on SQL2017N5
#       [-] DatabaseIntegrityCheck - USER_DATABASES should be scheduled - True on SQL2017N5 31ms
#         Expected $true, because If the DatabaseIntegrityCheck - USER_DATABASES job is not scheduled it will not run, but got $false.
#         281:                 $job.HasSchedule | Should -Be $Scheduled -Because "If the $UserIntegrityJobName job is not scheduled it will not run"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\MaintenanceSolution.Tests.ps1: line 281
#       [-] DatabaseIntegrityCheck - USER_DATABASES schedules should be enabled - True on SQL2017N5 18ms
#         Expected the actual value to be greater than 0, because If the schedule is not enabled the DatabaseIntegrityCheck - USER_DATABASES job will not run, but got $false.
#         285:                 $results | Should -BeGreaterThan 0 -Because "If the schedule is not enabled the $UserIntegrityJobName job will not run"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\MaintenanceSolution.Tests.ps1: line 285
#
#   Describing Ola - IndexOptimize - USER_DATABASES
#
#     Context Is job enabled on SQL2017N5
#
#     Context Is job scheduled on SQL2017N5
#
#   Describing Ola - Output File Cleanup
#
#     Context Is job enabled on SQL2017N5
#
#     Context Is job scheduled on SQL2017N5
#       [-] Output File Cleanup should be scheduled - True on SQL2017N5 39ms
#         Expected $true, because If the Output File Cleanup job is not scheduled it will not run, but got $false.
#         330:                 $job.HasSchedule | Should -Be $Scheduled -Because "If the $OutputFileJobName job is not scheduled it will not run"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\MaintenanceSolution.Tests.ps1: line 330
#       [-] Output File Cleanup schedules should be enabled - True on SQL2017N5 14ms
#         Expected the actual value to be greater than 0, because If the schedule is not enabled the Output File Cleanup job will not run, but got $false.
#         334:                 $results | Should -BeGreaterThan 0 -Because "If the schedule is not enabled the $OutputFileJobName job will not run"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\MaintenanceSolution.Tests.ps1: line 334
#
#     Context Checking the Output File Job Cleanup Time on SQL2017N5
#
#   Describing Ola - sp_delete_backuphistory
#
#     Context Is job enabled on SQL2017N5
#
#     Context Is job scheduled on SQL2017N5
#       [-] sp_delete_backuphistory should be scheduled - True on SQL2017N5 40ms
#         Expected $true, because If the sp_delete_backuphistory job is not scheduled it will not run, but got $false.
#         370:                 $job.HasSchedule | Should -Be $Scheduled -Because "If the $DeleteBackupJobName job is not scheduled it will not run"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\MaintenanceSolution.Tests.ps1: line 370
#       [-] sp_delete_backuphistory schedules should be enabled - True on SQL2017N5 15ms
#         Expected the actual value to be greater than 0, because If the schedule is not enabled the sp_delete_backuphistory job will not run, but got $false.
#         374:                 $results | Should -BeGreaterThan 0 -Because "If the schedule is not enabled the $DeleteBackupJobName job will not run"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\MaintenanceSolution.Tests.ps1: line 374
#
#     Context Checking the Delete Backup History Cleanup Time on SQL2017N5
#
#   Describing Ola - sp_purge_jobhistory
#
#     Context Is job enabled on SQL2017N5
#
#     Context Is job scheduled on SQL2017N5
#       [-] sp_purge_jobhistory should be scheduled - True on SQL2017N5 15ms
#         Expected $true, because If the sp_purge_jobhistory job is not scheduled it will not run, but got $false.
#         404:                 $job.HasSchedule | Should -Be $Scheduled -Because "If the $PurgeBackupJobName job is not scheduled it will not run"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\MaintenanceSolution.Tests.ps1: line 404
#       [-] sp_purge_jobhistory schedules should be enabled - True 14ms
#         Expected the actual value to be greater than 0, because If the schedule is not enabled the sp_purge_jobhistory job will not run, but got $false.
#         408:                 $results | Should -BeGreaterThan 0 -Because "If the schedule is not enabled the $PurgeBackupJobName job will not run"
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\MaintenanceSolution.Tests.ps1: line 408
#
#     Context Checking the Purge Backup History Cleanup Time on SQL2017N5
# Tests completed in 4.08s
# Tests Passed: 29, Failed: 14, Skipped: 0, Pending: 0, Inconclusive: 0
