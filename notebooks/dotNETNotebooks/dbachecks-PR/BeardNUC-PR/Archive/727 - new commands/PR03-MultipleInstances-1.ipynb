# %% [markdown]
# # dbachecks PR check on Beard NUC - MultipleInstances
#
# Rob uses this process to make sure that changes will work in an AD estate with a variety of versions

# %% [markdown]
# First we must check the status of the local source control and ensure that we are in the PR branch

# %%
cd D:\OneDrive\Documents\GitHub\dbachecks
git status
# Out:
# <script type="text/javascript">#!javascript
# if ((typeof(requirejs) !==  typeof(Function)) || (typeof(requirejs.config) !== typeof(Function))) {
#     let script = document.createElement("script");
#     script.setAttribute("src", "https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js");
#     script.onload = function(){
#         loadDotnetInteractiveApi();
#     };
#     document.getElementsByTagName("head")[0].appendChild(script);
# }
# else {
#     loadDotnetInteractiveApi();
# }
#
# function loadDotnetInteractiveApi(){
#     let apiRequire = requirejs.config({context:"dotnet-interactive.20428.62883",paths:{dotnetInteractive:"http://localhost:62883/resources/dotnet-interactive"}});
#     apiRequire(['dotnetInteractive'],
#     function(api) {
#         api.createDotnetInteractiveClient("http://localhost:62883/", window);
#     },
#     function(error){
#         console.log(error);
#     });
# }</script>
# On branch new-json
# Your branch is ahead of 'origin/new-json' by 162 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %% [markdown]
# First we need to import the module from source control - I normally use verbose to see how it is going

# %%
Import-Module .\dbachecks.psd1
$null = Reset-DbcConfig

# %% [markdown]
# Excellent, that worked. Now to run some checks against a single instance

# %% [markdown]
# I don't care if the test pass or fail, I am only interested in any
#
# > Describe block has Error
#
# or
#
# > Error in Script
#
# type failures

# %% [markdown]
# Multiple Instances at parameter

# %%
Get-VM -ComputerName BEARDNUC, BEARDNUC2
# Out:
# Name                             State   CPUUsage(%) MemoryAssigned(M) Uptime           Status
# ----                             -----   ----------- ----------------- ------           ------
# BeardDC1                         Running 0           1400              01:50:13.7100000 Operating …
# BeardDC2                         Off     0           0                 00:00:00         Operating …
# BeardLinuxVNext                  Off     0           0                 00:00:00         Operating …
# DockerDesktopVM                  Off     0           0                 00:00:00         Operating …
# LinuxvNextCTP14                  Off     0           0                 00:00:00         Operating …
# PullServer                       Off     0           0                 00:00:00         Operating …
# SQL2005Ser2003                   Running 0           800               01:17:59.8060000 Operating …
# SQL2008Ser12R2                   Running 0           942               01:17:58.1670000 Operating …
# SQL2012Ser08AG1                  Running 14          2664              01:17:58.8610000 Operating …
# SQL2012Ser08AG2                  Running 0           2056              01:17:59.6120000 Operating …
# SQL2012Ser08AG3                  Running 14          2154              01:16:52.0370000 Operating …
# SQL2014Ser12R2                   Running 5           4862              01:17:55.1990000 Operating …
# SQL2016N1                        Running 12          2658              01:17:47.2080000 Operating …
# SQL2016N2                        Running 10          3114              01:15:42.1900000 Operating …
# SQL2016N3                        Running 10          2168              01:14:35.6910000 Operating …
# SQL2017CTP2                      Off     0           0                 00:00:00         Operating …
# SQL2019N1                        Running 0           1882              01:14:32.4990000 Operating …
# SQL2019N2                        Off     0           0                 00:00:00         Operating …
# SQLVnextN1                       Off     0           0                 00:00:00         Operating …
# SQLvNextN2                       Off     0           0                 00:00:00         Operating …
# THEBEARDDNS1                     Off     0           0                 00:00:00         Operating …
# BeardDC4                         Running 0           1312              02:22:00.3510000 Operating …
# BeardNUC2VMs_2020-02-24-03-17-17 Off     0           0                 00:00:00         Operating …
# BeardNUC2VMs_2020-02-24-07-51-51 Off     0           0                 00:00:00         Operating …
# BeardNUC2VMs_2020-02-24-07-54-54 Off     0           0                 00:00:00         Operating …
# BeardNUC2VMs_2020-02-24-07-58-58 Off     0           0                 00:00:00         Operating …
# BeardNUC2VMs_2020-02-24-08-01-01 Off     0           0                 00:00:00         Operating …
# BeardNUC2VMs_2020-03-02-04-51-51 Off     0           0                 00:00:00         Operating …
# BeardNUC2VMs_2020-03-02-04-55-55 Off     0           0                 00:00:00         Operating …
# BeardNUC2VMs_2020-03-02-04-58-58 Off     0           0                 00:00:00         Operating …
# BeardNUC2VMs_2020-03-02-05-02-02 Off     0           0                 00:00:00         Operating …
# BeardNUC2VMs_2020-03-02-05-05-05 Off     0           0                 00:00:00         Operating …
# BeardNUC2VMs_2020-03-02-05-08-08 Off     0           0                 00:00:00         Operating …
# SQL2017N5                        Running 3           2326              01:18:36.0640000 Operating …
# SQL2019N20                       Running 0           1708              01:18:35.3740000 Operating …
# SQL2019N21                       Running 3           1712              01:18:34.6670000 Operating …
# SQL2019N22                       Running 3           1658              01:18:33.3940000 Operating …
# SQL2019N5                        Running 6           2836              01:18:27.1950000 Operating …

# %%
$Sqlinstances = (Get-VM -ComputerName BEARDNUC, BEARDNUC2 -Name *SQL* | Where State -eq 'Running').Name

Invoke-DbcCheck -SqlInstance $SQLInstances -Check InstanceConnection
# Out:
#     ____            __
#    / __ \___  _____/ /____  _____
#   / /_/ / _ \/ ___/ __/ _ \/ ___/
#  / ____/  __(__  ) /_/  __/ /
# /_/    \___/____/\__/\___/_/
# Pester v4.9.0
# Executing all tests in 'D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1' with Tags InstanceConnection
#
# Executing script D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2005Ser2003
#       [+] connects successfully to SQL2005Ser2003 41ms
#       [+] auth scheme should be Kerberos on SQL2005Ser2003 269ms
#       [+] We should be able to ping host SQL2005Ser2003 22ms
#       [-] We should be able to remote onto SQL2005Ser2003 32ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2016N2
#       [+] connects successfully to SQL2016N2 1ms
#       [+] auth scheme should be Kerberos on SQL2016N2 187ms
#       [+] We should be able to ping host SQL2016N2 4ms
#       [-] We should be able to remote onto SQL2016N2 10ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2012Ser08AG1
#       [+] connects successfully to SQL2012Ser08AG1 1ms
#       [+] auth scheme should be Kerberos on SQL2012Ser08AG1 87ms
#       [+] We should be able to ping host SQL2012Ser08AG1 4ms
#       [-] We should be able to remote onto SQL2012Ser08AG1 7ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2016N3
#       [+] connects successfully to SQL2016N3 3ms
#       [+] auth scheme should be Kerberos on SQL2016N3 109ms
#       [+] We should be able to ping host SQL2016N3 6ms
#       [-] We should be able to remote onto SQL2016N3 5ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2012Ser08AG3
#       [+] connects successfully to SQL2012Ser08AG3 3ms
#       [+] auth scheme should be Kerberos on SQL2012Ser08AG3 403ms
#       [+] We should be able to ping host SQL2012Ser08AG3 5ms
#       [-] We should be able to remote onto SQL2012Ser08AG3 6ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2012Ser08AG2
#       [+] connects successfully to SQL2012Ser08AG2 1ms
#       [+] auth scheme should be Kerberos on SQL2012Ser08AG2 106ms
#       [+] We should be able to ping host SQL2012Ser08AG2 4ms
#       [-] We should be able to remote onto SQL2012Ser08AG2 4ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2014Ser12R2
#       [+] connects successfully to SQL2014Ser12R2 3ms
#       [+] auth scheme should be Kerberos on SQL2014Ser12R2 98ms
#       [+] We should be able to ping host SQL2014Ser12R2 2ms
#       [-] We should be able to remote onto SQL2014Ser12R2 7ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2008Ser12R2
#       [+] connects successfully to SQL2008Ser12R2 1ms
#       [+] auth scheme should be Kerberos on SQL2008Ser12R2 80ms
#       [+] We should be able to ping host SQL2008Ser12R2 3ms
#       [-] We should be able to remote onto SQL2008Ser12R2 5ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2016N1
#       [+] connects successfully to SQL2016N1 2ms
#       [+] auth scheme should be Kerberos on SQL2016N1 246ms
#       [+] We should be able to ping host SQL2016N1 4ms
#       [-] We should be able to remote onto SQL2016N1 7ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2019N1
#       [+] connects successfully to SQL2019N1 1ms
#       [-] auth scheme should be Kerberos on SQL2019N1 188ms
#         Expected strings to be the same, but they were different.
#         Expected length: 8
#         Actual length:   4
#         Strings differ at index 0.
#         Expected: 'Kerberos'
#         But was:  'NTLM'
#         64:                         (Test-DbaConnectionAuthScheme -SqlInstance $Instance).authscheme | Should -Be $authscheme
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 64
#       [-] We should be able to ping host SQL2019N1 771ms
#         Expected $true, but got $false.
#         72:                     $pingable | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 72
#       [-] We should be able to remote onto SQL2019N1 7ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2017N5
#       [+] connects successfully to SQL2017N5 3ms
#       [+] auth scheme should be Kerberos on SQL2017N5 71ms
#       [-] We should be able to ping host SQL2017N5 725ms
#         Expected $true, but got $false.
#         72:                     $pingable | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 72
#       [-] We should be able to remote onto SQL2017N5 7ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2019N22
#       [+] connects successfully to SQL2019N22 1ms
#       [+] auth scheme should be Kerberos on SQL2019N22 56ms
#       [-] We should be able to ping host SQL2019N22 752ms
#         Expected $true, but got $false.
#         72:                     $pingable | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 72
#       [-] We should be able to remote onto SQL2019N22 4ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2019N21
#       [+] connects successfully to SQL2019N21 1ms
#       [+] auth scheme should be Kerberos on SQL2019N21 57ms
#       [-] We should be able to ping host SQL2019N21 752ms
#         Expected $true, but got $false.
#         72:                     $pingable | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 72
#       [-] We should be able to remote onto SQL2019N21 4ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2019N20
#       [+] connects successfully to SQL2019N20 1ms
#       [+] auth scheme should be Kerberos on SQL2019N20 66ms
#       [-] We should be able to ping host SQL2019N20 711ms
#         Expected $true, but got $false.
#         72:                     $pingable | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 72
#       [-] We should be able to remote onto SQL2019N20 5ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on SQL2019N5
#       [+] connects successfully to SQL2019N5 2ms
#       [+] auth scheme should be Kerberos on SQL2019N5 106ms
#       [-] We should be able to ping host SQL2019N5 692ms
#         Expected $true, but got $false.
#         72:                     $pingable | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 72
#       [-] We should be able to remote onto SQL2019N5 7ms
#         Expected $true, but got $false.
#         84:                     $remoting | Should -BeTrue
#         at <ScriptBlock>, D:\OneDrive\Documents\GitHub\dbachecks\checks\Instance.Tests.ps1: line 84
# Tests completed in 11.1s
# Tests Passed: 38, Failed: 22, Skipped: 0, Pending: 0, Inconclusive: 0
