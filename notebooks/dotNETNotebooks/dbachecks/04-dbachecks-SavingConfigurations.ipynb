# %% [markdown]
# ![First Power Bi](.\images\dbachecks-logo.png )
# # dbachecks - Saving Configurations
#
# You can alter the configurations for any check at the command line to ensure that you are running checks that will test what you want.
#
# You will want to save those configurations so that you can pass them to other people or run them using automation.
#
# The process that you will need to follow is
#
# - Create the configuration
# - test the configuration
# - save the configuration with `Export-DbcConfig`
#
# This will create a json file of the configuration which you can save in source control and then you, others in your team or automation can use the configuration with `Import-DbcConfig`

# %% [markdown]
# # Excluding and skipping checks
#
# As well as the configuration items that you saw in the simple configuration notebook, which will change the value for a check such as making sure that the database owners are the accounts that you expect, there are other configuration items which enable you to exclude checks, instances or databases from checks, skip parts of checks.
#
# You can see those configurations by running the block below.
#
# When you are creating configurations for saving and sharing, you will find `command.invokedbccheck.excludecheck` and `command.invokedbccheck.excludedatabases` useful.
#
# `command.invokedbccheck.excludecheck` will set the configuration so that any checks specified here will not run. It is best to exclude Groups of checks rather than individual ones here.
# `command.invokedbccheck.excludedatabases` will set the configuration for any databases that you do not wish to run checks against.

# %%
Get-DbcConfig | Where-Object{$_.Name -like '*exclude*' -or $_.Name -like '*skip*'}
# Out:
# <script type="text/javascript">#!javascript
# if ((typeof(requirejs) !==  typeof(Function)) || (typeof(requirejs.config) !== typeof(Function))) {
#     let script = document.createElement("script");
#     script.setAttribute("src", "https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js");
#     script.onload = function(){
#         loadDotnetInteractiveApi();
#     };
#     document.getElementsByTagName("head")[0].appendChild(script);
# }
# else {
#     loadDotnetInteractiveApi();
# }
#
# function loadDotnetInteractiveApi(){
#     let apiRequire = requirejs.config({context:"dotnet-interactive.1464.52983",paths:{dotnetInteractive:"http://localhost:52983/resources/dotnet-interactive"}});
#     apiRequire(['dotnetInteractive'],
#     function(api) {
#         api.createDotnetInteractiveClient("http://localhost:52983/", window);
#     },
#     function(error){
#         console.log(error);
#     });
# }</script>
# Name                                                                   Value Description
# ----                                                                   ----- -----------
# agent.failedjob.excludecancelled                                       False Exclude agent jobs wi…
# command.invokedbccheck.excludecheck                                       {} Invoke-DbcCheck: The …
# command.invokedbccheck.excludedatabases                                   {} Invoke-DbcCheck: The …
# policy.adlogingroup.excludecheck                                             Active Directory Grou…
# policy.adloginuser.excludecheck                                              Active Directory User…
# policy.certificateexpiration.excludedb         {master, msdb, model, tempdb} Databases to exclude …
# policy.database.filegrowthexcludedb                                       {} Databases to exclude …
# policy.database.maxdopexcludedb                                           {} Database Names that w…
# policy.database.status.excludeoffline                                     {} Database names that w…
# policy.database.status.excludereadonly                                    {} Database names that w…
# policy.database.status.excluderestoring                                   {} Database names that w…
# policy.instancemaxdop.excludeinstance                                     {} Any Instances to excl…
# policy.invaliddbowner.excludedb                {master, msdb, model, tempdb} Databases to exclude …
# policy.recoverymodel.excludedb                              {master, tempdb} Databases to exclude …
# policy.server.excludeDiskAllocationUnit                                   {} The disks to skip fro…
# policy.validdbowner.excludedb                  {master, msdb, model, tempdb} Databases to exclude …
# skip.agent.lastjobruntime                                              False Skip the last agent j…
# skip.agent.longrunningjobs                                             False Skip the long running…
# skip.backup.readonly                                                   False Check read-only datab…
# skip.backup.testing                                                     True Don't run Test-DbaLas…
# skip.connection.auth                                                   False Skip the authenticato…
# skip.connection.ping                                                   False Skip the ping check f…
# skip.connection.remoting                                               False Skip PowerShell remot…
# skip.database.filegrowthdisabled                                        True Skip validation of da…
# skip.database.logfilecounttest                                         False Skip the logfilecount…
# skip.datafilegrowthdisabled                                             True Skip validation of da…
# skip.dbcc.datapuritycheck                                              False Skip data purity chec…
# skip.diffbackuptest                                                    False Skip the Differential…
# skip.hadr.listener.pingcheck                                           False Skip the HADR listene…
# skip.instance.defaulttrace                                             False Skip the default trac…
# skip.instance.latestbuild                                              False Skip the scan the lat…
# skip.instance.modeldbgrowth                                            False Skip the model databa…
# skip.instance.oleautomationproceduresdisabled                          False Skip OLE Automation P…
# skip.instance.remoteaccessdisabled                                     False Skip the remote acces…
# skip.instance.scanforstartupproceduresdisabled                         False Skip the scan for sta…
# skip.logfilecounttest                                                  False Skip the logfilecount…
# skip.logshiptesting                                                    False Skip the logshipping …
# skip.security.builtinadmin                                              True Skips the scan for BU…
# skip.security.containedbautoclose                                       True Skips the scan for co…
# skip.security.guestuserconnect                                          True Skips the scan for gu…
# skip.security.localwindowsgroup                                         True Skips the scan for if…
# skip.security.loginauditlevelfailed                                     True Skips the scan for if…
# skip.security.loginauditlevelsuccessful                                 True Skips the scan for if…
# skip.security.publicrolepermission                                      True Skips the scan for if…
# skip.security.sadisabled                                                True Skip the check for if…
# skip.security.saexist                                                   True Skip the check for a …
# skip.tempdb1118                                                        False Don't run test for Tr…
# skip.tempdbfilecount                                                   False Don't run test for Te…
# skip.tempdbfilegrowthpercent                                           False Don't run test for Te…
# skip.tempdbfilesizemax                                                 False Don't run test for Te…
# skip.tempdbfilesonc                                                    False Don't run test for Te…

# %% [markdown]
# # Create a configuration
#
# First you will need to create your configuration.
#
# ## Reset the configuration to default first
# It is best practice to run `Reset-DbcConfig` before you start to do this to avoid confusion. This will reset all of the configurations to the default values. It will also list all of the configurations and you can see the current (default) values

# %%
Reset-DbcConfig
# Out:
# Name                                                                                                              Value
# ----                                                                                                              -----
# agent.alert.Job                                                                                                   False
# agent.alert.messageid                                                                                   {823, 824, 825}
# agent.alert.Notification                                                                                           True
# agent.alert.Severity                                                                                {16, 17, 18, 19...}
# agent.databasemailprofile
# agent.dbaoperatoremail
# agent.dbaoperatorname
# agent.failedjob.excludecancelled                                                                                  False
# agent.failedjob.since                                                                                                30
# agent.failsafeoperator
# agent.history.maximumhistoryrows                                                                                   1000
# agent.history.maximumjobhistoryrows                                                                                 100
# agent.lastjobruntime.percentage                                                                                      50
# agent.longrunningjob.percentage                                                                                      50
# agent.validjobowner.name                                                                                             sa
# app.checkrepos                                     {C:\Program Files\WindowsPowerShell\Modules\dbachecks\1.2.24\checks}
# app.cluster
# app.computername
# app.localapp                                                                     C:\Users\mrrob\AppData\Local\dbachecks
# app.maildirectory                                                 C:\Users\mrrob\AppData\Local\dbachecks\dbachecks.mail
# app.sqlcredential
# app.sqlinstance
# app.wincredential
# command.invokedbccheck.excludecheck                                                                                  {}
# command.invokedbccheck.excludedatabases                                                                              {}
# database.exists                                                                           {master, msdb, tempdb, model}
# domain.domaincontroller
# domain.name
# domain.organizationalunit
# global.notcontactable                                                                                                {}
# mail.failurethreshhold                                                                                                0
# mail.from
# mail.smtpserver
# mail.subject                                                                                          dbachecks results
# mail.to
# ola.JobName.CommandLogCleanup                                                                        CommandLog Cleanup
# ola.JobName.DeleteBackupHistory                                                                 sp_delete_backuphistory
# ola.JobName.OutputFileCleanup                                                                       Output File Cleanup
# ola.JobName.PurgeBackupHistory                                                                      sp_purge_jobhistory
# ola.JobName.SystemFull                                                         DatabaseBackup - SYSTEM_DATABASES - FULL
# ola.JobName.SystemIntegrity                                                   DatabaseIntegrityCheck - SYSTEM_DATABASES
# ola.JobName.UserDiff                                                             DatabaseBackup - USER_DATABASES - DIFF
# ola.JobName.UserFull                                                             DatabaseBackup - USER_DATABASES - FULL
# ola.JobName.UserIndex                                                                    IndexOptimize - USER_DATABASES
# ola.JobName.UserIntegrity                                                       DatabaseIntegrityCheck - USER_DATABASES
# ola.JobName.UserLog                                                               DatabaseBackup - USER_DATABASES - Log
# policy.adlogingroup.excludecheck
# policy.adloginuser.excludecheck
# policy.backup.datadir
# policy.backup.defaultbackupcompression                                                                             True
# policy.backup.diffmaxhours                                                                                           25
# policy.backup.fullmaxdays                                                                                             1
# policy.backup.logdir
# policy.backup.logmaxminutes                                                                                          15
# policy.backup.newdbgraceperiod                                                                                        0
# policy.backup.testserver
# policy.build.behind
# policy.build.warningwindow                                                                                            6
# policy.certificateexpiration.excludedb                                                    {master, msdb, model, tempdb}
# policy.certificateexpiration.warningwindow                                                                            1
# policy.connection.authscheme                                                                                   Kerberos
# policy.connection.pingcount                                                                                           3
# policy.connection.pingmaxms                                                                                          10
# policy.dacallowed                                                                                                  True
# policy.database.autoclose                                                                                         False
# policy.database.autocreatestatistics                                                                               True
# policy.database.autoshrink                                                                                        False
# policy.database.autoupdatestatistics                                                                               True
# policy.database.autoupdatestatisticsasynchronously                                                                False
# policy.database.filebalancetolerance                                                                                  5
# policy.database.filegrowthexcludedb                                                                                  {}
# policy.database.filegrowthfreespacethreshold                                                                         20
# policy.database.filegrowthtype                                                                                       kb
# policy.database.filegrowthvalue                                                                                   65535
# policy.database.logfilecount                                                                                          1
# policy.database.logfilesizecomparison                                                                           average
# policy.database.logfilesizepercentage                                                                               100
# policy.database.maxdop                                                                                                0
# policy.database.maxdopexcludedb                                                                                      {}
# policy.database.maxvlf                                                                                              512
# policy.database.status.excludeoffline                                                                                {}
# policy.database.status.excludereadonly                                                                               {}
# policy.database.status.excluderestoring                                                                              {}
# policy.database.wrongcollation                                                                                       {}
# policy.dbcc.maxdays                                                                                                   7
# policy.diskspace.percentfree                                                                                         20
# policy.dump.maxcount                                                                                                  1
# policy.errorlog.logcount                                                                                             -1
# policy.errorlog.warningwindow                                                                                         2
# policy.hadr.tcpport                                                                                                1433
# policy.identity.usagepercent                                                                                         90
# policy.instance.sqlenginestart                                                                                Automatic
# policy.instance.sqlenginestate                                                                                  Running
# policy.instancemaxdop.excludeinstance                                                                                {}
# policy.instancemaxdop.maxdop                                                                                          0
# policy.instancemaxdop.userecommended                                                                              False
# policy.invaliddbowner.excludedb                                                           {master, msdb, model, tempdb}
# policy.invaliddbowner.name                                                                                           sa
# policy.network.latencymaxms                                                                                          40
# policy.ola.CommandLogCleanUp                                                                                         30
# policy.ola.CommandLogenabled                                                                                       True
# policy.ola.CommandLogscheduled                                                                                     True
# policy.ola.database                                                                                              master
# policy.ola.DeleteBackupHistoryCleanUp                                                                                30
# policy.ola.DeleteBackupHistoryenabled                                                                              True
# policy.ola.DeleteBackupHistoryscheduled                                                                            True
# policy.ola.installed                                                                                               True
# policy.ola.OutputFileCleanUp                                                                                         30
# policy.ola.OutputFileCleanupenabled                                                                                True
# policy.ola.OutputFileCleanupscheduled                                                                              True
# policy.ola.PurgeJobHistoryCleanUp                                                                                    30
# policy.ola.PurgeJobHistoryenabled                                                                                  True
# policy.ola.PurgeJobHistoryscheduled                                                                                True
# policy.ola.systemfullenabled                                                                                       True
# policy.ola.systemfullretention                                                                                      192
# policy.ola.systemfullscheduled                                                                                     True
# policy.ola.SystemIntegrityCheckenabled                                                                             True
# policy.ola.SystemIntegrityCheckscheduled                                                                           True
# policy.ola.userdiffenabled                                                                                         True
# policy.ola.userdiffretention                                                                                        192
# policy.ola.userdiffscheduled                                                                                       True
# policy.ola.userfullenabled                                                                                         True
# policy.ola.userfullretention                                                                                        192
# policy.ola.userfullscheduled                                                                                       True
# policy.ola.UserIndexOptimizeenabled                                                                                True
# policy.ola.UserIndexOptimizescheduled                                                                              True
# policy.ola.UserIntegrityCheckenabled                                                                               True
# policy.ola.UserIntegrityCheckscheduled                                                                             True
# policy.ola.userlogenabled                                                                                          True
# policy.ola.userlogretention                                                                                         192
# policy.ola.userlogscheduled                                                                                        True
# policy.oleautomation                                                                                              False
# policy.pageverify                                                                                              Checksum
# policy.recoverymodel.excludedb                                                                         {master, tempdb}
# policy.recoverymodel.type                                                                                          Full
# policy.security.adhocdistributedqueriesenabled                                                                    False
# policy.security.clrenabled                                                                                        False
# policy.security.containedbautoclose                                                                               False
# policy.security.crossdbownershipchaining                                                                          False
# policy.security.databasemailenabled                                                                               False
# policy.security.latestbuild                                                                                        True
# policy.security.oleautomationproceduresdisabled                                                                    True
# policy.security.remoteaccessdisabled                                                                                  0
# policy.security.scanforstartupproceduresdisabled                                                                   True
# policy.security.xpcmdshelldisabled                                                                                 True
# policy.server.cpuprioritisation                                                                                    True
# policy.server.excludeDiskAllocationUnit                                                                              {}
# policy.storage.backuppath
# policy.traceflags.expected                                                                                           {}
# policy.traceflags.notexpected                                                                                        {}
# policy.twodigityearcutoff                                                                                          2049
# policy.validdbowner.excludedb                                                             {master, msdb, model, tempdb}
# policy.validdbowner.name                                                                                             sa
# policy.whoisactive.database                                                                                      master
# policy.xevent.requiredrunningsession
# policy.xevent.requiredstoppedsession
# policy.xevent.validrunningsession
# skip.agent.lastjobruntime                                                                                         False
# skip.agent.longrunningjobs                                                                                        False
# skip.backup.readonly                                                                                              False
# skip.backup.testing                                                                                                True
# skip.connection.auth                                                                                              False
# skip.connection.ping                                                                                              False
# skip.connection.remoting                                                                                          False
# skip.database.filegrowthdisabled                                                                                   True
# skip.database.logfilecounttest                                                                                    False
# skip.datafilegrowthdisabled                                                                                        True
# skip.dbcc.datapuritycheck                                                                                         False
# skip.diffbackuptest                                                                                               False
# skip.hadr.listener.pingcheck                                                                                      False
# skip.instance.defaulttrace                                                                                        False
# skip.instance.latestbuild                                                                                         False
# skip.instance.modeldbgrowth                                                                                       False
# skip.instance.oleautomationproceduresdisabled                                                                     False
# skip.instance.remoteaccessdisabled                                                                                False
# skip.instance.scanforstartupproceduresdisabled                                                                    False
# skip.logfilecounttest                                                                                             False
# skip.logshiptesting                                                                                               False
# skip.security.builtinadmin                                                                                         True
# skip.security.containedbautoclose                                                                                  True
# skip.security.guestuserconnect                                                                                     True
# skip.security.localwindowsgroup                                                                                    True
# skip.security.loginauditlevelfailed                                                                                True
# skip.security.loginauditlevelsuccessful                                                                            True
# skip.security.publicrolepermission                                                                                 True
# skip.security.sadisabled                                                                                           True
# skip.security.saexist                                                                                              True
# skip.tempdb1118                                                                                                   False
# skip.tempdbfilecount                                                                                              False
# skip.tempdbfilegrowthpercent                                                                                      False
# skip.tempdbfilesizemax                                                                                            False
# skip.tempdbfilesonc                                                                                               False
# testing.integration.instance                                                                                {localhost}

# %% [markdown]
# ## Morning Checks Configuration
#
# Lets create a configuration for some morning checks for our Production estate. You will
#
# - Check the production instances (we only have two in this demo) 'localhost,15592','localhost,15593'
# - Ensure the instance is available and the connection authentication scheme is SQL (because we are using SQL Auth) but don't check PSRemoting
# - Ensure that all agent jobs have succeeded
# - All databases have backups that meet RPO/RTO
# - There are no errors in the Error Logs in the last 24 hours
# - The disk space is not less than 10% free
# - There are no Memory Dumps
# - The last duration of the agent jobs was not more than 10% of the average run time including any currently running jobs
# - The log file sizes are less than 50% of the data file sizes
# - That databases have more than 10% free space available

# %%
# Set the instances and computernames to run the check against
Set-DbcConfig -Name app.sqlinstance -Value 'localhost,15592','localhost,15593'
Set-DbcConfig -Name app.computername -Value 'localhost,15592','localhost,15593'
# Set the auth scheme to SQL as we are using SQL Auth
Set-DbcConfig -Name policy.connection.authscheme -Value SQL
# Don't check the PSRemoting
Set-DbcConfig -Name skip.connection.remoting -Value $true
# Set expected backup - 7 days for full - 24 hours for diff - 15 minutes for log
Set-DbcConfig -Name policy.backup.fullmaxdays -Value 7
Set-DbcConfig -Name policy.backup.diffmaxhours -Value 24
Set-DbcConfig -Name policy.backup.logmaxminutes -Value 15
# Set config for disk space
Set-DbcConfig -Name policy.diskspace.percentfree -Value 10
# Maximum number of memory dumps
Set-DbcConfig -Name policy.dump.maxcount -Value 1
# Set config for job run times
Set-DbcConfig -Name agent.lastjobruntime.percentage -Value 10
Set-DbcConfig -Name agent.longrunningjob.percentage -Value 10
# Set max size of log files compared to data file size
Set-DbcConfig -Name policy.database.logfilesizecomparison -Value Average
Set-DbcConfig -Name policy.database.logfilesizepercentage -Value 50
# Set config to ensure files have more than 10% free
Set-DbcConfig -Name policy.database.filegrowthfreespacethreshold -Value 10
# Out:
# Name                                         Value                              Description
# ----                                         -----                              -----------
# app.sqlinstance                              {localhost,15592, localhost,15593} List of SQL Server…
# app.computername                             {localhost,15592, localhost,15593} List of Windows Se…
# policy.connection.authscheme                 SQL                                Auth requirement (…
# skip.connection.remoting                     True                               Skip PowerShell re…
# policy.backup.fullmaxdays                    7                                  Maximum number of …
# policy.backup.diffmaxhours                   24                                 Maximum number of …
# policy.backup.logmaxminutes                  15                                 Maximum number of …
# policy.diskspace.percentfree                 10                                 Percent disk free
# policy.dump.maxcount                         1                                  Maximum number of …
# agent.lastjobruntime.percentage              10                                 The maximum percen…
# agent.longrunningjob.percentage              10                                 The maximum percen…
# policy.database.logfilesizecomparison        Average                            How to compare dat…
# policy.database.logfilesizepercentage        50                                 Maximum percentage…
# policy.database.filegrowthfreespacethreshold 10                                 Integer representi…

# %% [markdown]
# # Examining the current configuration and saving it
#
# When you set the configuration, the output shows the cuurently configured values for the configuration items that you have changed.
#
# You can examine the complete current configuration with `Get-DbcConfig`

# %%
Get-DbcConfig
# Out:
# Name                                                                                          Value
# ----                                                                                          -----
# agent.alert.Job                                                                               False
# agent.alert.messageid                                                     {1101, 1105, 1121, 1214…}
# agent.alert.Notification                                                                       True
# agent.alert.Severity                                                              {16, 17, 18, 19…}
# agent.databasemailprofile
# agent.dbaoperatoremail
# agent.dbaoperatorname
# agent.failedjob.excludecancelled                                                              False
# agent.failedjob.since                                                                            30
# agent.failsafeoperator
# agent.history.maximumhistoryrows                                                               1000
# agent.history.maximumjobhistoryrows                                                             100
# agent.lastjobruntime.percentage                                                                  10
# agent.longrunningjob.percentage                                                                  10
# agent.validjobowner.name                                                                         sa
# app.checkrepos                                     …nts\PowerShell\Modules\dbachecks\1.2.24\checks}
# app.cluster
# app.computername                                                 {localhost,15592, localhost,15593}
# app.localapp                                                 C:\Users\mrrob\AppData\Local\dbachecks
# app.maildirectory                                  …rs\mrrob\AppData\Local\dbachecks\dbachecks.mail
# app.sqlcredential
# app.sqlinstance                                                  {localhost,15592, localhost,15593}
# app.wincredential
# command.invokedbccheck.excludecheck                                                              {}
# command.invokedbccheck.excludedatabases                                                          {}
# database.exists                                                      {master, msdb, tempdb, model…}
# domain.domaincontroller
# domain.name
# domain.organizationalunit
# global.notcontactable                                                                            {}
# mail.failurethreshhold                                                                            0
# mail.from
# mail.smtpserver
# mail.subject                                                                      dbachecks results
# mail.to
# ola.JobName.CommandLogCleanup                                                    CommandLog Cleanup
# ola.JobName.DeleteBackupHistory                                             sp_delete_backuphistory
# ola.JobName.OutputFileCleanup                                                   Output File Cleanup
# ola.JobName.PurgeBackupHistory                                                  sp_purge_jobhistory
# ola.JobName.SystemFull                                     DatabaseBackup - SYSTEM_DATABASES - FULL
# ola.JobName.SystemIntegrity                               DatabaseIntegrityCheck - SYSTEM_DATABASES
# ola.JobName.UserDiff                                         DatabaseBackup - USER_DATABASES - DIFF
# ola.JobName.UserFull                                         DatabaseBackup - USER_DATABASES - FULL
# ola.JobName.UserIndex                                                IndexOptimize - USER_DATABASES
# ola.JobName.UserIntegrity                                   DatabaseIntegrityCheck - USER_DATABASES
# ola.JobName.UserLog                                           DatabaseBackup - USER_DATABASES - Log
# policy.adlogingroup.excludecheck
# policy.adloginuser.excludecheck
# policy.backup.datadir
# policy.backup.defaultbackupcompression                                                         True
# policy.backup.diffmaxhours                                                                       24
# policy.backup.fullmaxdays                                                                         7
# policy.backup.logdir
# policy.backup.logmaxminutes                                                                      15
# policy.backup.newdbgraceperiod                                                                    0
# policy.backup.testserver
# policy.build.behind
# policy.build.warningwindow                                                                        6
# policy.certificateexpiration.excludedb                                {master, msdb, model, tempdb}
# policy.certificateexpiration.warningwindow                                                        1
# policy.connection.authscheme                                                                    SQL
# policy.connection.pingcount                                                                       3
# policy.connection.pingmaxms                                                                      10
# policy.dacallowed                                                                              True
# policy.database.autoclose                                                                     False
# policy.database.autocreatestatistics                                                           True
# policy.database.autoshrink                                                                    False
# policy.database.autoupdatestatistics                                                           True
# policy.database.autoupdatestatisticsasynchronously                                            False
# policy.database.filebalancetolerance                                                              5
# policy.database.filegrowthexcludedb                                                              {}
# policy.database.filegrowthfreespacethreshold                                                     10
# policy.database.filegrowthtype                                                                   kb
# policy.database.filegrowthvalue                                                               65535
# policy.database.logfilecount                                                                      1
# policy.database.logfilesizecomparison                                                       Average
# policy.database.logfilesizepercentage                                                            50
# policy.database.maxdop                                                                            0
# policy.database.maxdopexcludedb                                                                  {}
# policy.database.maxvlf                                                                          512
# policy.database.status.excludeoffline                                                            {}
# policy.database.status.excludereadonly                                                           {}
# policy.database.status.excluderestoring                                                          {}
# policy.database.wrongcollation                                                                   {}
# policy.dbcc.maxdays                                                                               7
# policy.diskspace.percentfree                                                                     10
# policy.dump.maxcount                                                                              1
# policy.errorlog.logcount                                                                         -1
# policy.errorlog.warningwindow                                                                     2
# policy.hadr.tcpport                                                                            1433
# policy.identity.usagepercent                                                                     90
# policy.instance.sqlenginestart                                                            Automatic
# policy.instance.sqlenginestate                                                              Running
# policy.instancemaxdop.excludeinstance                                                            {}
# policy.instancemaxdop.maxdop                                                                      0
# policy.instancemaxdop.userecommended                                                          False
# policy.invaliddbowner.excludedb                                       {master, msdb, model, tempdb}
# policy.invaliddbowner.name                                                                 sqladmin
# policy.network.latencymaxms                                                                      40
# policy.ola.CommandLogCleanUp                                                                     30
# policy.ola.CommandLogenabled                                                                   True
# policy.ola.CommandLogscheduled                                                                 True
# policy.ola.database                                                                          master
# policy.ola.DeleteBackupHistoryCleanUp                                                            30
# policy.ola.DeleteBackupHistoryenabled                                                          True
# policy.ola.DeleteBackupHistoryscheduled                                                        True
# policy.ola.installed                                                                           True
# policy.ola.OutputFileCleanUp                                                                     30
# policy.ola.OutputFileCleanupenabled                                                            True
# policy.ola.OutputFileCleanupscheduled                                                          True
# policy.ola.PurgeJobHistoryCleanUp                                                                30
# policy.ola.PurgeJobHistoryenabled                                                              True
# policy.ola.PurgeJobHistoryscheduled                                                            True
# policy.ola.systemfullenabled                                                                   True
# policy.ola.systemfullretention                                                                  192
# policy.ola.systemfullscheduled                                                                 True
# policy.ola.SystemIntegrityCheckenabled                                                         True
# policy.ola.SystemIntegrityCheckscheduled                                                       True
# policy.ola.userdiffenabled                                                                     True
# policy.ola.userdiffretention                                                                    192
# policy.ola.userdiffscheduled                                                                   True
# policy.ola.userfullenabled                                                                     True
# policy.ola.userfullretention                                                                    192
# policy.ola.userfullscheduled                                                                   True
# policy.ola.UserIndexOptimizeenabled                                                            True
# policy.ola.UserIndexOptimizescheduled                                                          True
# policy.ola.UserIntegrityCheckenabled                                                           True
# policy.ola.UserIntegrityCheckscheduled                                                         True
# policy.ola.userlogenabled                                                                      True
# policy.ola.userlogretention                                                                     192
# policy.ola.userlogscheduled                                                                    True
# policy.oleautomation                                                                          False
# policy.pageverify                                                                          Checksum
# policy.recoverymodel.excludedb                                                     {master, tempdb}
# policy.recoverymodel.type                                                                      Full
# policy.security.adhocdistributedqueriesenabled                                                False
# policy.security.clrenabled                                                                    False
# policy.security.containedbautoclose                                                           False
# policy.security.crossdbownershipchaining                                                      False
# policy.security.databasemailenabled                                                           False
# policy.security.latestbuild                                                                    True
# policy.security.oleautomationproceduresdisabled                                                True
# policy.security.remoteaccessdisabled                                                              0
# policy.security.scanforstartupproceduresdisabled                                               True
# policy.security.xpcmdshelldisabled                                                             True
# policy.server.cpuprioritisation                                                                True
# policy.server.excludeDiskAllocationUnit                                                          {}
# policy.storage.backuppath
# policy.traceflags.expected                                                                       {}
# policy.traceflags.notexpected                                                                    {}
# policy.twodigityearcutoff                                                                      2049
# policy.validdbowner.excludedb                                         {master, msdb, model, tempdb}
# policy.validdbowner.name                                                                   thebeard
# policy.whoisactive.database                                                                  master
# policy.xevent.requiredrunningsession
# policy.xevent.requiredstoppedsession
# policy.xevent.validrunningsession
# skip.agent.lastjobruntime                                                                     False
# skip.agent.longrunningjobs                                                                    False
# skip.backup.readonly                                                                          False
# skip.backup.testing                                                                            True
# skip.connection.auth                                                                          False
# skip.connection.ping                                                                          False
# skip.connection.remoting                                                                       True
# skip.database.filegrowthdisabled                                                               True
# skip.database.logfilecounttest                                                                False
# skip.datafilegrowthdisabled                                                                    True
# skip.dbcc.datapuritycheck                                                                     False
# skip.diffbackuptest                                                                           False
# skip.hadr.listener.pingcheck                                                                  False
# skip.instance.defaulttrace                                                                    False
# skip.instance.latestbuild                                                                     False
# skip.instance.modeldbgrowth                                                                   False
# skip.instance.oleautomationproceduresdisabled                                                 False
# skip.instance.remoteaccessdisabled                                                            False
# skip.instance.scanforstartupproceduresdisabled                                                False
# skip.logfilecounttest                                                                         False
# skip.logshiptesting                                                                           False
# skip.security.builtinadmin                                                                     True
# skip.security.containedbautoclose                                                              True
# skip.security.guestuserconnect                                                                 True
# skip.security.localwindowsgroup                                                                True
# skip.security.loginauditlevelfailed                                                            True
# skip.security.loginauditlevelsuccessful                                                        True
# skip.security.publicrolepermission                                                             True
# skip.security.sadisabled                                                                       True
# skip.security.saexist                                                                          True
# skip.tempdb1118                                                                               False
# skip.tempdbfilecount                                                                          False
# skip.tempdbfilegrowthpercent                                                                  False
# skip.tempdbfilesizemax                                                                        False
# skip.tempdbfilesonc                                                                           False
# testing.integration.instance                                                            {localhost}

# %% [markdown]
# ## Saving the configuration to a file for reuse
#
# Once you have a configuration created, you can save it for easy importing into your session or for use with automation. I suggest that the best place for you to save this is in a source control repository so changes can be controlled and auditted
#
# To save the current configuration use `Export-DbcConfig`

# %%
$FolderPath = $Env:USERPROFILE + '\Documents\dbachecks'
Export-DbcConfig -Path $FolderPath\Morning-Checks-Production.json
# Out:
# [18:30:43][Export-DbcConfig] Wrote file to C:\Users\mrrob\Documents\dbachecks\Morning-Checks-Production.json

# %% [markdown]
# The file that is created is just json, you can take a look at it (and alter it directly if you wish)

# %%
azuredatastudio $FolderPath\Morning-Checks-Production.json

# %% [markdown]
# # Loading the configuration from a file
#
# To use the configuration that you have saved you use `Import-DbcConfig`
#
# This will take the values from the json file and set the configuration accordingly

# %%
Import-DbcConfig -Path $FolderPath\Morning-Checks-Production.json
# Out:
# Name                                                    Value Description
# ----                                                    ----- -----------
# agent.alert.Job                                         False Agent alert job notification. Ex job…
# agent.alert.messageid               {1101, 1105, 1121, 1214…} Agent alert messageid to validate; h…
# agent.alert.Notification                                 True Agent alert notification
# agent.alert.Severity                        {16, 17, 18, 19…} Agent alert severity to validate; ht…
# agent.databasemailprofile                                     Name of the Database Mail Profile in…
# agent.dbaoperatoremail                                        Email address of the DBA Operator in…
# agent.dbaoperatorname                                         Name of the DBA Operator in SQL Agent
# agent.failedjob.excludecancelled                        False Exclude agent jobs with a status of …
# agent.failedjob.since                                      30 The maximum number of days to check …
# agent.failsafeoperator                                        Email address of the DBA Operator in…
# agent.history.maximumhistoryrows                         1000 Maximum job history log size (in row…
# agent.history.maximumjobhistoryrows                       100 Maximum job history row per job. Whe…
# agent.lastjobruntime.percentage                            10 The maximum percentage variance that…
# agent.longrunningjob.percentage                            10 The maximum percentage variance that…
# agent.validjobowner.name                                   sa Agent job owner account should be th…
# app.checkrepos                      …dbachecks\1.2.24\checks} Where Pester tests/checks are stored
# app.cluster                                                   One host name for each cluster for t…
# app.computername                    …,15592, localhost,15593} List of Windows Servers that Windows…
# app.localapp                        …\AppData\Local\dbachecks Persisted files live here
# app.maildirectory                   …dbachecks\dbachecks.mail Files for mail are stored here
# app.sqlcredential                                             The universal SQL credential if Trus…
# app.sqlinstance                     …,15592, localhost,15593} List of SQL Server instances that SQ…
# app.wincredential                                             The universal Windows if default Win…
# command.invokedbccheck.excludecheck                        {} Invoke-DbcCheck: The checks that sho…
# command.invokedbccheck.excludedata…                        {} Invoke-DbcCheck: The databases that …
# database.exists                     …r, msdb, tempdb, model…} The databases we expect to be on the…
# domain.domaincontroller                                       The domain controller to process you…
# domain.name                                                   The Active Directory domain that you…
# domain.organizationalunit                                     The OU that your server should be a …
# global.notcontactable                                      {} This is used within the checks to av…
# mail.failurethreshhold                                      0 Number of errors that must be presen…
# mail.from                                                     Email address the email reports shou…
# mail.smtpserver                                               Store the name of the smtp server to…
# mail.subject                                dbachecks results Subject line of the email report
# mail.to                                                       Email address to send the report to
# ola.JobName.CommandLogCleanup              CommandLog Cleanup The name for the Ola CommandLog Clea…
# ola.JobName.DeleteBackupHistory       sp_delete_backuphistory The name for the Ola Delete Backup H…
# ola.JobName.OutputFileCleanup             Output File Cleanup The name for the Ola Output File Cle…
# ola.JobName.PurgeBackupHistory            sp_purge_jobhistory The name for the Ola Delete Purge Hi…
# ola.JobName.SystemFull              … SYSTEM_DATABASES - FULL The name for the Ola System Full Job
# ola.JobName.SystemIntegrity         …Check - SYSTEM_DATABASES The name for the Ola System Integrit…
# ola.JobName.UserDiff                … - USER_DATABASES - DIFF The name for the Ola User Diff Job
# ola.JobName.UserFull                … - USER_DATABASES - FULL The name for the Ola User Full Job
# ola.JobName.UserIndex               …ptimize - USER_DATABASES The name for the Ola User Index Job
# ola.JobName.UserIntegrity           …tyCheck - USER_DATABASES The name for the Ola User Integrity …
# ola.JobName.UserLog                 …p - USER_DATABASES - Log The name for the Ola User Log Job
# policy.adlogingroup.excludecheck                              Active Directory Groups logins to ex…
# policy.adloginuser.excludecheck                               Active Directory User logins to excl…
# policy.backup.datadir                                         Destination server data directory
# policy.backup.defaultbackupcompres…                      True Default Backup Compression should be…
# policy.backup.diffmaxhours                                 24 Maximum number of hours before Diff …
# policy.backup.fullmaxdays                                   7 Maximum number of days before Full B…
# policy.backup.logdir                                          Destination server log directory
# policy.backup.logmaxminutes                                15 Maximum number of minutes before Log…
# policy.backup.newdbgraceperiod                              0 The number of hours a newly created …
# policy.backup.testserver                                      Destination server for backuptests
# policy.build.behind                                           The max number of service packs or c…
# policy.build.warningwindow                                  6 The number of months prior to a buil…
# policy.certificateexpiration.exclu… …er, msdb, model, tempdb} Databases to exclude from expired ce…
# policy.certificateexpiration.warni…                         1 The number of months prior to a cert…
# policy.connection.authscheme                              SQL Auth requirement (Kerberos, NTLM, et…
# policy.connection.pingcount                                 3 Number of times to ping a server to …
# policy.connection.pingmaxms                                10 Maximum response time in ms
# policy.dacallowed                                        True DAC should be allowed $true or disal…
# policy.database.autoclose                               False Auto Close should be allowed $true o…
# policy.database.autocreatestatisti…                      True Auto Create Statistics should be ena…
# policy.database.autoshrink                              False Auto Shrink should be allowed $true …
# policy.database.autoupdatestatisti…                      True Auto Update Statistics should be ena…
# policy.database.autoupdatestatisti…                     False Auto Update Statistics Asynchronousl…
# policy.database.filebalancetoleran…                         5 Percentage for Tolerance for checkin…
# policy.database.filegrowthexcludedb                        {} Databases to exclude from the file g…
# policy.database.filegrowthfreespac…                        10 Integer representing percentage of f…
# policy.database.filegrowthtype                             kb Growth Type should be 'kb' or 'perce…
# policy.database.filegrowthvalue                         65535 The auto growth value (in kb) should…
# policy.database.logfilecount                                1 The number of Log files expected on …
# policy.database.logfilesizecompari…                   Average How to compare data and log file siz…
# policy.database.logfilesizepercent…                        50 Maximum percentage of Data file Size…
# policy.database.maxdop                                      0 The value for the database maxdop th…
# policy.database.maxdopexcludedb                            {} Database Names that we don't want to…
# policy.database.maxvlf                                    512 Max virtual log files
# policy.database.status.excludeoffl…                        {} Database names that we expect to be …
# policy.database.status.excluderead…                        {} Database names that we expect to be …
# policy.database.status.excluderest…                        {} Database names that we expect to be …
# policy.database.wrongcollation                             {} Databases that doesnt match server c…
# policy.dbcc.maxdays                                         7 Maximum number of days before DBCC C…
# policy.diskspace.percentfree                               10 Percent disk free
# policy.dump.maxcount                                        1 Maximum number of expected dumps
# policy.errorlog.logcount                                   -1 The minimum number of error log file…
# policy.errorlog.warningwindow                               2 The number of days prior to check fo…
# policy.hadr.tcpport                                      1433 The TCPPort for the HADR check
# policy.identity.usagepercent                               90 Maximum percentage of max of identit…
# policy.instance.sqlenginestart                      Automatic The expected start type of the SQL E…
# policy.instance.sqlenginestate                        Running The expected state of the SQL Engine…
# policy.instancemaxdop.excludeinsta…                        {} Any Instances to exclude from checki…
# policy.instancemaxdop.maxdop                                0 The value for the Instance Level Max…
# policy.instancemaxdop.userecommend…                     False Use the recommendation from Test-Dba…
# policy.invaliddbowner.excludedb     …er, msdb, model, tempdb} Databases to exclude from invalid db…
# policy.invaliddbowner.name                           sqladmin The database owner account should no…
# policy.network.latencymaxms                                40 Max network latency average
# policy.ola.CommandLogCleanUp                               30 Ola's CommandLog Cleanup setting sho…
# policy.ola.CommandLogenabled                             True Ola's CommandLog Cleanup should be e…
# policy.ola.CommandLogscheduled                           True Ola's CommandLog Cleanup should be s…
# policy.ola.database                                    master The database where Ola's maintenance…
# policy.ola.DeleteBackupHistoryClea…                        30 Ola's Delete Backup History Cleanup …
# policy.ola.DeleteBackupHistoryenab…                      True Ola's Delete Backup History should b…
# policy.ola.DeleteBackupHistorysche…                      True Ola's Delete Backup History should b…
# policy.ola.installed                                     True Checks to see if Ola Hallengren solu…
# policy.ola.OutputFileCleanUp                               30 Ola's OutputFile Cleanup setting sho…
# policy.ola.OutputFileCleanupenabled                      True Ola's Output File Cleanup should be …
# policy.ola.OutputFileCleanupschedu…                      True Ola's Output File Cleanup should be …
# policy.ola.PurgeJobHistoryCleanUp                          30 Ola's Purge Backup History Cleanup s…
# policy.ola.PurgeJobHistoryenabled                        True Ola's Purge Job History should be en…
# policy.ola.PurgeJobHistoryscheduled                      True Ola's Purge Job History should be sc…
# policy.ola.systemfullenabled                             True Ola's Full System Database Backup sh…
# policy.ola.systemfullretention                            192 Ola's Full System Database Backup re…
# policy.ola.systemfullscheduled                           True Ola's Full System Database Backup sh…
# policy.ola.SystemIntegrityCheckena…                      True Ola's System Database Integrity shou…
# policy.ola.SystemIntegrityChecksch…                      True Ola's System Database Integrity shou…
# policy.ola.userdiffenabled                               True Ola's Diff User Database Backup shou…
# policy.ola.userdiffretention                              192 Ola's Diff User Database Backup rete…
# policy.ola.userdiffscheduled                             True Ola's Diff User Database Backup shou…
# policy.ola.userfullenabled                               True Ola's Full User Database Backup shou…
# policy.ola.userfullretention                              192 Ola's Full User Database Backup rete…
# policy.ola.userfullscheduled                             True Ola's Full User Database Backup shou…
# policy.ola.UserIndexOptimizeenabled                      True Ola's User Index Optimization should…
# policy.ola.UserIndexOptimizeschedu…                      True Ola's User Index Optimization should…
# policy.ola.UserIntegrityCheckenabl…                      True Ola's User Database Integrity should…
# policy.ola.UserIntegrityChecksched…                      True Ola's User Database Integrity should…
# policy.ola.userlogenabled                                True Ola's Log User Database Backup shoul…
# policy.ola.userlogretention                               192 Ola's Log User Database Backup reten…
# policy.ola.userlogscheduled                              True Ola's Log User Database Backup shoul…
# policy.oleautomation                                    False OLE Automation should be enabled $tr…
# policy.pageverify                                    Checksum Page verify option should be set to …
# policy.recoverymodel.excludedb               {master, tempdb} Databases to exclude from standard r…
# policy.recoverymodel.type                                Full Standard recovery model
# policy.security.adhocdistributedqu…                     False Ad Hoc Distributed Queries should be…
# policy.security.clrenabled                              False CLR Enabled should be enabled $true …
# policy.security.containedbautoclose                     False Contained databases should have auto…
# policy.security.crossdbownershipch…                     False Cross Database Ownership Chaining sh…
# policy.security.databasemailenabled                     False Database Mail XPs should be enabled …
# policy.security.latestbuild                              True SQL Server should have the latest SQ…
# policy.security.oleautomationproce…                      True OLE Automation Procedures should be …
# policy.security.remoteaccessdisabl…                         0 Remote Access should be disabled 0
# policy.security.scanforstartupproc…                      True Scan For Startup Procedures disabled…
# policy.security.xpcmdshelldisabled                       True XP CmdShell should be disabled $true…
# policy.server.cpuprioritisation                          True Shall we skip the CPU Prioritisation…
# policy.server.excludeDiskAllocatio…                        {} The disks to skip from the Disk Allo…
# policy.storage.backuppath                                     Enables tests to check if servers ha…
# policy.traceflags.expected                                 {} The trace flags we expect to be runn…
# policy.traceflags.notexpected                              {} The trace flags we expect not to be …
# policy.twodigityearcutoff                                2049 The value for 'Two Digit Year Cutoff…
# policy.validdbowner.excludedb       …er, msdb, model, tempdb} Databases to exclude from valid dbow…
# policy.validdbowner.name                             thebeard The database owner account should be…
# policy.whoisactive.database                            master Which database should contain the sp…
# policy.xevent.requiredrunningsessi…                           List of XE Sessions that should be r…
# policy.xevent.requiredstoppedsessi…                           List of XE Sessions that should not …
# policy.xevent.validrunningsession                             List of XE Sessions that can be be r…
# skip.agent.lastjobruntime                               False Skip the last agent job time check
# skip.agent.longrunningjobs                              False Skip the long running agent jobs che…
# skip.backup.readonly                                    False Check read-only databases for last b…
# skip.backup.testing                                      True Don't run Test-DbaLastBackup by defa…
# skip.connection.auth                                    False Skip the authenticaton scheme check …
# skip.connection.ping                                    False Skip the ping check for connectivity
# skip.connection.remoting                                 True Skip PowerShell remoting check for c…
# skip.database.filegrowthdisabled                         True Skip validation of datafiles which h…
# skip.database.logfilecounttest                          False Skip the logfilecount test
# skip.datafilegrowthdisabled                              True Skip validation of datafiles which h…
# skip.dbcc.datapuritycheck                               False Skip data purity check in last good …
# skip.diffbackuptest                                     False Skip the Differential backup test
# skip.hadr.listener.pingcheck                            False Skip the HADR listener ping test (ex…
# skip.instance.defaulttrace                              False Skip the default trace check
# skip.instance.latestbuild                               False Skip the scan the latest build of SQ…
# skip.instance.modeldbgrowth                             False Skip the model database growth setti…
# skip.instance.oleautomationprocedu…                     False Skip OLE Automation Procedures check
# skip.instance.remoteaccessdisabled                      False Skip the remote access check
# skip.instance.scanforstartupproced…                     False Skip the scan for startup procedures…
# skip.logfilecounttest                                   False Skip the logfilecount test
# skip.logshiptesting                                     False Skip the logshipping test
# skip.security.builtinadmin                               True Skips the scan for BUILTIN\Administr…
# skip.security.containedbautoclose                        True Skips the scan for contained databas…
# skip.security.guestuserconnect                           True Skips the scan for guest user have C…
# skip.security.localwindowsgroup                          True Skips the scan for if local windows …
# skip.security.loginauditlevelfailed                      True Skips the scan for if server login l…
# skip.security.loginauditlevelsucce…                      True Skips the scan for if server login l…
# skip.security.publicrolepermission                       True Skips the scan for if the public ser…
# skip.security.sadisabled                                 True Skip the check for if the sa login i…
# skip.security.saexist                                    True Skip the check for a login named sa …
# skip.tempdb1118                                         False Don't run test for Trace Flag 1118
# skip.tempdbfilecount                                    False Don't run test for Temp Database Fil…
# skip.tempdbfilegrowthpercent                            False Don't run test for Temp Database Fil…
# skip.tempdbfilesizemax                                  False Don't run test for Temp Database Fil…
# skip.tempdbfilesonc                                     False Don't run test for Temp Database Fil…
# testing.integration.instance                      {localhost} Default SQL Server instances to be u…

# %% [markdown]
# # Run the Checks with that configuration
#
# You can then run the checks with that configuration as usual. You do not need to specify the computer names or Instance names as they are in the configuration already. You will reset the configuration, load the configuration from the file and run the checks
#
# It will take about  30 seconds or so

# %%
$FolderPath = $Env:USERPROFILE + '\Documents\dbachecks'
$SqlCredential = Import-Clixml -Path $FolderPath\sqladmin.cred
# Just in case the config has been altered
$null = Reset-DbcConfig
$null = Import-DbcConfig -Path $FolderPath\Morning-Checks-Production.json 
$invokeDbcCheckSplat = @{

    SqlCredential = $SqlCredential
    Check = 'InstanceConnection', 'FailedJob', 'LastBackup', 'ErrorLog', 'DiskCapacity', 'MemoryDump', 'LastJobRunTime', 'LongRunningJob', 'LogfileSize', 'FutureFileGrowth'
}
Invoke-DbcCheck @invokeDbcCheckSplat
# Out:
#     ____            __
#    / __ \___  _____/ /____  _____
#   / /_/ / _ \/ ___/ __/ _ \/ ___/
#  / ____/  __(__  ) /_/  __/ /
# /_/    \___/____/\__/\___/_/
# Pester v4.9.0
# Executing all tests in 'C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Agent.Tests.ps1', 'C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1', 'C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1', 'C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Server.Tests.ps1' with Tags InstanceConnection', 'FailedJob', 'LastBackup', 'ErrorLog', 'DiskCapacity', 'MemoryDump', 'LastJobRunTime', 'LongRunningJob', 'LogfileSize', 'FutureFileGrowth
#
# Executing script C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Agent.Tests.ps1
#
#   Describing Failed Jobs
#
#     Context Checking for failed enabled jobs since 02/13/2020 18:31:11 on localhost,15592
#
#   Describing Long Running Agent Jobs
#
#     Context Testing long running jobs on localhost,15592
#
#   Describing Last Agent Job Run
#
#   Describing Failed Jobs
#
#     Context Checking for failed enabled jobs since 02/13/2020 18:31:12 on localhost,15593
#
#   Describing Long Running Agent Jobs
#
#     Context Testing long running jobs on localhost,15593
#
#   Describing Last Agent Job Run
#
# Executing script C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1
#
#   Describing Last Full Backup Times
#
#     Context Testing last full backups on localhost,15592
#       [-] AdventureWorks2017 full backups on localhost,15592 should be less than 7 days 73ms
#         Expected the actual value to be greater than 2020-03-07T18:31:14.7585642Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:01.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] master full backups on localhost,15592 should be less than 7 days 11ms
#         Expected the actual value to be greater than 2020-03-07T18:31:14.9407329Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:41:56.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] model full backups on localhost,15592 should be less than 7 days 72ms
#         Expected the actual value to be greater than 2020-03-07T18:31:14.9710804Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:41:56.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] msdb full backups on localhost,15592 should be less than 7 days 10ms
#         Expected the actual value to be greater than 2020-03-07T18:31:15.0569711Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:41:57.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] Northwind full backups on localhost,15592 should be less than 7 days 8ms
#         Expected the actual value to be greater than 2020-03-07T18:31:15.0767669Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:01.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] pubs full backups on localhost,15592 should be less than 7 days 11ms
#         Expected the actual value to be greater than 2020-03-07T18:31:15.0970315Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:02.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#
#   Describing Last Diff Backup Times
#
#     Context Testing last diff backups on localhost,15592
#       [-] AdventureWorks2017 diff backups on localhost,15592 should be less than 24 hours 7ms
#         Expected the actual value to be greater than 2020-03-13T18:31:15.2907294Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:00.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 487
#       [-] Northwind diff backups on localhost,15592 should be less than 24 hours 7ms
#         Expected the actual value to be greater than 2020-03-13T18:31:15.3057918Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:00.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 487
#       [-] pubs diff backups on localhost,15592 should be less than 24 hours 8ms
#         Expected the actual value to be greater than 2020-03-13T18:31:15.3252170Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:00.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 487
#
#   Describing Last Log Backup Times
#
#     Context Testing last log backups on localhost,15592
#
#   Describing Log File Size Checks
#
#     Context Testing Log File size for localhost,15592
#       [+] AdventureWorks2017 on localhost,15592 Should have no log files larger than 50% of the Average of DataFiles 6ms
#       [+] master on localhost,15592 Should have no log files larger than 50% of the Average of DataFiles 3ms
#       [+] model on localhost,15592 Should have no log files larger than 50% of the Average of DataFiles 3ms
#       [+] msdb on localhost,15592 Should have no log files larger than 50% of the Average of DataFiles 2ms
#       [+] Northwind on localhost,15592 Should have no log files larger than 50% of the Average of DataFiles 2ms
#       [+] pubs on localhost,15592 Should have no log files larger than 50% of the Average of DataFiles 5ms
#       [+] tempdb on localhost,15592 Should have no log files larger than 50% of the Average of DataFiles 3ms
#
#   Describing Future File Growth
#
#     Context Testing for files likely to grow soon on localhost,15592
#       [+] AdventureWorks2017 file AdventureWorks2017 on 97b41bdb09c7 has free space under threshold 28ms
#       [+] AdventureWorks2017 file AdventureWorks2017_log on 97b41bdb09c7 has free space under threshold 4ms
#       [-] master file master on 97b41bdb09c7 has free space under threshold 12ms
#         Expected the actual value to be greater than or equal to 10, because free space within the file should be lower than threshold of 10 %, but got 0.951999999999998.
#         612:                                 $PSItem.PercentFree | Should -BeGreaterOrEqual $threshold -Because "free space within the file should be lower than threshold of $threshold %"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 612
#       [+] master file mastlog on 97b41bdb09c7 has free space under threshold 2ms
#       [+] model file modeldev on 97b41bdb09c7 has free space under threshold 2ms
#       [+] model file modellog on 97b41bdb09c7 has free space under threshold 6ms
#       [-] msdb file MSDBData on 97b41bdb09c7 has free space under threshold 8ms
#         Expected the actual value to be greater than or equal to 10, because free space within the file should be lower than threshold of 10 %, but got 1.69499999999999.
#         612:                                 $PSItem.PercentFree | Should -BeGreaterOrEqual $threshold -Because "free space within the file should be lower than threshold of $threshold %"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 612
#       [+] msdb file MSDBLog on 97b41bdb09c7 has free space under threshold 4ms
#       [+] Northwind file Northwind on 97b41bdb09c7 has free space under threshold 3ms
#       [+] Northwind file Northwind_log on 97b41bdb09c7 has free space under threshold 5ms
#       [+] pubs file pubs on 97b41bdb09c7 has free space under threshold 6ms
#       [+] pubs file pubs_log on 97b41bdb09c7 has free space under threshold 4ms
#       [+] tempdb file tempdev on 97b41bdb09c7 has free space under threshold 4ms
#       [+] tempdb file templog on 97b41bdb09c7 has free space under threshold 3ms
#       [+] tempdb file tempdev2 on 97b41bdb09c7 has free space under threshold 5ms
#       [+] tempdb file tempdev3 on 97b41bdb09c7 has free space under threshold 4ms
#       [+] tempdb file tempdev4 on 97b41bdb09c7 has free space under threshold 8ms
#
#   Describing Last Full Backup Times
#
#     Context Testing last full backups on localhost,15593
#       [-] AdventureWorks2017 full backups on localhost,15593 should be less than 7 days 6ms
#         Expected the actual value to be greater than 2020-03-07T18:31:21.4074130Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:01.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] master full backups on localhost,15593 should be less than 7 days 7ms
#         Expected the actual value to be greater than 2020-03-07T18:31:21.4219593Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:41:56.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] model full backups on localhost,15593 should be less than 7 days 6ms
#         Expected the actual value to be greater than 2020-03-07T18:31:21.4362184Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:41:56.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] msdb full backups on localhost,15593 should be less than 7 days 7ms
#         Expected the actual value to be greater than 2020-03-07T18:31:21.4500050Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:41:57.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] Northwind full backups on localhost,15593 should be less than 7 days 13ms
#         Expected the actual value to be greater than 2020-03-07T18:31:21.4640976Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:01.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] pubs full backups on localhost,15593 should be less than 7 days 6ms
#         Expected the actual value to be greater than 2020-03-07T18:31:21.4868497Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:02.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#
#   Describing Last Diff Backup Times
#
#     Context Testing last diff backups on localhost,15593
#       [-] AdventureWorks2017 diff backups on localhost,15593 should be less than 24 hours 5ms
#         Expected the actual value to be greater than 2020-03-13T18:31:21.6769075Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:00.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 487
#       [-] Northwind diff backups on localhost,15593 should be less than 24 hours 7ms
#         Expected the actual value to be greater than 2020-03-13T18:31:21.6901272Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:00.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 487
#       [-] pubs diff backups on localhost,15593 should be less than 24 hours 8ms
#         Expected the actual value to be greater than 2020-03-13T18:31:21.7066212Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:00.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 487
#
#   Describing Last Log Backup Times
#
#     Context Testing last log backups on localhost,15593
#
#   Describing Log File Size Checks
#
#     Context Testing Log File size for localhost,15593
#       [+] AdventureWorks2017 on localhost,15593 Should have no log files larger than 50% of the Average of DataFiles 1ms
#       [+] master on localhost,15593 Should have no log files larger than 50% of the Average of DataFiles 3ms
#       [+] model on localhost,15593 Should have no log files larger than 50% of the Average of DataFiles 3ms
#       [+] msdb on localhost,15593 Should have no log files larger than 50% of the Average of DataFiles 3ms
#       [+] Northwind on localhost,15593 Should have no log files larger than 50% of the Average of DataFiles 3ms
#       [+] pubs on localhost,15593 Should have no log files larger than 50% of the Average of DataFiles 1ms
#       [+] tempdb on localhost,15593 Should have no log files larger than 50% of the Average of DataFiles 3ms
#
#   Describing Future File Growth
#
#     Context Testing for files likely to grow soon on localhost,15593
#       [+] AdventureWorks2017 file AdventureWorks2017 on c2192602e462 has free space under threshold 2ms
#       [+] AdventureWorks2017 file AdventureWorks2017_log on c2192602e462 has free space under threshold 2ms
#       [-] master file master on c2192602e462 has free space under threshold 4ms
#         Expected the actual value to be greater than or equal to 10, because free space within the file should be lower than threshold of 10 %, but got 0.951999999999998.
#         612:                                 $PSItem.PercentFree | Should -BeGreaterOrEqual $threshold -Because "free space within the file should be lower than threshold of $threshold %"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 612
#       [+] master file mastlog on c2192602e462 has free space under threshold 1ms
#       [+] model file modeldev on c2192602e462 has free space under threshold 1ms
#       [+] model file modellog on c2192602e462 has free space under threshold 1ms
#       [-] msdb file MSDBData on c2192602e462 has free space under threshold 3ms
#         Expected the actual value to be greater than or equal to 10, because free space within the file should be lower than threshold of 10 %, but got 1.69499999999999.
#         612:                                 $PSItem.PercentFree | Should -BeGreaterOrEqual $threshold -Because "free space within the file should be lower than threshold of $threshold %"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 612
#       [+] msdb file MSDBLog on c2192602e462 has free space under threshold 1ms
#       [+] Northwind file Northwind on c2192602e462 has free space under threshold 1ms
#       [+] Northwind file Northwind_log on c2192602e462 has free space under threshold 2ms
#       [+] pubs file pubs on c2192602e462 has free space under threshold 2ms
#       [+] pubs file pubs_log on c2192602e462 has free space under threshold 2ms
#       [+] tempdb file tempdev on c2192602e462 has free space under threshold 1ms
#       [+] tempdb file templog on c2192602e462 has free space under threshold 3ms
#       [+] tempdb file tempdev2 on c2192602e462 has free space under threshold 3ms
#       [+] tempdb file tempdev3 on c2192602e462 has free space under threshold 3ms
#       [+] tempdb file tempdev4 on c2192602e462 has free space under threshold 3ms
#
# Executing script C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on localhost,15592
#       [+] connects successfully to localhost,15592 6ms
#       [+] auth scheme should be SQL on localhost,15592 155ms
#       [+] localhost,15592 is pingable 16ms
#       [!] localhost,15592 Is PSRemoteable, is skipped 0ms
#
#   Describing SQL Memory Dumps
#
#     Context Checking that dumps on localhost,15592 do not exceed 1 for localhost,15592
#       [+] dump count of  is less than or equal to the 1 dumps on localhost,15592 8ms
#
#   Describing Error Log Entries
#
#     Context Checking error log on localhost,15592
#       [+] Error log should be free of error severities 17-24 on localhost,15592 9ms
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on localhost,15593
#       [+] connects successfully to localhost,15593 2ms
#       [+] auth scheme should be SQL on localhost,15593 110ms
#       [+] localhost,15593 is pingable 5ms
#       [!] localhost,15593 Is PSRemoteable, is skipped 0ms
#
#   Describing SQL Memory Dumps
#
#     Context Checking that dumps on localhost,15593 do not exceed 1 for localhost,15593
#       [+] dump count of  is less than or equal to the 1 dumps on localhost,15593 2ms
#
#   Describing Error Log Entries
#
#     Context Checking error log on localhost,15593
#       [+] Error log should be free of error severities 17-24 on localhost,15593 2ms
#
# Executing script C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Server.Tests.ps1
#
#   Describing Disk Space
#
#     Context Testing Disk Space on localhost,15592
#       [+] C:\ with 48.8% free should be at least 10% free on localhost 10ms
#
#   Describing Disk Space
#
#     Context Testing Disk Space on localhost,15593
#       [+] C:\ with 48.8% free should be at least 10% free on localhost 25ms
# Tests completed in 18.73s
# Tests Passed: 56, Failed: 22, Skipped: 2, Pending: 0, Inconclusive: 0

# %% [markdown]
# ## Only showing the failures
#
# This will run 91 checks and most will pass. To avoid filling our buffer will all the checks that have passed, we can only display the failed checks using the `-Show` parameter with the `Fails` value. (NOTE - This is a better option than `Failed` which will only show the failed tests and no context for them)

# %%
$invokeDbcCheckSplat = @{
    SqlCredential = $SqlCredential
    Check = 'InstanceConnection', 'FailedJob', 'LastBackup', 'ErrorLog', 'DiskCapacity', 'MemoryDump', 'LastJobRunTime', 'LongRunningJob', 'LogfileSize', 'FutureFileGrowth'
    Show = 'Fails'
}
Invoke-DbcCheck @invokeDbcCheckSplat
# Out:
#     ____            __
#    / __ \___  _____/ /____  _____
#   / /_/ / _ \/ ___/ __/ _ \/ ___/
#  / ____/  __(__  ) /_/  __/ /
# /_/    \___/____/\__/\___/_/
# Pester v4.9.0
# Executing all tests in 'C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Agent.Tests.ps1', 'C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1', 'C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1', 'C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Server.Tests.ps1' with Tags InstanceConnection', 'FailedJob', 'LastBackup', 'ErrorLog', 'DiskCapacity', 'MemoryDump', 'LastJobRunTime', 'LongRunningJob', 'LogfileSize', 'FutureFileGrowth
#
# Executing script C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Agent.Tests.ps1
#
#   Describing Failed Jobs
#
#     Context Checking for failed enabled jobs since 02/13/2020 18:31:45 on localhost,15592
#
#   Describing Long Running Agent Jobs
#
#     Context Testing long running jobs on localhost,15592
#
#   Describing Last Agent Job Run
#
#   Describing Failed Jobs
#
#     Context Checking for failed enabled jobs since 02/13/2020 18:31:46 on localhost,15593
#
#   Describing Long Running Agent Jobs
#
#     Context Testing long running jobs on localhost,15593
#
#   Describing Last Agent Job Run
#
# Executing script C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1
#
#   Describing Last Full Backup Times
#
#     Context Testing last full backups on localhost,15592
#       [-] AdventureWorks2017 full backups on localhost,15592 should be less than 7 days 4ms
#         Expected the actual value to be greater than 2020-03-07T18:31:48.1423310Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:01.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] master full backups on localhost,15592 should be less than 7 days 7ms
#         Expected the actual value to be greater than 2020-03-07T18:31:48.1532591Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:41:56.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] model full backups on localhost,15592 should be less than 7 days 6ms
#         Expected the actual value to be greater than 2020-03-07T18:31:48.1674284Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:41:56.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] msdb full backups on localhost,15592 should be less than 7 days 7ms
#         Expected the actual value to be greater than 2020-03-07T18:31:48.1851844Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:41:57.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] Northwind full backups on localhost,15592 should be less than 7 days 7ms
#         Expected the actual value to be greater than 2020-03-07T18:31:48.2014771Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:01.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] pubs full backups on localhost,15592 should be less than 7 days 10ms
#         Expected the actual value to be greater than 2020-03-07T18:31:48.2162464Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:02.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#
#   Describing Last Diff Backup Times
#
#     Context Testing last diff backups on localhost,15592
#       [-] AdventureWorks2017 diff backups on localhost,15592 should be less than 24 hours 7ms
#         Expected the actual value to be greater than 2020-03-13T18:31:48.4439270Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:00.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 487
#       [-] Northwind diff backups on localhost,15592 should be less than 24 hours 8ms
#         Expected the actual value to be greater than 2020-03-13T18:31:48.4619632Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:00.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 487
#       [-] pubs diff backups on localhost,15592 should be less than 24 hours 12ms
#         Expected the actual value to be greater than 2020-03-13T18:31:48.4784550Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:00.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 487
#
#   Describing Last Log Backup Times
#
#     Context Testing last log backups on localhost,15592
#
#   Describing Log File Size Checks
#
#     Context Testing Log File size for localhost,15592
#
#   Describing Future File Growth
#
#     Context Testing for files likely to grow soon on localhost,15592
#       [-] master file master on 97b41bdb09c7 has free space under threshold 8ms
#         Expected the actual value to be greater than or equal to 10, because free space within the file should be lower than threshold of 10 %, but got 0.951999999999998.
#         612:                                 $PSItem.PercentFree | Should -BeGreaterOrEqual $threshold -Because "free space within the file should be lower than threshold of $threshold %"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 612
#       [-] msdb file MSDBData on 97b41bdb09c7 has free space under threshold 6ms
#         Expected the actual value to be greater than or equal to 10, because free space within the file should be lower than threshold of 10 %, but got 1.69499999999999.
#         612:                                 $PSItem.PercentFree | Should -BeGreaterOrEqual $threshold -Because "free space within the file should be lower than threshold of $threshold %"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 612
#
#   Describing Last Full Backup Times
#
#     Context Testing last full backups on localhost,15593
#       [-] AdventureWorks2017 full backups on localhost,15593 should be less than 7 days 9ms
#         Expected the actual value to be greater than 2020-03-07T18:31:52.4122574Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:01.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] master full backups on localhost,15593 should be less than 7 days 9ms
#         Expected the actual value to be greater than 2020-03-07T18:31:52.4288029Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:41:56.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] model full backups on localhost,15593 should be less than 7 days 14ms
#         Expected the actual value to be greater than 2020-03-07T18:31:52.4451710Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:41:56.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] msdb full backups on localhost,15593 should be less than 7 days 9ms
#         Expected the actual value to be greater than 2020-03-07T18:31:52.4665663Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:41:57.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] Northwind full backups on localhost,15593 should be less than 7 days 8ms
#         Expected the actual value to be greater than 2020-03-07T18:31:52.4875750Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:01.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] pubs full backups on localhost,15593 should be less than 7 days 7ms
#         Expected the actual value to be greater than 2020-03-07T18:31:52.5068328Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:02.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#
#   Describing Last Diff Backup Times
#
#     Context Testing last diff backups on localhost,15593
#       [-] AdventureWorks2017 diff backups on localhost,15593 should be less than 24 hours 9ms
#         Expected the actual value to be greater than 2020-03-13T18:31:52.7502824Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:00.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 487
#       [-] Northwind diff backups on localhost,15593 should be less than 24 hours 5ms
#         Expected the actual value to be greater than 2020-03-13T18:31:52.7703658Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:00.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 487
#       [-] pubs diff backups on localhost,15593 should be less than 24 hours 6ms
#         Expected the actual value to be greater than 2020-03-13T18:31:52.7827517Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:00.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 487
#
#   Describing Last Log Backup Times
#
#     Context Testing last log backups on localhost,15593
#
#   Describing Log File Size Checks
#
#     Context Testing Log File size for localhost,15593
#
#   Describing Future File Growth
#
#     Context Testing for files likely to grow soon on localhost,15593
#       [-] master file master on c2192602e462 has free space under threshold 7ms
#         Expected the actual value to be greater than or equal to 10, because free space within the file should be lower than threshold of 10 %, but got 0.951999999999998.
#         612:                                 $PSItem.PercentFree | Should -BeGreaterOrEqual $threshold -Because "free space within the file should be lower than threshold of $threshold %"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 612
#       [-] msdb file MSDBData on c2192602e462 has free space under threshold 13ms
#         Expected the actual value to be greater than or equal to 10, because free space within the file should be lower than threshold of 10 %, but got 1.69499999999999.
#         612:                                 $PSItem.PercentFree | Should -BeGreaterOrEqual $threshold -Because "free space within the file should be lower than threshold of $threshold %"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 612
#
# Executing script C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on localhost,15592
#       [!] localhost,15592 Is PSRemoteable, is skipped 0ms
#
#   Describing SQL Memory Dumps
#
#     Context Checking that dumps on localhost,15592 do not exceed 1 for localhost,15592
#
#   Describing Error Log Entries
#
#     Context Checking error log on localhost,15592
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on localhost,15593
#       [!] localhost,15593 Is PSRemoteable, is skipped 0ms
#
#   Describing SQL Memory Dumps
#
#     Context Checking that dumps on localhost,15593 do not exceed 1 for localhost,15593
#
#   Describing Error Log Entries
#
#     Context Checking error log on localhost,15593
#
# Executing script C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Server.Tests.ps1
#
#   Describing Disk Space
#
#     Context Testing Disk Space on localhost,15592
#
#   Describing Disk Space
#
#     Context Testing Disk Space on localhost,15593
# Tests completed in 13.98s
# Tests Passed: 56, Failed: 22, Skipped: 2, Pending: 0, Inconclusive: 0

# %% [markdown]
# # Configuration for New Instance
#
# You might want to create a configuration to run after a new instance has been set up
#
# This might require the following configurations (other settings will also be checked with default configurations)
#
# - Database mail has been set up
# - Operators and Failsafe Operators are set up
# - Agent Jobs are owned by the correct account
# - Agent Alerts are set up correctly
# - Job History settings are set up correctly
# - Ola Hallengrens Maintenance solution is set up as expected
# - The expected Extended Events sessions are installed and running
# - The correct Error Logs Setting

# %%
# reset the configuration
$null = Reset-DbcConfig
# Set Checks to exclude (these wont run on containers)
Set-DbcConfig -Name command.invokedbccheck.excludecheck -Value FailsafeOperator,DatabaseMailEnabled,DatabaseMailProfile,SqlEngineServiceAccount,OrphanedFile,ServerNameMatch
# Set the auth scheme to SQL as we are using SQL Auth
Set-DbcConfig -Name policy.connection.authscheme -Value SQL
# Don't check the PSRemoting
Set-DbcConfig -Name skip.connection.remoting -Value $true
# Set config for expected Operators
Set-DbcConfig -Name agent.dbaoperatorname -Value SQLAdmins
# Set COnfig for operators email address
Set-DbcConfig -Name agent.dbaoperatoremail -Value SQLAdmins@TheBeard.local
# Set config for the expected job owner
Set-DbcConfig -Name agent.validjobowner.name -Value OldSa
# Set config for expected agent alerts
$Ids = '1101','1105','1121','1214','17130','17179','17300','17883','17884','17887','17888','17890','2508','2511','28036','3271','3452','3619','3624','5180','5228','5229','5242','5243','5250','5572','5901','605','701','802','823','824','825','832','833','845','855','856','8966','9002','9100'
Set-DbcConfig -Name agent.alert.messageid -Value $Ids
# Set the config for the job history settings
Set-DbcConfig -Name agent.history.maximumhistoryrows -Value 1000
Set-DbcConfig -Name agent.history.maximumjobhistoryrows -Value 100
# Set config for the extended events
Set-DbcConfig -Name policy.xevent.requiredrunningsession -Value '15 Second IO Error','Blocked Process Report','Stored Procedure Parameters' 
# Sets Error log - Its a container!
Set-DbcConfig -Name policy.errorlog.logcount -Value -1
# Set Remote Access configuration
Set-DbcConfig -Name skip.instance.remoteaccessdisabled -Value $true
# Out:
# Name                                 Value
# ----                                 -----
# command.invokedbccheck.excludecheck  {FailsafeOperator, DatabaseMailEnabled, DatabaseMailProfile, …
# policy.connection.authscheme         SQL
# skip.connection.remoting             True
# agent.dbaoperatorname                SQLAdmins
# agent.dbaoperatoremail               SQLAdmins@TheBeard.local
# agent.validjobowner.name             OldSa
# agent.alert.messageid                {1101, 1105, 1121, 1214…}
# agent.history.maximumhistoryrows     1000
# agent.history.maximumjobhistoryrows  100
# policy.xevent.requiredrunningsession {15 Second IO Error, Blocked Process Report, Stored Procedure…
# policy.errorlog.logcount             -1
# skip.instance.remoteaccessdisabled   True

# %% [markdown]
# With the configuration created you can save it to a file

# %%
$FolderPath = $Env:USERPROFILE + '\Documents\dbachecks'
Export-DbcConfig -Path $FolderPath\New-Instance.json
# Out:
# [18:32:12][Export-DbcConfig] Wrote file to C:\Users\mrrob\Documents\dbachecks\New-Instance.json

# %% [markdown]
# You can then load that configuration and run it. This will take a couple of minutes to run, be patient.

# %%
# Just in case the config has been altered
$null = Reset-DbcConfig
$null = Import-DbcConfig -Path $FolderPath\New-Instance.json 
$invokeDbcCheckSplat = @{
    SqlInstance = 'localhost,15592'
    SqlCredential = $SqlCredential
    Check = 'Instance','Agent'
    Show = 'Fails'
}
Invoke-DbcCheck @invokeDbcCheckSplat
# Out:
#     ____            __
#    / __ \___  _____/ /____  _____
#   / /_/ / _ \/ ___/ __/ _ \/ ___/
#  / ____/  __(__  ) /_/  __/ /
# /_/    \___/____/\__/\___/_/
# Pester v4.9.0
# Executing all tests in 'C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Agent.Tests.ps1', 'C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1' with Tags Instance', 'Agent
#
# Executing script C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Agent.Tests.ps1
#
#   Describing SQL Agent Account
#     [!] Running on Linux or connecting to container so can't check Services on localhost,15592, is skipped 0ms
#
#   Describing DBA Operators
#
#     Context Testing DBA Operators exists on localhost,15592
#
#   Describing Failed Jobs
#
#     Context Checking for failed enabled jobs since 02/13/2020 18:32:24 on localhost,15592
#
#   Describing Valid Job Owner
#
#     Context Testing job owners on localhost,15592
#       [-] Job The Beard is Important  - owner sqladmin should be in this list ( OldSa ) on 97b41bdb09c7 4ms
#         Expected collection OldSa to contain 'sqladmin', because The account that is the job owner is not what was expected, but it was not found.
#         191:                                     $psitem.OwnerLoginName | Should -BeIn $TargetOwner -Because "The account that is the job owner is not what was expected"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Agent.Tests.ps1: line 191
#
#   Describing Agent Alerts
#
#     Context Testing Agent Alerts Severity exists on localhost,15592
#
#     Context Testing Agent Alerts MessageID exists on localhost,15592
#
#   Describing Job History Configuration
#
#     Context Testing job history configuration on localhost,15592
#
#   Describing Long Running Agent Jobs
#
#     Context Testing long running jobs on localhost,15592
#
#   Describing Last Agent Job Run
#
# Executing script C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on localhost,15592
#       [!] localhost,15592 Is PSRemoteable, is skipped 0ms
#
#   Describing TempDB Configuration
#
#     Context Testing TempDB Configuration on localhost,15592
#       [!] should have TF1118 enabled on 97b41bdb09c7, is skipped 0ms
#
#   Describing Ad Hoc Workload Optimization
#
#     Context Testing Ad Hoc Workload Optimization on localhost,15592
#
#   Describing Backup Path Access
#
#     Context Testing Backup Path Access on localhost,15592
#
#   Describing Default File Path
#
#     Context Testing Default Data File Path on localhost,15592
#
#     Context Testing Default Log File Path on localhost,15592
#
#   Describing Dedicated Administrator Connection
#
#     Context Testing Dedicated Administrator Connection on localhost,15592
#
#   Describing Network Latency
#
#     Context Testing Network Latency on localhost,15592
#
#   Describing Linked Servers
#
#     Context Testing Linked Servers on localhost,15592
#
#   Describing Max Memory
#
#     Context Testing Max Memory on localhost,15592
#       [-] Max Memory setting should be correct on localhost,15592 1.72s
#         DivideByZeroException: Attempted to divide by zero.
#         RuntimeException: Attempted to divide by zero.
#         at Test-DbaMaxMemory<Process>, C:\Users\mrrob\Documents\PowerShell\Modules\dbatools\1.0.100\allcommands.ps1: line 72154
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1: line 294
#
#   Describing SQL Memory Dumps
#
#     Context Checking that dumps on localhost,15592 do not exceed 1 for localhost,15592
#
#   Describing Supported Build
#
#     Context Checking that build is still supportedby Microsoft for localhost,15592
#
#   Describing SA Login Renamed
#
#     Context Checking that sa login has been renamed on localhost,15592
#
#   Describing SA Login Disabled
#
#     Context Checking that sa login has been disabled on localhost,15592
#       [!] sa login is disabled on localhost,15592, is skipped 0ms
#
#   Describing Login SA cannot exist
#
#     Context Checking that a login named sa does not exist on localhost,15592
#       [!] sa login does not exist on localhost,15592, is skipped 0ms
#
#   Describing Default Backup Compression
#
#     Context Testing Default Backup Compression on localhost,15592
#
#   Describing XE Sessions That should be Stopped
# WARNING: You need to use Set-DbcConfig -Name policy.xevent.requiredstoppedsession -Value to add some Extended Events session names to run this check
#
#   Describing XE Sessions That should be Running
#
#     Context Checking running sessions on localhost,15592
#
#   Describing XE Sessions That Are Allowed to Be Running
# WARNING: You need to use Set-DbcConfig -Name policy.xevent.validrunningsession -Value to add some Extended Events session names to run this check
#
#   Describing OLE Automation
#
#     Context Testing OLE Automation on localhost,15592
#
#   Describing sp_whoisactive is Installed
#
#     Context Testing WhoIsActive exists on localhost,15592
#
#   Describing Model Database Growth
#
#     Context Testing model database growth setting is not default on localhost,15592
#
#   Describing Ad Users and Groups
#
#     Context Testing Active Directory users on localhost,15592
#
#     Context Testing Active Directory groups on localhost,15592
#
#   Describing Error Log Entries
#
#     Context Checking error log on localhost,15592
#       [-] Error log should be free of error severities 17-24 on localhost,15592 21ms
#         Expected $null or empty, because these severities indicate serious problems, but got @(@{LogDate=Do not know the Date; ProcessInfo=Do not know the Process; Text=Do not know the Test; InstanceName=An Error occurred [localhost,15592]}).
#         710:     $AllInstanceInfo.ErrorLog | Should -BeNullOrEmpty -Because "these severities indicate serious problems"
#         at Assert-ErrorLogEntry, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\internal\assertions\Instance.Assertions.ps1: line 710
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1: line 693
#
#   Describing Error Log Count
#
#     Context Checking error log count on localhost,15592
#
#   Describing Instance MaxDop
#
#     Context Testing Instance MaxDop Value on localhost,15592
#
#   Describing Two Digit Year Cutoff
#
#     Context Testing Two Digit Year Cutoff on localhost,15592
#
#   Describing Trace Flags Expected
#
#     Context Testing Expected Trace Flags on localhost,15592
#
#   Describing Trace Flags Not Expected
#
#     Context Testing Not Expected Trace Flags on localhost,15592
#
#   Describing CLR Enabled
#
#     Context Testing CLR Enabled on localhost,15592
#
#   Describing Cross Database Ownership Chaining
#
#     Context Testing Cross Database Ownership Chaining on localhost,15592
#       [-] Cross Database Ownership Chaining should be disabled on localhost,15592 10ms
#         Expected 0, because We expected the Cross DB Ownership Chaining to be disabled, but got 'We Could not Connect to $Instance'.
#         683:     $AllInstanceInfo.CrossDBOwnershipChaining.ConfiguredValue | Should -Be 0 -Because "We expected the Cross DB Ownership Chaining to be disabled"
#         at Assert-CrossDBOwnershipChaining, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\internal\assertions\Instance.Assertions.ps1: line 683
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1: line 820
#
#   Describing Ad Hoc Distributed Queries
#
#     Context Testing Ad Hoc Distributed Queries on localhost,15592
#
#   Describing XP CmdShell
#
#     Context Testing XP CmdShell on localhost,15592
#
#   Describing Scan For Startup Procedures
#
#     Context Testing Scan For Startup Procedures on localhost,15592
#       [-] Scan For Startup Procedures should be disabled on localhost,15592 8ms
#         Expected 0, because We expected the scan for startup procedures to be disabled, but got 'We Could not Connect to $Instance'.
#         563:     $AllInstanceInfo.ScanForStartupProceduresDisabled.ConfiguredValue | Should -Be 0 -Because "We expected the scan for startup procedures to be disabled"
#         at Assert-ScanForStartupProcedures, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\internal\assertions\Instance.Assertions.ps1: line 563
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1: line 872
#
#   Describing Default Trace
#
#     Context Checking Default Trace on localhost,15592
#       [-] The Default Trace should be enabled on localhost,15592 9ms
#         Expected 1, because We expected the Default Trace to be enabled, but got 'We Could not Connect to $Instance'.
#         538:     $AllInstanceInfo.DefaultTrace.ConfiguredValue | Should -Be 1 -Because "We expected the Default Trace to be enabled"
#         at Assert-DefaultTrace, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\internal\assertions\Instance.Assertions.ps1: line 538
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1: line 889
#
#   Describing OLE Automation Procedures Disabled
#
#     Context Checking OLE Automation Procedures on localhost,15592
#       [-] The OLE Automation Procedures should be disabled on localhost,15592 7ms
#         Expected 0, because We expect the OLE Automation Procedures to be disabled, but got 'We Could not Connect to $Instance'.
#         557:     $AllInstanceInfo.OleAutomationProceduresDisabled.ConfiguredValue | Should -Be 0 -Because "We expect the OLE Automation Procedures to be disabled"
#         at Assert-OleAutomationProcedures, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\internal\assertions\Instance.Assertions.ps1: line 557
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1: line 906
#
#   Describing Remote Access Disabled
#
#     Context Testing Remote Access on localhost,15592
#       [!] The Remote Access should be disabled on localhost,15592, is skipped 0ms
#
#   Describing Latest Build
#
#     Context Testing Latest Build on localhost,15592
#
#   Describing Login BUILTIN Administrators cannot exist
#
#     Context Checking that a login named BUILTIN\Administrators does not exist on localhost,15592
#       [!] BUILTIN\Administrators login does not exist on localhost,15592, is skipped 0ms
#
#   Describing Local Windows Groups Not Have SQL Logins
#
#     Context Checking that local Windows groups do not have SQL Logins on localhost,15592
#       [!] Local Windows groups should not SQL Logins on localhost,15592, is skipped 0ms
#
#   Describing Failed Login Auditing
#
#     Context Testing if failed login auditing is in place on localhost,15592
#       [!] The failed login auditing should be set on localhost,15592, is skipped 0ms
#
#   Describing Successful Login Auditing
#
#     Context Testing if successful and failed login auditing is in place on localhost,15592
#       [!] The successful and failed auditng should be set on localhost,15592, is skipped 0ms
#
#   Describing SQL Browser Service
# WARNING: [18:32:41][Get-ComputerName] You must specify -ComputerName or use Set-DbcConfig app.computername to setup a list of servers
# Tests completed in 18.91s
# Tests Passed: 204, Failed: 7, Skipped: 10, Pending: 0, Inconclusive: 0

# %% [markdown]
# # Configuration for Weekly Check
#
# This configuration could be used for a weekly check of an estate. It includes
#
# - Failed jobs in the last 2 days - I ran this on a Sunday so checking weekend maintenance

# %%
# reset the configuration
$null = Reset-DbcConfig
# Set Checks to exclude (these wont run on containers)
Set-DbcConfig -Name command.invokedbccheck.excludecheck -Value FailsafeOperator,DatabaseMailEnabled,DatabaseMailProfile,SqlEngineServiceAccount,OrphanedFile,ServerNameMatch, SqlBrowserServiceAccount
# Set the instances and computernames to run the check against
Set-DbcConfig -Name app.sqlinstance -Value 'localhost,15592','localhost,15593'
Set-DbcConfig -Name app.computername -Value 'localhost,15592','localhost,15593'
# Set the auth scheme to SQL as we are using SQL Auth
Set-DbcConfig -Name policy.connection.authscheme -Value SQL
# Don't check the PSRemoting
Set-DbcConfig -Name skip.connection.remoting -Value $true
Set-DbcConfig -Name agent.failedjob.since -Value 2
# COnfig for build warning
Set-DbcConfig -Name policy.build.behind	-Value 1SP
Set-DbcConfig -Name policy.build.warningwindow	-Value 2
# COnfig for when we want to know certs are going to expire
Set-DbcConfig -Name policy.certificateexpiration.warningwindow -Value 2	
# How different can our files be in a filegroup
Set-DbcConfig -Name policy.database.filebalancetolerance -Value 3
# Free Space in file
Set-DbcConfig -Name policy.database.filegrowthfreespacethreshold 10
# How big can our log file be in comparison to our data files
Set-DbcConfig -Name policy.database.logfilesizecomparison -Value average	
Set-DbcConfig -Name policy.database.logfilesizepercentage -Value 50
# max number of VLFs allowed
Set-DbcConfig -Name policy.database.maxvlf 256
# Last DBCC
Set-DbcConfig -Name policy.dbcc.maxdays -Value 3
#Disk Space
Set-DbcConfig -Name policy.diskspace.percentfree -Value 5
# Set config for the expected job owner
Set-DbcConfig -Name agent.validjobowner.name -Value OldSa
# Set config for expected agent alerts
$Ids = '1101','1105','1121','1214','17130','17179','17300','17883','17884','17887','17888','17890','2508','2511','28036','3271','3452','3619','3624','5180','5228','5229','5242','5243','5250','5572','5901','605','701','802','823','824','825','832','833','845','855','856','8966','9002','9100'
Set-DbcConfig -Name agent.alert.messageid -Value $Ids
# Set the config for the job history settings
Set-DbcConfig -Name agent.history.maximumhistoryrows -Value 1000
Set-DbcConfig -Name agent.history.maximumjobhistoryrows -Value 100
# Set config for the extended events
Set-DbcConfig -Name policy.xevent.requiredrunningsession -Value '15 Second IO Error','Blocked Process Report','Stored Procedure Parameters' 
# Set Database owners
Set-DbcConfig -Name policy.invaliddbowner.name -Value OldSa
Set-DbcConfig -Name policy.validdbowner.name -Value sqladmin

Set-DbcConfig -Name database.exists -Value 'pubs','NorthWind','AdventureWorks2017' -Append
# Out:
# Name                                         Value
# ----                                         -----
# command.invokedbccheck.excludecheck          {FailsafeOperator, DatabaseMailEnabled, DatabaseMailP…
# app.sqlinstance                              {localhost,15592, localhost,15593}
# app.computername                             {localhost,15592, localhost,15593}
# policy.connection.authscheme                 SQL
# skip.connection.remoting                     True
# agent.failedjob.since                        2
# policy.build.behind                          1SP
# policy.build.warningwindow                   2
# policy.certificateexpiration.warningwindow   2
# policy.database.filebalancetolerance         3
# policy.database.filegrowthfreespacethreshold 10
# policy.database.logfilesizecomparison        average
# policy.database.logfilesizepercentage        50
# policy.database.maxvlf                       256
# policy.dbcc.maxdays                          3
# policy.diskspace.percentfree                 5
# agent.validjobowner.name                     OldSa
# agent.alert.messageid                        {1101, 1105, 1121, 1214…}
# agent.history.maximumhistoryrows             1000
# agent.history.maximumjobhistoryrows          100
# policy.xevent.requiredrunningsession         {15 Second IO Error, Blocked Process Report, Stored P…
# policy.invaliddbowner.name                   OldSa
# policy.validdbowner.name                     sqladmin
# database.exists                              {master, msdb, tempdb, model…}

# %% [markdown]
# and save it

# %%
$FolderPath = $Env:USERPROFILE + '\Documents\dbachecks'
Export-DbcConfig -Path $FolderPath\Weekly-Check.json
# Out:
# [18:32:58][Export-DbcConfig] Wrote file to C:\Users\mrrob\Documents\dbachecks\Weekly-Check.json

# %% [markdown]
# load it and run it.
#
# This will run nearly 900 tests and takes a minute or so

# %%
$FolderPath = $Env:USERPROFILE + '\Documents\dbachecks'
$SqlCredential = Import-Clixml -Path $FolderPath\sqladmin.cred
# Just in case the config has been altered
$null = Reset-DbcConfig
$null = Import-DbcConfig -Path $FolderPath\Weekly-Check.json 
$invokeDbcCheckSplat = @{
    SqlInstance = 'localhost,15592'
    SqlCredential = $SqlCredential
    Check = 'Agent', 'Database','Instance'
    Show = 'Fails'
}
Invoke-DbcCheck @invokeDbcCheckSplat
# Out:
#     ____            __
#    / __ \___  _____/ /____  _____
#   / /_/ / _ \/ ___/ __/ _ \/ ___/
#  / ____/  __(__  ) /_/  __/ /
# /_/    \___/____/\__/\___/_/
# Pester v4.9.0
# Executing all tests in 'C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Agent.Tests.ps1', 'C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1', 'C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1' with Tags Agent', 'Database', 'Instance
#
# Executing script C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Agent.Tests.ps1
#
#   Describing SQL Agent Account
#     [!] Running on Linux or connecting to container so can't check Services on localhost,15592, is skipped 0ms
#
#   Describing DBA Operators
#
#     Context Testing DBA Operators exists on localhost,15592
#
#   Describing Failed Jobs
#
#     Context Checking for failed enabled jobs since 03/12/2020 18:33:08 on localhost,15592
#
#   Describing Valid Job Owner
#
#     Context Testing job owners on localhost,15592
#       [-] Job The Beard is Important  - owner sqladmin should be in this list ( OldSa ) on 97b41bdb09c7 3ms
#         Expected collection OldSa to contain 'sqladmin', because The account that is the job owner is not what was expected, but it was not found.
#         191:                                     $psitem.OwnerLoginName | Should -BeIn $TargetOwner -Because "The account that is the job owner is not what was expected"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Agent.Tests.ps1: line 191
#
#   Describing Agent Alerts
#
#     Context Testing Agent Alerts Severity exists on localhost,15592
#
#     Context Testing Agent Alerts MessageID exists on localhost,15592
#
#   Describing Job History Configuration
#
#     Context Testing job history configuration on localhost,15592
#
#   Describing Long Running Agent Jobs
#
#     Context Testing long running jobs on localhost,15592
#
#   Describing Last Agent Job Run
#
# Executing script C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1
#
#   Describing Database Collation
#
#     Context Testing database collation on localhost,15592
#
#   Describing Suspect Page
#
#     Context Testing suspect pages on localhost,15592
#
#   Describing Last Backup Restore Test
#
#   Describing Last Backup VerifyOnly
#
#     Context VerifyOnly tests of last backups on localhost,15592
#   Describing Valid Database Owner
#
#     Context Testing Database Owners on localhost,15592
#       [-] Database AdventureWorks2017 - owner thebeard should be in this list ( sqladmin ) on localhost,15592 7ms
#         Expected collection sqladmin to contain 'thebeard', because The account that is the database owner is not what was expected, but it was not found.
#         154:                         $psitem.Owner | Should -BeIn $TargetOwner -Because "The account that is the database owner is not what was expected"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 154
#       [-] Database Northwind - owner thebeard should be in this list ( sqladmin ) on localhost,15592 7ms
#         Expected collection sqladmin to contain 'thebeard', because The account that is the database owner is not what was expected, but it was not found.
#         154:                         $psitem.Owner | Should -BeIn $TargetOwner -Because "The account that is the database owner is not what was expected"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 154
#       [-] Database pubs - owner thebeard should be in this list ( sqladmin ) on localhost,15592 8ms
#         Expected collection sqladmin to contain 'thebeard', because The account that is the database owner is not what was expected, but it was not found.
#         154:                         $psitem.Owner | Should -BeIn $TargetOwner -Because "The account that is the database owner is not what was expected"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 154
#
#   Describing Invalid Database Owner
#
#     Context Testing Database Owners on localhost,15592
#
#   Describing Last Good DBCC CHECKDB
#
#     Context Testing Last Good DBCC CHECKDB on localhost,15592
#       [-] last good integrity check for master on 97b41bdb09c7 should be less than 3 days old 7ms
#         Expected the actual value to be greater than 2020-03-11T18:33:24.4565495Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-21T14:41:58.0230000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [-] last good integrity check for model on 97b41bdb09c7 should be less than 3 days old 5ms
#         Expected the actual value to be greater than 2020-03-11T18:33:24.4767182Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-21T14:41:58.6100000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [-] last good integrity check for msdb on 97b41bdb09c7 should be less than 3 days old 6ms
#         Expected the actual value to be greater than 2020-03-11T18:33:24.4947940Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-21T14:41:59.0070000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [-] last good integrity check for AdventureWorks2017 on 97b41bdb09c7 should be less than 3 days old 5ms
#         Expected the actual value to be greater than 2020-03-11T18:33:24.5156108Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-21T14:42:03.4030000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [-] last good integrity check for Northwind on 97b41bdb09c7 should be less than 3 days old 7ms
#         Expected the actual value to be greater than 2020-03-11T18:33:24.5380186Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-21T14:42:06.1930000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#       [-] last good integrity check for pubs on 97b41bdb09c7 should be less than 3 days old 9ms
#         Expected the actual value to be greater than 2020-03-11T18:33:24.5648251Z, because You should have run a DBCC CheckDB inside that time, but got 2019-12-21T14:42:06.5630000.
#         200:                                 $psitem.LastGoodCheckDb | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxdays)) -Because "You should have run a DBCC CheckDB inside that time"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 200
#
#   Describing Column Identity Usage
#
#     Context Testing Column Identity Usage on localhost,15592
#
#   Describing Recovery Model
#
#     Context Testing Recovery Model on localhost,15592
#       [-] msdb should be set to Full on 97b41bdb09c7 9ms
#         Expected 'Full', because You expect this recovery model, but got Simple.
#         262:                         $psitem.RecoveryModel | Should -Be $recoverymodel -Because "You expect this recovery model"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 262
#       [-] AdventureWorks2017 should be set to Full on 97b41bdb09c7 10ms
#         Expected 'Full', because You expect this recovery model, but got Simple.
#         262:                         $psitem.RecoveryModel | Should -Be $recoverymodel -Because "You expect this recovery model"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 262
#       [-] Northwind should be set to Full on 97b41bdb09c7 11ms
#         Expected 'Full', because You expect this recovery model, but got Simple.
#         262:                         $psitem.RecoveryModel | Should -Be $recoverymodel -Because "You expect this recovery model"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 262
#       [-] pubs should be set to Full on 97b41bdb09c7 9ms
#         Expected 'Full', because You expect this recovery model, but got Simple.
#         262:                         $psitem.RecoveryModel | Should -Be $recoverymodel -Because "You expect this recovery model"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 262
#
#   Describing Duplicate Index
#
#     Context Testing duplicate indexes on localhost,15592
#       [-] AdventureWorks2017 on localhost,15592 should return 0 duplicate indexes 1.31s
#         Expected 0, because Duplicate indexes waste disk space and cost you extra IO, CPU, and Memory, but got 2.
#         61:     @(Find-DbaDbDuplicateIndex -SqlInstance $Instance -Database $Database).Count | Should -Be 0 -Because "Duplicate indexes waste disk space and cost you extra IO, CPU, and Memory"
#         at Assert-DatabaseDuplicateIndex, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\internal\assertions\Database.Assertions.ps1: line 61
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 289
#       [-] Northwind on localhost,15592 should return 0 duplicate indexes 530ms
#         Expected 0, because Duplicate indexes waste disk space and cost you extra IO, CPU, and Memory, but got 12.
#         61:     @(Find-DbaDbDuplicateIndex -SqlInstance $Instance -Database $Database).Count | Should -Be 0 -Because "Duplicate indexes waste disk space and cost you extra IO, CPU, and Memory"
#         at Assert-DatabaseDuplicateIndex, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\internal\assertions\Database.Assertions.ps1: line 61
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 289
#
#   Describing Unused Index
#
#     Context Testing Unused indexes on localhost,15592
#       [!] The SQL Service on localhost,15592 was restarted on 03/14/2020 18:25:58, which is not long enough for a solid evaluation. on  should return 0 Unused indexes, is skipped 0ms
#
#   Describing Disabled Index
#
#     Context Testing Disabled indexes on localhost,15592
#
#   Describing Database Growth Event
#
#     Context Testing database growth event on localhost,15592
#
#   Describing Page Verify
#
#     Context Testing page verify on localhost,15592
#
#   Describing Auto Close
#
#     Context Testing Auto Close on localhost,15592
#
#   Describing Auto Shrink
#
#     Context Testing Auto Shrink on localhost,15592
#
#   Describing Last Full Backup Times
#
#     Context Testing last full backups on localhost,15592
#       [-] AdventureWorks2017 full backups on localhost,15592 should be less than 1 days 8ms
#         Expected the actual value to be greater than 2020-03-13T18:33:34.1998751Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:01.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] master full backups on localhost,15592 should be less than 1 days 6ms
#         Expected the actual value to be greater than 2020-03-13T18:33:34.2164599Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:41:56.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] model full backups on localhost,15592 should be less than 1 days 7ms
#         Expected the actual value to be greater than 2020-03-13T18:33:34.2320802Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:41:56.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] msdb full backups on localhost,15592 should be less than 1 days 7ms
#         Expected the actual value to be greater than 2020-03-13T18:33:34.2479414Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:41:57.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] Northwind full backups on localhost,15592 should be less than 1 days 7ms
#         Expected the actual value to be greater than 2020-03-13T18:33:34.2636176Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:01.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#       [-] pubs full backups on localhost,15592 should be less than 1 days 6ms
#         Expected the actual value to be greater than 2020-03-13T18:33:34.2773712Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:02.0000000Z.
#         463:                         $psitem.LastBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddDays( - ($maxfull)) -Because "Taking regular backups is extraordinarily important"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 463
#
#   Describing Last Diff Backup Times
#
#     Context Testing last diff backups on localhost,15592
#       [-] AdventureWorks2017 diff backups on localhost,15592 should be less than 25 hours 8ms
#         Expected the actual value to be greater than 2020-03-13T17:33:34.5003036Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:00.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 487
#       [-] Northwind diff backups on localhost,15592 should be less than 25 hours 6ms
#         Expected the actual value to be greater than 2020-03-13T17:33:34.5178133Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:00.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 487
#       [-] pubs diff backups on localhost,15592 should be less than 25 hours 6ms
#         Expected the actual value to be greater than 2020-03-13T17:33:34.5337547Z, because Taking regular backups is extraordinarily important, but got 2019-12-21T14:42:00.0000000Z.
#         487:                             $psitem.LastDifferentialBackupDate.ToUniversalTime() | Should -BeGreaterThan (Get-Date).ToUniversalTime().AddHours( - ($maxdiff)) -Because 'Taking regular backups is extraordinarily important'
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 487
#
#   Describing Last Log Backup Times
#
#     Context Testing last log backups on localhost,15592
#
#   Describing Virtual Log Files
#
#     Context Testing Database VLFs on localhost,15592
#
#   Describing Log File Count Checks
#
#     Context Testing Log File count for localhost,15592
#
#   Describing Log File Size Checks
#
#     Context Testing Log File size for localhost,15592
#
#   Describing Future File Growth
#
#     Context Testing for files likely to grow soon on localhost,15592
#       [-] master file master on 97b41bdb09c7 has free space under threshold 5ms
#         Expected the actual value to be greater than or equal to 10, because free space within the file should be lower than threshold of 10 %, but got 0.951999999999998.
#         612:                                 $PSItem.PercentFree | Should -BeGreaterOrEqual $threshold -Because "free space within the file should be lower than threshold of $threshold %"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 612
#       [-] msdb file MSDBData on 97b41bdb09c7 has free space under threshold 5ms
#         Expected the actual value to be greater than or equal to 10, because free space within the file should be lower than threshold of 10 %, but got 1.69499999999999.
#         612:                                 $PSItem.PercentFree | Should -BeGreaterOrEqual $threshold -Because "free space within the file should be lower than threshold of $threshold %"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 612
#
#   Describing Correctly sized Filegroup members
#
#     Context Testing for balanced FileGroups on localhost,15592
#
#   Describing Certificate Expiration
#
#     Context Checking that encryption certificates have not expired on localhost,15592
#
#   Describing Auto Create Statistics
#
#     Context Testing Auto Create Statistics on localhost,15592
#
#   Describing Auto Update Statistics
#
#     Context Testing Auto Update Statistics on localhost,15592
#
#   Describing Auto Update Statistics Asynchronously
#
#     Context Testing Auto Update Statistics Asynchronously on localhost,15592
#
#   Describing Datafile Auto Growth Configuration
#
#     Context Testing datafile growth type on localhost,15592
#       [-] master on filegroup PRIMARY should have GrowthType set to kb on 97b41bdb09c7 17ms
#         Expected strings to be the same, because We expect a certain file growth type, but they were different.
#         Expected length: 2
#         Actual length:   7
#         Strings differ at index 0.
#         Expected: 'kb'
#         But was:  'Percent'
#         751:                             $psitem.GrowthType | Should -Be $datafilegrowthtype -Because "We expect a certain file growth type"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 751
#       [-] master on filegroup PRIMARY should have Growth set equal or higher than 65535 on 97b41bdb09c7 7ms
#         Expected the actual value to be greater than or equal to 65535, because We expect a certain file growth value, but got 80.
#         755:                                 $psitem.Growth * 8 | Should -BeGreaterOrEqual $datafilegrowthvalue  -because "We expect a certain file growth value"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 755
#       [-] mastlog on filegroup  should have GrowthType set to kb on 97b41bdb09c7 5ms
#         Expected strings to be the same, because We expect a certain file growth type, but they were different.
#         Expected length: 2
#         Actual length:   7
#         Strings differ at index 0.
#         Expected: 'kb'
#         But was:  'Percent'
#         751:                             $psitem.GrowthType | Should -Be $datafilegrowthtype -Because "We expect a certain file growth type"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 751
#       [-] mastlog on filegroup  should have Growth set equal or higher than 65535 on 97b41bdb09c7 5ms
#         Expected the actual value to be greater than or equal to 65535, because We expect a certain file growth value, but got 80.
#         755:                                 $psitem.Growth * 8 | Should -BeGreaterOrEqual $datafilegrowthvalue  -because "We expect a certain file growth value"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 755
#       [-] MSDBData on filegroup PRIMARY should have GrowthType set to kb on 97b41bdb09c7 7ms
#         Expected strings to be the same, because We expect a certain file growth type, but they were different.
#         Expected length: 2
#         Actual length:   7
#         Strings differ at index 0.
#         Expected: 'kb'
#         But was:  'Percent'
#         751:                             $psitem.GrowthType | Should -Be $datafilegrowthtype -Because "We expect a certain file growth type"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 751
#       [-] MSDBData on filegroup PRIMARY should have Growth set equal or higher than 65535 on 97b41bdb09c7 6ms
#         Expected the actual value to be greater than or equal to 65535, because We expect a certain file growth value, but got 80.
#         755:                                 $psitem.Growth * 8 | Should -BeGreaterOrEqual $datafilegrowthvalue  -because "We expect a certain file growth value"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 755
#       [-] MSDBLog on filegroup  should have GrowthType set to kb on 97b41bdb09c7 7ms
#         Expected strings to be the same, because We expect a certain file growth type, but they were different.
#         Expected length: 2
#         Actual length:   7
#         Strings differ at index 0.
#         Expected: 'kb'
#         But was:  'Percent'
#         751:                             $psitem.GrowthType | Should -Be $datafilegrowthtype -Because "We expect a certain file growth type"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 751
#       [-] MSDBLog on filegroup  should have Growth set equal or higher than 65535 on 97b41bdb09c7 4ms
#         Expected the actual value to be greater than or equal to 65535, because We expect a certain file growth value, but got 80.
#         755:                                 $psitem.Growth * 8 | Should -BeGreaterOrEqual $datafilegrowthvalue  -because "We expect a certain file growth value"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 755
#
#   Describing Trustworthy Option
#
#     Context Testing database trustworthy option on localhost,15592
#
#   Describing Database Orphaned User
#
#     Context Testing database orphaned user event on localhost,15592
#
#   Describing PseudoSimple Recovery Model
#
#     Context Testing database is not in PseudoSimple recovery model on localhost,15592
#
#   Describing Compatibility Level
#
#     Context Testing database compatibility level matches server compatibility level on localhost,15592
#       [-] AdventureWorks2017 has a database compatibility level equal to the level of 97b41bdb09c7 16ms
#         Expected 'Version150', because it means you are on the appropriate compatibility level for your SQL Server version to use all available features, but got Version140.
#         839:                         $psItem.DatabaseCompatibility | Should -Be $psItem.ServerLevel -Because "it means you are on the appropriate compatibility level for your SQL Server version to use all available features"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 839
#
#   Describing Foreign keys and check constraints not trusted
#
#     Context Testing Foreign Keys and Check Constraints are not trusted localhost,15592
#       [-] FK_Employees_Employees foreign key on table [dbo].[Employees] within database Northwind should be trusted on 97b41bdb09c7. 6ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 858
#       [-] FK_Order_Details_Orders foreign key on table [dbo].[Order Details] within database Northwind should be trusted on 97b41bdb09c7. 5ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 858
#       [-] FK_Order_Details_Products foreign key on table [dbo].[Order Details] within database Northwind should be trusted on 97b41bdb09c7. 5ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 858
#       [-] FK_Orders_Customers foreign key on table [dbo].[Orders] within database Northwind should be trusted on 97b41bdb09c7. 5ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 858
#       [-] FK_Orders_Employees foreign key on table [dbo].[Orders] within database Northwind should be trusted on 97b41bdb09c7. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 858
#       [-] FK_Orders_Shippers foreign key on table [dbo].[Orders] within database Northwind should be trusted on 97b41bdb09c7. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 858
#       [-] FK_Products_Categories foreign key on table [dbo].[Products] within database Northwind should be trusted on 97b41bdb09c7. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 858
#       [-] FK_Products_Suppliers foreign key on table [dbo].[Products] within database Northwind should be trusted on 97b41bdb09c7. 5ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         858:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 858
#       [-] CK_Birthdate check constraint on table [dbo].[Employees] within database Northwind should be trusted on 97b41bdb09c7. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         864:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 864
#       [-] CK_Discount check constraint on table [dbo].[Order Details] within database Northwind should be trusted on 97b41bdb09c7. 3ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         864:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 864
#       [-] CK_Quantity check constraint on table [dbo].[Order Details] within database Northwind should be trusted on 97b41bdb09c7. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         864:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 864
#       [-] CK_UnitPrice check constraint on table [dbo].[Order Details] within database Northwind should be trusted on 97b41bdb09c7. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         864:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 864
#       [-] CK_Products_UnitPrice check constraint on table [dbo].[Products] within database Northwind should be trusted on 97b41bdb09c7. 4ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         864:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 864
#       [-] CK_ReorderLevel check constraint on table [dbo].[Products] within database Northwind should be trusted on 97b41bdb09c7. 5ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         864:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 864
#       [-] CK_UnitsInStock check constraint on table [dbo].[Products] within database Northwind should be trusted on 97b41bdb09c7. 5ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         864:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 864
#       [-] CK_UnitsOnOrder check constraint on table [dbo].[Products] within database Northwind should be trusted on 97b41bdb09c7. 6ms
#         Expected $true, because This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation, but got $false.
#         864:                         $psitem.IsChecked | Should -Be $true -Because "This can have a huge performance impact on queries. SQL Server won't use untrusted constraints to build better execution plans. It will also avoid data violation"
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Database.Tests.ps1: line 864
#
#   Describing Database MaxDop
#
#     Context Database MaxDop setting is correct on localhost,15592
#
#   Describing Database Status
#
#     Context Database status is correct on localhost,15592
#
#   Describing Database Exists
#
#     Context Database exists on localhost,15592
#
#   Describing Contained Database Auto Close
#
#     Context Testing contained database auto close option on localhost,15592
#
#   Describing Guest User
#
#     Context Testing Guest user has CONNECT permission on localhost,15592
#       [!] Guest user should return no CONNECT permissions in AdventureWorks2017 on localhost,15592, is skipped 0ms
#       [!] Guest user should return no CONNECT permissions in model on localhost,15592, is skipped 0ms
#       [!] Guest user should return no CONNECT permissions in Northwind on localhost,15592, is skipped 0ms
#       [!] Guest user should return no CONNECT permissions in pubs on localhost,15592, is skipped 0ms
#
# Executing script C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1
#
#   Describing Instance Connection
#
#     Context Testing Instance Connection on localhost,15592
#       [!] localhost,15592 Is PSRemoteable, is skipped 0ms
#
#   Describing TempDB Configuration
#
#     Context Testing TempDB Configuration on localhost,15592
#       [!] should have TF1118 enabled on 97b41bdb09c7, is skipped 0ms
#
#   Describing Ad Hoc Workload Optimization
#
#     Context Testing Ad Hoc Workload Optimization on localhost,15592
#
#   Describing Backup Path Access
#
#     Context Testing Backup Path Access on localhost,15592
#
#   Describing Default File Path
#
#     Context Testing Default Data File Path on localhost,15592
#
#     Context Testing Default Log File Path on localhost,15592
#
#   Describing Dedicated Administrator Connection
#
#     Context Testing Dedicated Administrator Connection on localhost,15592
#
#   Describing Network Latency
#
#     Context Testing Network Latency on localhost,15592
#
#   Describing Linked Servers
#
#     Context Testing Linked Servers on localhost,15592
#
#   Describing Max Memory
#
#     Context Testing Max Memory on localhost,15592
#       [-] Max Memory setting should be correct on localhost,15592 947ms
#         DivideByZeroException: Attempted to divide by zero.
#         RuntimeException: Attempted to divide by zero.
#         at Test-DbaMaxMemory<Process>, C:\Users\mrrob\Documents\PowerShell\Modules\dbatools\1.0.100\allcommands.ps1: line 72154
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1: line 294
#
#   Describing SQL Memory Dumps
#
#     Context Checking that dumps on localhost,15592 do not exceed 1 for localhost,15592
#
#   Describing Supported Build
#
#     Context Checking that build is still supportedby Microsoft for localhost,15592
#
#   Describing SA Login Renamed
#
#     Context Checking that sa login has been renamed on localhost,15592
#
#   Describing SA Login Disabled
#
#     Context Checking that sa login has been disabled on localhost,15592
#       [!] sa login is disabled on localhost,15592, is skipped 0ms
#
#   Describing Login SA cannot exist
#
#     Context Checking that a login named sa does not exist on localhost,15592
#       [!] sa login does not exist on localhost,15592, is skipped 0ms
#
#   Describing Default Backup Compression
#
#     Context Testing Default Backup Compression on localhost,15592
#
#   Describing XE Sessions That should be Stopped
# WARNING: You need to use Set-DbcConfig -Name policy.xevent.requiredstoppedsession -Value to add some Extended Events session names to run this check
#
#   Describing XE Sessions That should be Running
#
#     Context Checking running sessions on localhost,15592
#
#   Describing XE Sessions That Are Allowed to Be Running
# WARNING: You need to use Set-DbcConfig -Name policy.xevent.validrunningsession -Value to add some Extended Events session names to run this check
#
#   Describing OLE Automation
#
#     Context Testing OLE Automation on localhost,15592
#
#   Describing sp_whoisactive is Installed
#
#     Context Testing WhoIsActive exists on localhost,15592
#
#   Describing Model Database Growth
#
#     Context Testing model database growth setting is not default on localhost,15592
#
#   Describing Ad Users and Groups
#
#     Context Testing Active Directory users on localhost,15592
#
#     Context Testing Active Directory groups on localhost,15592
#
#   Describing Error Log Entries
#
#     Context Checking error log on localhost,15592
#       [-] Error log should be free of error severities 17-24 on localhost,15592 4ms
#         Expected $null or empty, because these severities indicate serious problems, but got @(@{LogDate=Do not know the Date; ProcessInfo=Do not know the Process; Text=Do not know the Test; InstanceName=An Error occurred [localhost,15592]}).
#         710:     $AllInstanceInfo.ErrorLog | Should -BeNullOrEmpty -Because "these severities indicate serious problems"
#         at Assert-ErrorLogEntry, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\internal\assertions\Instance.Assertions.ps1: line 710
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1: line 693
#
#   Describing Error Log Count
#
#     Context Checking error log count on localhost,15592
#
#   Describing Instance MaxDop
#
#     Context Testing Instance MaxDop Value on localhost,15592
#
#   Describing Two Digit Year Cutoff
#
#     Context Testing Two Digit Year Cutoff on localhost,15592
#
#   Describing Trace Flags Expected
#
#     Context Testing Expected Trace Flags on localhost,15592
#
#   Describing Trace Flags Not Expected
#
#     Context Testing Not Expected Trace Flags on localhost,15592
#
#   Describing CLR Enabled
#
#     Context Testing CLR Enabled on localhost,15592
#
#   Describing Cross Database Ownership Chaining
#
#     Context Testing Cross Database Ownership Chaining on localhost,15592
#       [-] Cross Database Ownership Chaining should be disabled on localhost,15592 4ms
#         Expected 0, because We expected the Cross DB Ownership Chaining to be disabled, but got 'We Could not Connect to $Instance'.
#         683:     $AllInstanceInfo.CrossDBOwnershipChaining.ConfiguredValue | Should -Be 0 -Because "We expected the Cross DB Ownership Chaining to be disabled"
#         at Assert-CrossDBOwnershipChaining, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\internal\assertions\Instance.Assertions.ps1: line 683
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1: line 820
#
#   Describing Ad Hoc Distributed Queries
#
#     Context Testing Ad Hoc Distributed Queries on localhost,15592
#
#   Describing XP CmdShell
#
#     Context Testing XP CmdShell on localhost,15592
#
#   Describing Scan For Startup Procedures
#
#     Context Testing Scan For Startup Procedures on localhost,15592
#       [-] Scan For Startup Procedures should be disabled on localhost,15592 8ms
#         Expected 0, because We expected the scan for startup procedures to be disabled, but got 'We Could not Connect to $Instance'.
#         563:     $AllInstanceInfo.ScanForStartupProceduresDisabled.ConfiguredValue | Should -Be 0 -Because "We expected the scan for startup procedures to be disabled"
#         at Assert-ScanForStartupProcedures, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\internal\assertions\Instance.Assertions.ps1: line 563
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1: line 872
#
#   Describing Default Trace
#
#     Context Checking Default Trace on localhost,15592
#       [-] The Default Trace should be enabled on localhost,15592 10ms
#         Expected 1, because We expected the Default Trace to be enabled, but got 'We Could not Connect to $Instance'.
#         538:     $AllInstanceInfo.DefaultTrace.ConfiguredValue | Should -Be 1 -Because "We expected the Default Trace to be enabled"
#         at Assert-DefaultTrace, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\internal\assertions\Instance.Assertions.ps1: line 538
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1: line 889
#
#   Describing OLE Automation Procedures Disabled
#
#     Context Checking OLE Automation Procedures on localhost,15592
#       [-] The OLE Automation Procedures should be disabled on localhost,15592 7ms
#         Expected 0, because We expect the OLE Automation Procedures to be disabled, but got 'We Could not Connect to $Instance'.
#         557:     $AllInstanceInfo.OleAutomationProceduresDisabled.ConfiguredValue | Should -Be 0 -Because "We expect the OLE Automation Procedures to be disabled"
#         at Assert-OleAutomationProcedures, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\internal\assertions\Instance.Assertions.ps1: line 557
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1: line 906
#
#   Describing Remote Access Disabled
#
#     Context Testing Remote Access on localhost,15592
#       [-] The Remote Access should be disabled on localhost,15592 5ms
#         Expected 0, because We expected Remote Access to be disabled, but got 'We Could not Connect to $Instance'.
#         572:     $AllInstanceInfo.RemoteAccess.ConfiguredValue | Should -Be 0 -Because "We expected Remote Access to be disabled"
#         at Assert-RemoteAccess, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\internal\assertions\Instance.Assertions.ps1: line 572
#         at <ScriptBlock>, C:\Users\mrrob\Documents\PowerShell\Modules\dbachecks\1.2.24\checks\Instance.Tests.ps1: line 923
#
#   Describing Latest Build
#
#     Context Testing Latest Build on localhost,15592
#
#   Describing Login BUILTIN Administrators cannot exist
#
#     Context Checking that a login named BUILTIN\Administrators does not exist on localhost,15592
#       [!] BUILTIN\Administrators login does not exist on localhost,15592, is skipped 0ms
#
#   Describing Local Windows Groups Not Have SQL Logins
#
#     Context Checking that local Windows groups do not have SQL Logins on localhost,15592
#       [!] Local Windows groups should not SQL Logins on localhost,15592, is skipped 0ms
#
#   Describing Failed Login Auditing
#
#     Context Testing if failed login auditing is in place on localhost,15592
#       [!] The failed login auditing should be set on localhost,15592, is skipped 0ms
#
#   Describing Successful Login Auditing
#
#     Context Testing if successful and failed login auditing is in place on localhost,15592
#       [!] The successful and failed auditng should be set on localhost,15592, is skipped 0ms
# Tests completed in 64.83s
# Tests Passed: 800, Failed: 59, Skipped: 14, Pending: 0, Inconclusive: 0
